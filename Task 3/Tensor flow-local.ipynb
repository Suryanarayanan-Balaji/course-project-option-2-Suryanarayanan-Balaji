# %%
#importing libraries

import findspark
import pyspark
import pyspark.sql.functions as F
import pyspark
from pyspark.sql import SparkSession, SQLContext
from pyspark.ml import Pipeline,Transformer
from pyspark.ml.feature import Imputer,StandardScaler,StringIndexer,OneHotEncoder, VectorAssembler

from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np

from pyspark.ml.classification import LogisticRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# Out:
# C:\Users\SAROJ SATHISH\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#creating spark session
findspark.init()
findspark.find()

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("MQTT") \
    .getOrCreate()

spark = SparkSession.builder.appName("mqttProject").getOrCreate()
sc    = spark.sparkContext

sqlContext = SQLContext(sc)
# Out:
# C:\Users\SAROJ SATHISH\anaconda3\lib\site-packages\pyspark\sql\context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
train = spark.read.csv( (r"C:\Users\SAROJ SATHISH\Downloads\MMQT\train70_augmented.csv"),header=True, inferSchema= True)
test  = spark.read.csv( (r"C:\Users\SAROJ SATHISH\Downloads\MMQT\test30_augmented.csv"),header=True, inferSchema= True)
DF = train.union(test)
DF = DF.toDF(*(c.replace('.', '_') for c in DF.columns))
train = train.toDF(*(c.replace('.', '_') for c in train.columns))
test = test.toDF(*(c.replace('.', '_') for c in test.columns))

# %%
numeric_features = [feature[0] for feature in DF.dtypes if feature[1] not in ('string')]
string_features = [feature[0] for feature in DF.dtypes if feature[1] in ('string')]
to_drop =  ["mqtt_conflag_cleansess","mqtt_proto_len","mqtt_conflag_passwd","mqtt_qos"]

# %%
col_names = ['tcp_flags','tcp_time_delta','tcp_len','mqtt_conack_flags','mqtt_conack_flags_reserved','mqtt_conack_flags_sp',
 'mqtt_conack_val','mqtt_conflag_cleansess','mqtt_conflag_passwd','mqtt_conflag_qos','mqtt_conflag_reserved',
 'mqtt_conflag_retain','mqtt_conflag_uname','mqtt_conflag_willflag','mqtt_conflags','mqtt_dupflag','mqtt_hdrflags', 
 'mqtt_kalive', 'mqtt_len','mqtt_msg','mqtt_msgid', 'mqtt_msgtype', 'mqtt_proto_len', 'mqtt_qos', 'mqtt_retain',
 'mqtt_sub_qos', 'mqtt_suback_qos', 'mqtt_ver', 'mqtt_willmsg', 'mqtt_willmsg_len', 'mqtt_willtopic', 'mqtt_willtopic_len',
 'target']

nominal_cols = ['tcp_flags','mqtt_conack_flags','mqtt_conflags', 'mqtt_hdrflags', 'mqtt_msg', 'mqtt_protoname']

continuous_cols = ['tcp_time_delta', 'tcp_len', 'mqtt_conack_flags_reserved', 'mqtt_conack_flags_sp', 'mqtt_conack_val',
 'mqtt_conflag_cleansess', 'mqtt_conflag_passwd', 'mqtt_conflag_qos', 'mqtt_conflag_reserved', 'mqtt_conflag_retain',
 'mqtt_conflag_uname', 'mqtt_conflag_willflag', 'mqtt_dupflag', 'mqtt_kalive', 'mqtt_len', 'mqtt_msgid',
 'mqtt_msgtype', 'mqtt_proto_len', 'mqtt_qos', 'mqtt_retain', 'mqtt_sub_qos', 'mqtt_suback_qos', 'mqtt_ver',
 'mqtt_willmsg', 'mqtt_willmsg_len', 'mqtt_willtopic', 'mqtt_willtopic_len']

# %%
class OutcomeCreater_binary(Transformer): # this defines a transformer that creates the outcome column
    
    def __init__(self):
        super().__init__()
  
    def _transform(self, dataset):
        label_to_binary = udf(lambda name: 0.0 if name == 'legitimate' else 1.0)
        output_df = dataset.withColumn('outcome', label_to_binary(col('target'))).drop("target")  
        output_df = output_df.withColumn('outcome', col('outcome').cast(DoubleType()))
        return output_df
    
class OutcomeCreater_multi(Transformer): # this defines a transformer that creates the outcome column
    
    def __init__(self):
        super().__init__()
  
    def _transform(self, dataset):
        label_to_multiple = udf(lambda name: 0.0 if name == 'legitimate' else (1.0 if name == "flood" else(2.0 if name == "dos" else(3.0 if name == "bruteforce" else(4.0 if name == "slowite" else (5.0))))))
        output_df = dataset.withColumn('outcome', label_to_multiple(col('target'))).drop("target")  
        output_df = output_df.withColumn('outcome', col('outcome').cast(DoubleType()))
        return output_df
        
class FeatureTypeCaster(Transformer): # this transformer will cast the columns as appropriate types  
    def __init__(self):
        super().__init__()

    def _transform(self, dataset):
        output_df = dataset
        for col_name in continuous_cols:
            output_df = output_df.withColumn(col_name,col(col_name).cast(DoubleType()))

        return output_df
    
class ColumnDropper(Transformer): # this transformer drops unnecessary columns
    def __init__(self, columns_to_drop = None):
        super().__init__()
        self.columns_to_drop=columns_to_drop
    def _transform(self, dataset):
        output_df = dataset
        for col_name in self.columns_to_drop:
            output_df = output_df.drop(col_name)
            
        return output_df
    
def get_preprocess_pipeline(classification):
    # Stage where columns are casted as appropriate types
    stage_typecaster = FeatureTypeCaster()

    # Stage where nominal columns are transformed to index columns using StringIndexer
    nominal_id_cols = [x+"_index" for x in nominal_cols]
    nominal_onehot_cols = [x+"_encoded" for x in nominal_cols]
    stage_nominal_indexer = StringIndexer(inputCols = nominal_cols, outputCols = nominal_id_cols )
    
    # Stage where the index columns are further transformed using OneHotEncoder
    stage_nominal_onehot_encoder = OneHotEncoder(inputCols=nominal_id_cols, outputCols=nominal_onehot_cols)

    # Stage where all relevant features are assembled into a vector (and dropping a few)
    feature_cols = continuous_cols+nominal_onehot_cols
    corelated_cols_to_remove = to_drop
    
    for col_name in corelated_cols_to_remove:
        feature_cols.remove(col_name)
    stage_vector_assembler = VectorAssembler(inputCols=feature_cols, outputCol="vectorized_features")

    # Stage where we scale the columns
    stage_scaler = StandardScaler(inputCol= 'vectorized_features', outputCol= 'features')
    

    # Stage for creating the outcome column representing whether there is attack
    if(classification == "binary"): 
        stage_outcome = OutcomeCreater_binary()
    else:
        stage_outcome = OutcomeCreater_multi()

    # Removing all unnecessary columbs, only keeping the 'features' and 'outcome' columns
    stage_column_dropper = ColumnDropper(columns_to_drop = nominal_cols+nominal_id_cols+
        nominal_onehot_cols + continuous_cols + ['vectorized_features'])
    
    pipeline = Pipeline(stages=[stage_typecaster,stage_nominal_indexer,stage_nominal_onehot_encoder,
        stage_vector_assembler,stage_scaler,stage_outcome,stage_column_dropper])
    
    return pipeline

# %% [markdown]
# ### Multiclass classification

# %%
preprocess_pipeline = get_preprocess_pipeline("multi")
preprocess_pipeline_model = preprocess_pipeline.fit(train)

train_df = preprocess_pipeline_model.transform(train)
test_df = preprocess_pipeline_model.transform(test)

# %%
train_df= train_df.limit(1400)
test_df = test_df.limit(600)

# %%
train_df.show(15)
# Out:
# +--------------------+-------+
# |            features|outcome|
# +--------------------+-------+
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,27,30,3...|    3.0|
# |(50369,[0,24,30,3...|    1.0|
# |(50369,[0,24,30,3...|    4.0|
# |(50369,[0,1,12,14...|    1.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,24,30,3...|    3.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,8,11,...|    3.0|
# |(50369,[1,12,13,1...|    2.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,28,30,3...|    5.0|
# |(50369,[0,24,30,3...|    2.0|
# +--------------------+-------+
# only showing top 15 rows

# %%
to_array = udf(lambda v: v.toArray().tolist(), ArrayType(FloatType()))

df_train = train_df
df_validate,df_test = test_df.randomSplit([0.5,0.5])

# %%
df_train.show(15)
# Out:
# +--------------------+-------+
# |            features|outcome|
# +--------------------+-------+
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,27,30,3...|    3.0|
# |(50369,[0,24,30,3...|    1.0|
# |(50369,[0,24,30,3...|    4.0|
# |(50369,[0,1,12,14...|    1.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,24,30,3...|    3.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,8,11,...|    3.0|
# |(50369,[1,12,13,1...|    2.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,1,12,14...|    0.0|
# |(50369,[0,28,30,3...|    5.0|
# |(50369,[0,24,30,3...|    2.0|
# +--------------------+-------+
# only showing top 15 rows

# %%
df_train_pandas = df_train.withColumn('features', to_array('features')).toPandas()

# %%
df_validate_pandas = df_validate.withColumn('features', to_array('features')).toPandas()
df_test_pandas = df_test.withColumn('features', to_array('features')).toPandas()

# %%
import tensorflow as tf
from tensorflow import keras 

# Converting the pandas DataFrame to tensors
# Note we are using 3 data sets train, validate, test

x_train = tf.constant(np.array(df_train_pandas['features'].values.tolist()))
y_train = tf.constant(np.array(df_train_pandas['outcome'].values.tolist()))

x_validate = tf.constant(np.array(df_validate_pandas['features'].values.tolist()))
y_validate = tf.constant(np.array(df_validate_pandas['outcome'].values.tolist()))


x_test = tf.constant(np.array(df_test_pandas['features'].values.tolist()))
y_test = tf.constant(np.array(df_test_pandas['outcome'].values.tolist()))

# %% [markdown]
# ### Shallow NN

# %%
import datetime
model_multiclass = keras.Sequential( [keras.layers.Dense(30,activation='relu'),
                           keras.layers.Dense(6)] )

model_multiclass.compile(optimizer = 'sgd',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

log_dir = "logss/multiiclassfin/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model_multiclass.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 1.5188 - sparse_categorical_accuracy: 0.4907 - val_loss: 1.2771 - val_sparse_categorical_accuracy: 0.5425 - 1s/epoch - 31ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 1.0914 - sparse_categorical_accuracy: 0.5764 - val_loss: 1.0767 - val_sparse_categorical_accuracy: 0.6438 - 474ms/epoch - 11ms/step
# Epoch 3/20
# 44/44 - 1s - loss: 0.9088 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.9598 - val_sparse_categorical_accuracy: 0.7124 - 590ms/epoch - 13ms/step
# Epoch 4/20
# 44/44 - 1s - loss: 0.7885 - sparse_categorical_accuracy: 0.7750 - val_loss: 0.8747 - val_sparse_categorical_accuracy: 0.7549 - 684ms/epoch - 16ms/step
# Epoch 5/20
# 44/44 - 1s - loss: 0.7007 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.8032 - val_sparse_categorical_accuracy: 0.7876 - 635ms/epoch - 14ms/step
# Epoch 6/20
# 44/44 - 1s - loss: 0.6430 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.7722 - val_sparse_categorical_accuracy: 0.7876 - 575ms/epoch - 13ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.6016 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.7534 - val_sparse_categorical_accuracy: 0.7876 - 479ms/epoch - 11ms/step
# Epoch 8/20
# 44/44 - 1s - loss: 0.5770 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.7331 - val_sparse_categorical_accuracy: 0.7876 - 574ms/epoch - 13ms/step
# Epoch 9/20
# 44/44 - 1s - loss: 0.5509 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.7102 - val_sparse_categorical_accuracy: 0.7876 - 522ms/epoch - 12ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.5371 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.7147 - val_sparse_categorical_accuracy: 0.7712 - 460ms/epoch - 10ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.5248 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.7061 - val_sparse_categorical_accuracy: 0.7876 - 488ms/epoch - 11ms/step
# Epoch 12/20
# 44/44 - 1s - loss: 0.5160 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.6920 - val_sparse_categorical_accuracy: 0.7712 - 546ms/epoch - 12ms/step
# Epoch 13/20
# 44/44 - 1s - loss: 0.5090 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.6971 - val_sparse_categorical_accuracy: 0.7876 - 642ms/epoch - 15ms/step
# Epoch 14/20
# 44/44 - 1s - loss: 0.5050 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.7047 - val_sparse_categorical_accuracy: 0.7908 - 567ms/epoch - 13ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.4943 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.7745 - 481ms/epoch - 11ms/step
# Epoch 16/20
# 44/44 - 1s - loss: 0.4920 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.7712 - 521ms/epoch - 12ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.4859 - sparse_categorical_accuracy: 0.8329 - val_loss: 0.6819 - val_sparse_categorical_accuracy: 0.7745 - 463ms/epoch - 11ms/step
# Epoch 18/20
# 44/44 - 1s - loss: 0.4875 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.6825 - val_sparse_categorical_accuracy: 0.7745 - 552ms/epoch - 13ms/step
# Epoch 19/20
# 44/44 - 1s - loss: 0.4830 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.6859 - val_sparse_categorical_accuracy: 0.7745 - 605ms/epoch - 14ms/step
# Epoch 20/20
# 44/44 - 1s - loss: 0.4830 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.6980 - val_sparse_categorical_accuracy: 0.7712 - 502ms/epoch - 11ms/step

# %% [markdown]
# #### Hyper parameter tuning with cross validation

# %% [markdown]
# ##### Shuffling

# %%
import tensorflow as tf
from tensorflow import keras 
train = tf.concat([x_train,tf.reshape(y_train,[-1,1])],1)
train_shuffle = tf.random.shuffle(train)
x_train_shuffle = train_shuffle[:,0:tf.shape(x_train)[1]]
y_train_shuffle = train_shuffle[:,tf.shape(x_train)[1]]

# %% [markdown]
# ##### Hyperparameters

# %%
from tensorboard.plugins.hparams import api as hp

HP_WIDTH = hp.HParam('NN_width', hp.Discrete([20,30,40]))
HP_DEPTH = hp.HParam('NN_depth', hp.Discrete([1,2]))


with tf.summary.create_file_writer('logs1483/hparams_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_WIDTH, HP_DEPTH],
    metrics=[hp.Metric('Accuracy')],
  )

# %% [markdown]
# ##### CrossValidation

# %%
def CV_model(hparams,logdir, k, current_best, d, w):
    indiceslist = []
    
    for i in range(k-1):
        indices = tf.range(i * ((tf.shape(x_train_shuffle)[0])//k), (i + 1)* ((tf.shape(x_train_shuffle)[0])//k),1).numpy().tolist()
        indiceslist.append([indices])
        
    accuracy = 0
    # combining whatever remaining after k-1 splits (to account if length of dataset is not divisible by k)
    
    indices = tf.range((k-1) * ((tf.shape(x_train_shuffle)[0])//k), (tf.shape(x_train_shuffle)[0]),1).numpy().tolist()
    
    indiceslist.append([indices]) ## indiceslist to divide train and validate
    
    for i in range(k):
        print("\nSplit no",i+1)
        model = keras.Sequential()
        for _ in range(hparams[HP_DEPTH]):
            model.add(keras.layers.Dense(hparams[HP_WIDTH],activation='relu'))
        model.add(keras.layers.Dense(6))
        model.compile(
          optimizer=keras.optimizers.SGD(),
          loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=[keras.metrics.SparseCategoricalAccuracy()])
        
        b = indiceslist[i][0] 
        a = [int(item) for item in b]

        x_validate = tf.gather(x_train_shuffle,a)

        y_validate = tf.gather(y_train_shuffle,a)
        
        z = []
        
        for j in range(k):
            
            if j != i:                     ## Make sure validation and train set are different
                z =  z + indiceslist[j][0]
                
        a = [int(item) for item in z]
        
        x_train = tf.gather(x_train_shuffle, a)
        y_train = tf.gather(y_train_shuffle, a)
        
        print("\nTraining")
        
        history = model.fit(x_train, y_train, epochs= 10,validation_data = (x_validate,y_validate), verbose = 2)
        if np.max(history.history["val_sparse_categorical_accuracy"]) > current_best:
                  current_best = np.max(history.history["val_sparse_categorical_accuracy"])
                  d = hparams[HP_DEPTH]
                  w = hparams[HP_WIDTH]
        accuracy = accuracy + np.max(history.history["val_sparse_categorical_accuracy"])
    
    return accuracy/k, d, w, current_best

# %%
k =3 
current_best = 0
d,w = 0,0
for hp_width in HP_WIDTH.domain.values:
  for hp_depth in (HP_DEPTH.domain.values):
    hparams = {
        HP_WIDTH: hp_width,
        HP_DEPTH: hp_depth,
    }
    run_name = f"run-WIDTH{int(hparams[HP_WIDTH])}-DEPTH{hparams[HP_DEPTH]}"
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})

    run_dir = 'logs1483/hparams_tuning/' + run_name
    accuracy, d, w, current_best = CV_model(hparams,run_dir, k, current_best, d, w)

    with tf.summary.create_file_writer(run_dir).as_default():
      hp.hparams(hparams)  # record the values used in this trial
      tf.summary.scalar("Accuracy", accuracy, step=1)
# Out:
# --- Starting trial: run-WIDTH20-DEPTH1
# {'NN_width': 20, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 1.6092 - sparse_categorical_accuracy: 0.4690 - val_loss: 1.4310 - val_sparse_categorical_accuracy: 0.4957 - 2s/epoch - 75ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3009 - sparse_categorical_accuracy: 0.5482 - val_loss: 1.3341 - val_sparse_categorical_accuracy: 0.5172 - 270ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1680 - sparse_categorical_accuracy: 0.5675 - val_loss: 1.2631 - val_sparse_categorical_accuracy: 0.5300 - 282ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0873 - sparse_categorical_accuracy: 0.5953 - val_loss: 1.1997 - val_sparse_categorical_accuracy: 0.5472 - 406ms/epoch - 14ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0168 - sparse_categorical_accuracy: 0.6113 - val_loss: 1.1490 - val_sparse_categorical_accuracy: 0.5536 - 281ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9593 - sparse_categorical_accuracy: 0.6253 - val_loss: 1.0973 - val_sparse_categorical_accuracy: 0.5966 - 287ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.9040 - sparse_categorical_accuracy: 0.6488 - val_loss: 1.0372 - val_sparse_categorical_accuracy: 0.5880 - 321ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8521 - sparse_categorical_accuracy: 0.6617 - val_loss: 0.9820 - val_sparse_categorical_accuracy: 0.6395 - 309ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7980 - sparse_categorical_accuracy: 0.7409 - val_loss: 0.9438 - val_sparse_categorical_accuracy: 0.6931 - 290ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7539 - sparse_categorical_accuracy: 0.7848 - val_loss: 0.9147 - val_sparse_categorical_accuracy: 0.6974 - 287ms/epoch - 10ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.9643 - sparse_categorical_accuracy: 0.4690 - val_loss: 1.9561 - val_sparse_categorical_accuracy: 0.4828 - 773ms/epoch - 26ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3541 - sparse_categorical_accuracy: 0.5364 - val_loss: 1.7740 - val_sparse_categorical_accuracy: 0.4957 - 291ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1607 - sparse_categorical_accuracy: 0.5675 - val_loss: 1.6827 - val_sparse_categorical_accuracy: 0.5451 - 294ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0091 - sparse_categorical_accuracy: 0.6306 - val_loss: 1.6167 - val_sparse_categorical_accuracy: 0.5429 - 387ms/epoch - 13ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9263 - sparse_categorical_accuracy: 0.6895 - val_loss: 1.5574 - val_sparse_categorical_accuracy: 0.6738 - 282ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8539 - sparse_categorical_accuracy: 0.7677 - val_loss: 1.5179 - val_sparse_categorical_accuracy: 0.7296 - 273ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7952 - sparse_categorical_accuracy: 0.7859 - val_loss: 1.4492 - val_sparse_categorical_accuracy: 0.7382 - 318ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7506 - sparse_categorical_accuracy: 0.8158 - val_loss: 1.4140 - val_sparse_categorical_accuracy: 0.7403 - 307ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7112 - sparse_categorical_accuracy: 0.8158 - val_loss: 1.3956 - val_sparse_categorical_accuracy: 0.7403 - 296ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6807 - sparse_categorical_accuracy: 0.8233 - val_loss: 1.3599 - val_sparse_categorical_accuracy: 0.7425 - 311ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.9635 - sparse_categorical_accuracy: 0.4453 - val_loss: 1.6025 - val_sparse_categorical_accuracy: 0.5235 - 909ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5845 - sparse_categorical_accuracy: 0.5300 - val_loss: 1.3964 - val_sparse_categorical_accuracy: 0.5214 - 389ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1710 - sparse_categorical_accuracy: 0.5633 - val_loss: 1.3082 - val_sparse_categorical_accuracy: 0.5940 - 323ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9908 - sparse_categorical_accuracy: 0.6438 - val_loss: 1.2195 - val_sparse_categorical_accuracy: 0.6026 - 321ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8908 - sparse_categorical_accuracy: 0.7178 - val_loss: 1.1721 - val_sparse_categorical_accuracy: 0.6944 - 320ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8158 - sparse_categorical_accuracy: 0.7586 - val_loss: 1.1021 - val_sparse_categorical_accuracy: 0.7051 - 335ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7600 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.0717 - val_sparse_categorical_accuracy: 0.7457 - 333ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7154 - sparse_categorical_accuracy: 0.8004 - val_loss: 1.0635 - val_sparse_categorical_accuracy: 0.7521 - 336ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6809 - sparse_categorical_accuracy: 0.8219 - val_loss: 1.0369 - val_sparse_categorical_accuracy: 0.7457 - 333ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6531 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.9833 - val_sparse_categorical_accuracy: 0.7436 - 323ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH20-DEPTH2
# {'NN_width': 20, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.4889 - sparse_categorical_accuracy: 0.4989 - val_loss: 1.4360 - val_sparse_categorical_accuracy: 0.4893 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3389 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.2754 - val_sparse_categorical_accuracy: 0.5172 - 401ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1469 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.1876 - val_sparse_categorical_accuracy: 0.5622 - 382ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0390 - sparse_categorical_accuracy: 0.5942 - val_loss: 1.1071 - val_sparse_categorical_accuracy: 0.6416 - 402ms/epoch - 13ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9540 - sparse_categorical_accuracy: 0.6274 - val_loss: 1.0299 - val_sparse_categorical_accuracy: 0.6867 - 354ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8780 - sparse_categorical_accuracy: 0.6959 - val_loss: 0.9827 - val_sparse_categorical_accuracy: 0.7682 - 370ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8094 - sparse_categorical_accuracy: 0.7741 - val_loss: 0.8868 - val_sparse_categorical_accuracy: 0.7704 - 333ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7519 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.8346 - val_sparse_categorical_accuracy: 0.7790 - 337ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7014 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.8167 - val_sparse_categorical_accuracy: 0.7489 - 378ms/epoch - 13ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6605 - sparse_categorical_accuracy: 0.8105 - val_loss: 0.7640 - val_sparse_categorical_accuracy: 0.7811 - 341ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.8321 - sparse_categorical_accuracy: 0.4507 - val_loss: 1.6608 - val_sparse_categorical_accuracy: 0.4700 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5840 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.4408 - val_sparse_categorical_accuracy: 0.4936 - 428ms/epoch - 14ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.2434 - sparse_categorical_accuracy: 0.5300 - val_loss: 1.2958 - val_sparse_categorical_accuracy: 0.5000 - 318ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1230 - sparse_categorical_accuracy: 0.5407 - val_loss: 1.2347 - val_sparse_categorical_accuracy: 0.5000 - 350ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0446 - sparse_categorical_accuracy: 0.5964 - val_loss: 1.1724 - val_sparse_categorical_accuracy: 0.6438 - 349ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9767 - sparse_categorical_accuracy: 0.6660 - val_loss: 1.1251 - val_sparse_categorical_accuracy: 0.6416 - 327ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.9155 - sparse_categorical_accuracy: 0.6927 - val_loss: 1.0986 - val_sparse_categorical_accuracy: 0.6502 - 401ms/epoch - 13ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8636 - sparse_categorical_accuracy: 0.7088 - val_loss: 1.0434 - val_sparse_categorical_accuracy: 0.6803 - 374ms/epoch - 12ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.8193 - sparse_categorical_accuracy: 0.7409 - val_loss: 1.0091 - val_sparse_categorical_accuracy: 0.7146 - 311ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7753 - sparse_categorical_accuracy: 0.7677 - val_loss: 0.9704 - val_sparse_categorical_accuracy: 0.7339 - 315ms/epoch - 11ms/step
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.8612 - sparse_categorical_accuracy: 0.3637 - val_loss: 1.6369 - val_sparse_categorical_accuracy: 0.5150 - 952ms/epoch - 32ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4723 - sparse_categorical_accuracy: 0.5172 - val_loss: 1.4513 - val_sparse_categorical_accuracy: 0.5128 - 282ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.2503 - sparse_categorical_accuracy: 0.5172 - val_loss: 1.3367 - val_sparse_categorical_accuracy: 0.5171 - 309ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1123 - sparse_categorical_accuracy: 0.5719 - val_loss: 1.3155 - val_sparse_categorical_accuracy: 0.6410 - 308ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0145 - sparse_categorical_accuracy: 0.6642 - val_loss: 1.2005 - val_sparse_categorical_accuracy: 0.6581 - 316ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9329 - sparse_categorical_accuracy: 0.6824 - val_loss: 1.1473 - val_sparse_categorical_accuracy: 0.6453 - 360ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8728 - sparse_categorical_accuracy: 0.6910 - val_loss: 1.1254 - val_sparse_categorical_accuracy: 0.6731 - 402ms/epoch - 13ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8229 - sparse_categorical_accuracy: 0.7049 - val_loss: 1.1055 - val_sparse_categorical_accuracy: 0.7073 - 315ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7841 - sparse_categorical_accuracy: 0.7361 - val_loss: 1.0532 - val_sparse_categorical_accuracy: 0.6667 - 329ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7450 - sparse_categorical_accuracy: 0.7554 - val_loss: 1.0137 - val_sparse_categorical_accuracy: 0.7030 - 315ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH30-DEPTH1
# {'NN_width': 30, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7437 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.6347 - val_sparse_categorical_accuracy: 0.4785 - 781ms/epoch - 26ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3296 - sparse_categorical_accuracy: 0.5525 - val_loss: 1.4423 - val_sparse_categorical_accuracy: 0.5043 - 336ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.0782 - sparse_categorical_accuracy: 0.5782 - val_loss: 1.3580 - val_sparse_categorical_accuracy: 0.5773 - 316ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9895 - sparse_categorical_accuracy: 0.6542 - val_loss: 1.2625 - val_sparse_categorical_accuracy: 0.5665 - 317ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8622 - sparse_categorical_accuracy: 0.7109 - val_loss: 1.1745 - val_sparse_categorical_accuracy: 0.6974 - 319ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.7931 - sparse_categorical_accuracy: 0.7805 - val_loss: 1.1442 - val_sparse_categorical_accuracy: 0.6824 - 381ms/epoch - 13ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7367 - sparse_categorical_accuracy: 0.7934 - val_loss: 1.0978 - val_sparse_categorical_accuracy: 0.7275 - 334ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6898 - sparse_categorical_accuracy: 0.8137 - val_loss: 1.0713 - val_sparse_categorical_accuracy: 0.7039 - 334ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6542 - sparse_categorical_accuracy: 0.8137 - val_loss: 1.0380 - val_sparse_categorical_accuracy: 0.7339 - 323ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6216 - sparse_categorical_accuracy: 0.8287 - val_loss: 1.0197 - val_sparse_categorical_accuracy: 0.7468 - 334ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6928 - sparse_categorical_accuracy: 0.4668 - val_loss: 1.4750 - val_sparse_categorical_accuracy: 0.4957 - 986ms/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.1654 - sparse_categorical_accuracy: 0.5600 - val_loss: 1.3473 - val_sparse_categorical_accuracy: 0.5536 - 370ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.9897 - sparse_categorical_accuracy: 0.6274 - val_loss: 1.2288 - val_sparse_categorical_accuracy: 0.5687 - 433ms/epoch - 14ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.8797 - sparse_categorical_accuracy: 0.7056 - val_loss: 1.1439 - val_sparse_categorical_accuracy: 0.6567 - 327ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.7974 - sparse_categorical_accuracy: 0.7687 - val_loss: 1.0740 - val_sparse_categorical_accuracy: 0.7296 - 343ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.7387 - sparse_categorical_accuracy: 0.7955 - val_loss: 1.0200 - val_sparse_categorical_accuracy: 0.7661 - 438ms/epoch - 15ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6905 - sparse_categorical_accuracy: 0.8084 - val_loss: 0.9790 - val_sparse_categorical_accuracy: 0.7597 - 323ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6537 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.9793 - val_sparse_categorical_accuracy: 0.7446 - 345ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6290 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.9319 - val_sparse_categorical_accuracy: 0.7682 - 329ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6069 - sparse_categorical_accuracy: 0.8244 - val_loss: 0.9115 - val_sparse_categorical_accuracy: 0.7725 - 316ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6861 - sparse_categorical_accuracy: 0.4678 - val_loss: 1.4583 - val_sparse_categorical_accuracy: 0.5299 - 1s/epoch - 41ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.1583 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.3324 - val_sparse_categorical_accuracy: 0.5641 - 378ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.0040 - sparse_categorical_accuracy: 0.5998 - val_loss: 1.2462 - val_sparse_categorical_accuracy: 0.5876 - 393ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9022 - sparse_categorical_accuracy: 0.6921 - val_loss: 1.1517 - val_sparse_categorical_accuracy: 0.6581 - 391ms/epoch - 13ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8220 - sparse_categorical_accuracy: 0.7457 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6966 - 365ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.7597 - sparse_categorical_accuracy: 0.7822 - val_loss: 1.0483 - val_sparse_categorical_accuracy: 0.7265 - 340ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7087 - sparse_categorical_accuracy: 0.8112 - val_loss: 1.0278 - val_sparse_categorical_accuracy: 0.7137 - 301ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6736 - sparse_categorical_accuracy: 0.8208 - val_loss: 0.9860 - val_sparse_categorical_accuracy: 0.7457 - 301ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6386 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.9748 - val_sparse_categorical_accuracy: 0.7457 - 324ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6103 - sparse_categorical_accuracy: 0.8230 - val_loss: 0.9535 - val_sparse_categorical_accuracy: 0.7521 - 315ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH30-DEPTH2
# {'NN_width': 30, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 9s - loss: 1.8450 - sparse_categorical_accuracy: 0.4625 - val_loss: 1.5094 - val_sparse_categorical_accuracy: 0.4785 - 9s/epoch - 316ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3712 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.3510 - val_sparse_categorical_accuracy: 0.4936 - 301ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1668 - sparse_categorical_accuracy: 0.5525 - val_loss: 1.2627 - val_sparse_categorical_accuracy: 0.4957 - 310ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0635 - sparse_categorical_accuracy: 0.5749 - val_loss: 1.1922 - val_sparse_categorical_accuracy: 0.5730 - 313ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9790 - sparse_categorical_accuracy: 0.6552 - val_loss: 1.1146 - val_sparse_categorical_accuracy: 0.5730 - 352ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9135 - sparse_categorical_accuracy: 0.7173 - val_loss: 1.0920 - val_sparse_categorical_accuracy: 0.5987 - 301ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8572 - sparse_categorical_accuracy: 0.7537 - val_loss: 0.9965 - val_sparse_categorical_accuracy: 0.6245 - 292ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8091 - sparse_categorical_accuracy: 0.7891 - val_loss: 1.0484 - val_sparse_categorical_accuracy: 0.5773 - 293ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7728 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.8992 - val_sparse_categorical_accuracy: 0.7704 - 291ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7286 - sparse_categorical_accuracy: 0.8266 - val_loss: 0.8666 - val_sparse_categorical_accuracy: 0.7682 - 341ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6632 - sparse_categorical_accuracy: 0.4433 - val_loss: 1.5080 - val_sparse_categorical_accuracy: 0.4721 - 914ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3953 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.3360 - val_sparse_categorical_accuracy: 0.5086 - 277ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1949 - sparse_categorical_accuracy: 0.5407 - val_loss: 1.2623 - val_sparse_categorical_accuracy: 0.5064 - 272ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1018 - sparse_categorical_accuracy: 0.5899 - val_loss: 1.2097 - val_sparse_categorical_accuracy: 0.5365 - 279ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0096 - sparse_categorical_accuracy: 0.6328 - val_loss: 1.1127 - val_sparse_categorical_accuracy: 0.6330 - 304ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9262 - sparse_categorical_accuracy: 0.6884 - val_loss: 1.0509 - val_sparse_categorical_accuracy: 0.7253 - 360ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8626 - sparse_categorical_accuracy: 0.7559 - val_loss: 0.9951 - val_sparse_categorical_accuracy: 0.7082 - 304ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8021 - sparse_categorical_accuracy: 0.7805 - val_loss: 1.0237 - val_sparse_categorical_accuracy: 0.6803 - 304ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7551 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.9375 - val_sparse_categorical_accuracy: 0.7661 - 305ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7108 - sparse_categorical_accuracy: 0.8116 - val_loss: 0.8977 - val_sparse_categorical_accuracy: 0.7575 - 285ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.9383 - sparse_categorical_accuracy: 0.4174 - val_loss: 1.5898 - val_sparse_categorical_accuracy: 0.5000 - 828ms/epoch - 28ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3759 - sparse_categorical_accuracy: 0.5215 - val_loss: 1.3963 - val_sparse_categorical_accuracy: 0.6068 - 299ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1378 - sparse_categorical_accuracy: 0.5665 - val_loss: 1.2547 - val_sparse_categorical_accuracy: 0.6175 - 279ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0187 - sparse_categorical_accuracy: 0.6491 - val_loss: 1.1672 - val_sparse_categorical_accuracy: 0.6624 - 277ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9197 - sparse_categorical_accuracy: 0.6899 - val_loss: 1.0865 - val_sparse_categorical_accuracy: 0.6774 - 277ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8425 - sparse_categorical_accuracy: 0.7285 - val_loss: 1.0284 - val_sparse_categorical_accuracy: 0.6902 - 321ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7772 - sparse_categorical_accuracy: 0.7618 - val_loss: 0.9919 - val_sparse_categorical_accuracy: 0.7073 - 294ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7235 - sparse_categorical_accuracy: 0.7876 - val_loss: 0.9946 - val_sparse_categorical_accuracy: 0.7436 - 281ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6833 - sparse_categorical_accuracy: 0.8155 - val_loss: 0.9432 - val_sparse_categorical_accuracy: 0.7543 - 289ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6452 - sparse_categorical_accuracy: 0.8251 - val_loss: 0.8912 - val_sparse_categorical_accuracy: 0.7521 - 322ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH40-DEPTH1
# {'NN_width': 40, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.9431 - sparse_categorical_accuracy: 0.4604 - val_loss: 1.7062 - val_sparse_categorical_accuracy: 0.4828 - 815ms/epoch - 27ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.1959 - sparse_categorical_accuracy: 0.5460 - val_loss: 1.5794 - val_sparse_categorical_accuracy: 0.4828 - 300ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.0650 - sparse_categorical_accuracy: 0.5814 - val_loss: 1.4896 - val_sparse_categorical_accuracy: 0.5343 - 323ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9662 - sparse_categorical_accuracy: 0.6585 - val_loss: 1.4268 - val_sparse_categorical_accuracy: 0.5472 - 329ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8850 - sparse_categorical_accuracy: 0.7313 - val_loss: 1.3544 - val_sparse_categorical_accuracy: 0.6459 - 353ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8186 - sparse_categorical_accuracy: 0.7548 - val_loss: 1.3064 - val_sparse_categorical_accuracy: 0.6502 - 339ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7643 - sparse_categorical_accuracy: 0.7848 - val_loss: 1.2641 - val_sparse_categorical_accuracy: 0.7146 - 338ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7197 - sparse_categorical_accuracy: 0.8137 - val_loss: 1.2236 - val_sparse_categorical_accuracy: 0.7060 - 327ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6852 - sparse_categorical_accuracy: 0.8073 - val_loss: 1.1733 - val_sparse_categorical_accuracy: 0.7489 - 314ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6528 - sparse_categorical_accuracy: 0.8223 - val_loss: 1.1689 - val_sparse_categorical_accuracy: 0.7489 - 336ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.5762 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.4642 - val_sparse_categorical_accuracy: 0.5000 - 860ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.1949 - sparse_categorical_accuracy: 0.5535 - val_loss: 1.3535 - val_sparse_categorical_accuracy: 0.5107 - 352ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.0733 - sparse_categorical_accuracy: 0.5899 - val_loss: 1.2320 - val_sparse_categorical_accuracy: 0.5622 - 348ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9651 - sparse_categorical_accuracy: 0.6660 - val_loss: 1.1463 - val_sparse_categorical_accuracy: 0.6717 - 399ms/epoch - 13ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8783 - sparse_categorical_accuracy: 0.7377 - val_loss: 1.0885 - val_sparse_categorical_accuracy: 0.7361 - 375ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8116 - sparse_categorical_accuracy: 0.7730 - val_loss: 1.0212 - val_sparse_categorical_accuracy: 0.7318 - 382ms/epoch - 13ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7559 - sparse_categorical_accuracy: 0.7944 - val_loss: 0.9727 - val_sparse_categorical_accuracy: 0.7318 - 389ms/epoch - 13ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7143 - sparse_categorical_accuracy: 0.8062 - val_loss: 0.9412 - val_sparse_categorical_accuracy: 0.7554 - 404ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6795 - sparse_categorical_accuracy: 0.8148 - val_loss: 0.9162 - val_sparse_categorical_accuracy: 0.7661 - 356ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6502 - sparse_categorical_accuracy: 0.8201 - val_loss: 0.9878 - val_sparse_categorical_accuracy: 0.7146 - 330ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.9438 - sparse_categorical_accuracy: 0.4657 - val_loss: 1.5755 - val_sparse_categorical_accuracy: 0.5171 - 681ms/epoch - 23ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.2971 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.4275 - val_sparse_categorical_accuracy: 0.5299 - 321ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.0662 - sparse_categorical_accuracy: 0.5976 - val_loss: 1.3329 - val_sparse_categorical_accuracy: 0.5897 - 293ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.9588 - sparse_categorical_accuracy: 0.6738 - val_loss: 1.2737 - val_sparse_categorical_accuracy: 0.6859 - 307ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.8664 - sparse_categorical_accuracy: 0.7489 - val_loss: 1.2001 - val_sparse_categorical_accuracy: 0.6538 - 309ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.7959 - sparse_categorical_accuracy: 0.7672 - val_loss: 1.1612 - val_sparse_categorical_accuracy: 0.7009 - 301ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7418 - sparse_categorical_accuracy: 0.7918 - val_loss: 1.1123 - val_sparse_categorical_accuracy: 0.7436 - 340ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6964 - sparse_categorical_accuracy: 0.8133 - val_loss: 1.0715 - val_sparse_categorical_accuracy: 0.7308 - 305ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6616 - sparse_categorical_accuracy: 0.8165 - val_loss: 1.0890 - val_sparse_categorical_accuracy: 0.7479 - 308ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6307 - sparse_categorical_accuracy: 0.8208 - val_loss: 1.0427 - val_sparse_categorical_accuracy: 0.7500 - 295ms/epoch - 10ms/step
# --- Starting trial: run-WIDTH40-DEPTH2
# {'NN_width': 40, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6375 - sparse_categorical_accuracy: 0.4754 - val_loss: 1.5125 - val_sparse_categorical_accuracy: 0.4807 - 816ms/epoch - 27ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3237 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.4048 - val_sparse_categorical_accuracy: 0.4957 - 378ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1688 - sparse_categorical_accuracy: 0.5482 - val_loss: 1.3206 - val_sparse_categorical_accuracy: 0.5322 - 345ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0581 - sparse_categorical_accuracy: 0.5996 - val_loss: 1.2270 - val_sparse_categorical_accuracy: 0.6116 - 449ms/epoch - 15ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9702 - sparse_categorical_accuracy: 0.6724 - val_loss: 1.1792 - val_sparse_categorical_accuracy: 0.6588 - 482ms/epoch - 16ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8997 - sparse_categorical_accuracy: 0.7152 - val_loss: 1.1100 - val_sparse_categorical_accuracy: 0.6223 - 466ms/epoch - 16ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8319 - sparse_categorical_accuracy: 0.7398 - val_loss: 1.0813 - val_sparse_categorical_accuracy: 0.6223 - 441ms/epoch - 15ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7775 - sparse_categorical_accuracy: 0.7698 - val_loss: 1.0142 - val_sparse_categorical_accuracy: 0.6803 - 395ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7316 - sparse_categorical_accuracy: 0.7955 - val_loss: 0.9783 - val_sparse_categorical_accuracy: 0.7275 - 421ms/epoch - 14ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6962 - sparse_categorical_accuracy: 0.8062 - val_loss: 0.9861 - val_sparse_categorical_accuracy: 0.6953 - 368ms/epoch - 12ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7562 - sparse_categorical_accuracy: 0.4582 - val_loss: 1.5297 - val_sparse_categorical_accuracy: 0.4936 - 1s/epoch - 46ms/step
# Epoch 2/10
# 30/30 - 1s - loss: 1.3352 - sparse_categorical_accuracy: 0.5300 - val_loss: 1.3794 - val_sparse_categorical_accuracy: 0.5150 - 554ms/epoch - 18ms/step
# Epoch 3/10
# 30/30 - 1s - loss: 1.1654 - sparse_categorical_accuracy: 0.5567 - val_loss: 1.2882 - val_sparse_categorical_accuracy: 0.5193 - 626ms/epoch - 21ms/step
# Epoch 4/10
# 30/30 - 1s - loss: 1.0619 - sparse_categorical_accuracy: 0.6006 - val_loss: 1.2571 - val_sparse_categorical_accuracy: 0.7318 - 550ms/epoch - 18ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9804 - sparse_categorical_accuracy: 0.6606 - val_loss: 1.1614 - val_sparse_categorical_accuracy: 0.6888 - 424ms/epoch - 14ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.9104 - sparse_categorical_accuracy: 0.7302 - val_loss: 1.1205 - val_sparse_categorical_accuracy: 0.6330 - 418ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.8473 - sparse_categorical_accuracy: 0.7762 - val_loss: 1.0767 - val_sparse_categorical_accuracy: 0.7403 - 409ms/epoch - 14ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7973 - sparse_categorical_accuracy: 0.7987 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.7124 - 400ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7556 - sparse_categorical_accuracy: 0.8084 - val_loss: 1.0008 - val_sparse_categorical_accuracy: 0.7747 - 454ms/epoch - 15ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7132 - sparse_categorical_accuracy: 0.8137 - val_loss: 1.0191 - val_sparse_categorical_accuracy: 0.7318 - 408ms/epoch - 14ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 1.8012 - sparse_categorical_accuracy: 0.4410 - val_loss: 1.5100 - val_sparse_categorical_accuracy: 0.5150 - 2s/epoch - 81ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4449 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.3055 - val_sparse_categorical_accuracy: 0.5278 - 300ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.1699 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.2077 - val_sparse_categorical_accuracy: 0.5342 - 315ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.0473 - sparse_categorical_accuracy: 0.5848 - val_loss: 1.1228 - val_sparse_categorical_accuracy: 0.5962 - 300ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.9434 - sparse_categorical_accuracy: 0.6588 - val_loss: 1.0694 - val_sparse_categorical_accuracy: 0.6624 - 311ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.8558 - sparse_categorical_accuracy: 0.7167 - val_loss: 0.9679 - val_sparse_categorical_accuracy: 0.7158 - 300ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.7799 - sparse_categorical_accuracy: 0.7779 - val_loss: 0.9489 - val_sparse_categorical_accuracy: 0.7436 - 301ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.7234 - sparse_categorical_accuracy: 0.7983 - val_loss: 0.8692 - val_sparse_categorical_accuracy: 0.7308 - 337ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6750 - sparse_categorical_accuracy: 0.8079 - val_loss: 0.8402 - val_sparse_categorical_accuracy: 0.7564 - 301ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6352 - sparse_categorical_accuracy: 0.8101 - val_loss: 0.8406 - val_sparse_categorical_accuracy: 0.7607 - 321ms/epoch - 11ms/step

# %% [markdown]
# ##### Best parameters

# %%
print("Tuned Depth for shallow NN = ",d)
print("Tuned Widhth for shallow NN = ",w)
# Out:
# Tuned Depth for shallow NN =  2
# Tuned Widhth for shallow NN =  20

# %% [markdown]
# #### Tuned Hyper parameters

# %%
model_multiclass = keras.Sequential( [keras.layers.Dense(20,activation='relu'),keras.layers.Dense(20,activation='relu'),
                           keras.layers.Dense(6)] )

model_multiclass.compile(optimizer = 'sgd',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

log_dir = "logss/multiiclassfin/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model_multiclass.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 1.6055 - sparse_categorical_accuracy: 0.4179 - val_loss: 1.3592 - val_sparse_categorical_accuracy: 0.5131 - 860ms/epoch - 20ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 1.1363 - sparse_categorical_accuracy: 0.5914 - val_loss: 1.1916 - val_sparse_categorical_accuracy: 0.6536 - 418ms/epoch - 10ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 0.9574 - sparse_categorical_accuracy: 0.6921 - val_loss: 1.0985 - val_sparse_categorical_accuracy: 0.6634 - 453ms/epoch - 10ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 0.8394 - sparse_categorical_accuracy: 0.7257 - val_loss: 1.0640 - val_sparse_categorical_accuracy: 0.6961 - 404ms/epoch - 9ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 0.7541 - sparse_categorical_accuracy: 0.7657 - val_loss: 1.0277 - val_sparse_categorical_accuracy: 0.7222 - 414ms/epoch - 9ms/step
# Epoch 6/20
# 44/44 - 0s - loss: 0.6978 - sparse_categorical_accuracy: 0.7864 - val_loss: 1.0115 - val_sparse_categorical_accuracy: 0.7255 - 437ms/epoch - 10ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.6548 - sparse_categorical_accuracy: 0.8043 - val_loss: 1.0208 - val_sparse_categorical_accuracy: 0.7255 - 401ms/epoch - 9ms/step
# Epoch 8/20
# 44/44 - 0s - loss: 0.6257 - sparse_categorical_accuracy: 0.8129 - val_loss: 0.9928 - val_sparse_categorical_accuracy: 0.7353 - 463ms/epoch - 11ms/step
# Epoch 9/20
# 44/44 - 0s - loss: 0.5986 - sparse_categorical_accuracy: 0.8186 - val_loss: 1.0018 - val_sparse_categorical_accuracy: 0.7320 - 429ms/epoch - 10ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.5808 - sparse_categorical_accuracy: 0.8207 - val_loss: 1.0038 - val_sparse_categorical_accuracy: 0.7418 - 435ms/epoch - 10ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.5671 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.9734 - val_sparse_categorical_accuracy: 0.7516 - 417ms/epoch - 9ms/step
# Epoch 12/20
# 44/44 - 0s - loss: 0.5595 - sparse_categorical_accuracy: 0.8243 - val_loss: 0.9653 - val_sparse_categorical_accuracy: 0.7516 - 442ms/epoch - 10ms/step
# Epoch 13/20
# 44/44 - 0s - loss: 0.5452 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.9700 - val_sparse_categorical_accuracy: 0.7614 - 405ms/epoch - 9ms/step
# Epoch 14/20
# 44/44 - 0s - loss: 0.5364 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.9724 - val_sparse_categorical_accuracy: 0.7582 - 401ms/epoch - 9ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.5224 - sparse_categorical_accuracy: 0.8243 - val_loss: 0.9880 - val_sparse_categorical_accuracy: 0.7549 - 407ms/epoch - 9ms/step
# Epoch 16/20
# 44/44 - 0s - loss: 0.5184 - sparse_categorical_accuracy: 0.8193 - val_loss: 0.9698 - val_sparse_categorical_accuracy: 0.7712 - 405ms/epoch - 9ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.5134 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.9372 - val_sparse_categorical_accuracy: 0.7516 - 420ms/epoch - 10ms/step
# Epoch 18/20
# 44/44 - 0s - loss: 0.5107 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.9480 - val_sparse_categorical_accuracy: 0.7484 - 403ms/epoch - 9ms/step
# Epoch 19/20
# 44/44 - 0s - loss: 0.5020 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.9308 - val_sparse_categorical_accuracy: 0.7614 - 412ms/epoch - 9ms/step
# Epoch 20/20
# 44/44 - 0s - loss: 0.4952 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.9292 - val_sparse_categorical_accuracy: 0.7614 - 405ms/epoch - 9ms/step

# %% [markdown]
# #### Evaluate on Test set

# %%
print("Evaluate on test data")
results = model_multiclass.evaluate(x_test, y_test)
print("test accuracy = ", results[1]);
# Out:
# Evaluate on test data
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9011 - sparse_categorical_accuracy: 0.7653
# test accuracy =  0.7653061151504517

# %% [markdown]
# ### Deep NN

# %%
import datetime
model_multiclass = keras.Sequential( [keras.layers.Dense(30,activation='relu'),keras.layers.Dense(30,activation='relu'),
                                      keras.layers.Dense(20,activation='relu'),keras.layers.Dense(20,activation='relu'),
                           keras.layers.Dense(6)] )

model_multiclass.compile(optimizer = 'sgd',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

log_dir = "logss/multiiclassfin/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model_multiclass.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 1.6440 - sparse_categorical_accuracy: 0.4771 - val_loss: 1.5313 - val_sparse_categorical_accuracy: 0.5131 - 918ms/epoch - 21ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 1.4008 - sparse_categorical_accuracy: 0.5243 - val_loss: 1.4094 - val_sparse_categorical_accuracy: 0.5131 - 477ms/epoch - 11ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 1.2963 - sparse_categorical_accuracy: 0.5243 - val_loss: 1.3223 - val_sparse_categorical_accuracy: 0.5196 - 493ms/epoch - 11ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 1.2031 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.2587 - val_sparse_categorical_accuracy: 0.5131 - 466ms/epoch - 11ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 1.1179 - sparse_categorical_accuracy: 0.5257 - val_loss: 1.1928 - val_sparse_categorical_accuracy: 0.5261 - 446ms/epoch - 10ms/step
# Epoch 6/20
# 44/44 - 1s - loss: 1.0424 - sparse_categorical_accuracy: 0.5436 - val_loss: 1.1451 - val_sparse_categorical_accuracy: 0.5523 - 551ms/epoch - 13ms/step
# Epoch 7/20
# 44/44 - 1s - loss: 0.9839 - sparse_categorical_accuracy: 0.5586 - val_loss: 1.1118 - val_sparse_categorical_accuracy: 0.5686 - 532ms/epoch - 12ms/step
# Epoch 8/20
# 44/44 - 1s - loss: 0.9317 - sparse_categorical_accuracy: 0.6221 - val_loss: 1.0718 - val_sparse_categorical_accuracy: 0.6634 - 512ms/epoch - 12ms/step
# Epoch 9/20
# 44/44 - 1s - loss: 0.8817 - sparse_categorical_accuracy: 0.7250 - val_loss: 1.0457 - val_sparse_categorical_accuracy: 0.7320 - 546ms/epoch - 12ms/step
# Epoch 10/20
# 44/44 - 1s - loss: 0.8225 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.0068 - val_sparse_categorical_accuracy: 0.7418 - 556ms/epoch - 13ms/step
# Epoch 11/20
# 44/44 - 1s - loss: 0.7632 - sparse_categorical_accuracy: 0.7943 - val_loss: 0.9915 - val_sparse_categorical_accuracy: 0.7386 - 572ms/epoch - 13ms/step
# Epoch 12/20
# 44/44 - 1s - loss: 0.7146 - sparse_categorical_accuracy: 0.8057 - val_loss: 0.9975 - val_sparse_categorical_accuracy: 0.7484 - 519ms/epoch - 12ms/step
# Epoch 13/20
# 44/44 - 1s - loss: 0.6526 - sparse_categorical_accuracy: 0.8086 - val_loss: 0.9216 - val_sparse_categorical_accuracy: 0.7484 - 521ms/epoch - 12ms/step
# Epoch 14/20
# 44/44 - 1s - loss: 0.6187 - sparse_categorical_accuracy: 0.8064 - val_loss: 1.0558 - val_sparse_categorical_accuracy: 0.7451 - 587ms/epoch - 13ms/step
# Epoch 15/20
# 44/44 - 1s - loss: 0.5893 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.9079 - val_sparse_categorical_accuracy: 0.7451 - 623ms/epoch - 14ms/step
# Epoch 16/20
# 44/44 - 1s - loss: 0.5771 - sparse_categorical_accuracy: 0.8064 - val_loss: 0.9225 - val_sparse_categorical_accuracy: 0.7451 - 582ms/epoch - 13ms/step
# Epoch 17/20
# 44/44 - 1s - loss: 0.5469 - sparse_categorical_accuracy: 0.8164 - val_loss: 0.9112 - val_sparse_categorical_accuracy: 0.7549 - 571ms/epoch - 13ms/step
# Epoch 18/20
# 44/44 - 1s - loss: 0.5587 - sparse_categorical_accuracy: 0.8136 - val_loss: 0.8984 - val_sparse_categorical_accuracy: 0.7549 - 571ms/epoch - 13ms/step
# Epoch 19/20
# 44/44 - 1s - loss: 0.5453 - sparse_categorical_accuracy: 0.8157 - val_loss: 1.1047 - val_sparse_categorical_accuracy: 0.7516 - 590ms/epoch - 13ms/step
# Epoch 20/20
# 44/44 - 1s - loss: 0.5311 - sparse_categorical_accuracy: 0.8121 - val_loss: 0.8936 - val_sparse_categorical_accuracy: 0.7549 - 520ms/epoch - 12ms/step

# %% [markdown]
# ##### Cross validation function

# %%
def CV_Deep_model(hparams,logdir, k, current_best, d, w):
    indiceslist = []
    
    for i in range(k-1):
        indices = tf.range(i * ((tf.shape(x_train_shuffle)[0])//k), (i + 1)* ((tf.shape(x_train_shuffle)[0])//k),1).numpy().tolist()
        indiceslist.append([indices])
        
    accuracy = 0
    # combining whatever remaining after k-1 splits (to account if length of dataset is not divisible by k)
    
    indices = tf.range((k-1) * ((tf.shape(x_train_shuffle)[0])//k), (tf.shape(x_train_shuffle)[0]),1).numpy().tolist()
    
    indiceslist.append([indices]) ## indiceslist to divide train and validate
    
    for i in range(k):
        print("\nSplit no",i+1)
        model = keras.Sequential()
        for _ in range(hparams[HP_DEPTH]):
            model.add(keras.layers.Dense(hparams[HP_WIDTH],activation='relu'))
        model.add(keras.layers.Dense(6))
        model.compile(
          optimizer=keras.optimizers.SGD(),
          loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=[keras.metrics.SparseCategoricalAccuracy()])
        
        b = indiceslist[i][0] 
        a = [int(item) for item in b]

        x_validate = tf.gather(x_train_shuffle,a)

        y_validate = tf.gather(y_train_shuffle,a)
        
        z = []
        
        for j in range(k):
            
            if j != i:                     ## Make sure validation and train set are different
                z =  z + indiceslist[j][0]
                
        a = [int(item) for item in z]
        
        x_train = tf.gather(x_train_shuffle, a)
        y_train = tf.gather(y_train_shuffle, a)
        
        print("\nTraining")
        
        history = model.fit(x_train, y_train, epochs= 10,validation_data = (x_validate,y_validate), verbose = 2)
        if np.max(history.history["val_sparse_categorical_accuracy"]) > current_best:
                  current_best = np.max(history.history["val_sparse_categorical_accuracy"])
                  d = hparams[HP_DEPTH]
                  w = hparams[HP_WIDTH]
        accuracy = accuracy + np.max(history.history["val_sparse_categorical_accuracy"])
    
    return accuracy/k, d, w, current_best

# %% [markdown]
# #### Shuffling

# %%
train = tf.concat([x_train,tf.reshape(y_train,[-1,1])],1)
train_shuffle = tf.random.shuffle(train)
x_train_shuffle = train_shuffle[:,0:tf.shape(x_train)[1]]
y_train_shuffle = train_shuffle[:,tf.shape(x_train)[1]]

# %% [markdown]
# ##### Hyperparameters

# %%
from tensorboard.plugins.hparams import api as hp

HP_WIDTH = hp.HParam('NN_width', hp.Discrete([20,30,40]))
HP_DEPTH = hp.HParam('NN_depth', hp.Discrete([4,5,6]))


with tf.summary.create_file_writer('logs1483/hparams_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_WIDTH, HP_DEPTH],
    metrics=[hp.Metric('Accuracy')],
  )

# %%
k =3 
current_best = 0
d,w = 0,0
for hp_width in HP_WIDTH.domain.values:
  for hp_depth in (HP_DEPTH.domain.values):
    hparams = {
        HP_WIDTH: hp_width,
        HP_DEPTH: hp_depth,
    }
    run_name = f"run-WIDTH{int(hparams[HP_WIDTH])}-DEPTH{hparams[HP_DEPTH]}"
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})

    run_dir = 'logs1483/hparams_tuning/' + run_name
    accuracy, d, w, current_best = CV_Deep_model(hparams,run_dir, k, current_best, d, w)

    with tf.summary.create_file_writer(run_dir).as_default():
      hp.hparams(hparams)  # record the values used in this trial
      tf.summary.scalar("Accuracy", accuracy, step=1)
# Out:
# --- Starting trial: run-WIDTH20-DEPTH4
# {'NN_width': 20, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7969 - sparse_categorical_accuracy: 0.4304 - val_loss: 1.7312 - val_sparse_categorical_accuracy: 0.4807 - 707ms/epoch - 24ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6487 - sparse_categorical_accuracy: 0.4936 - val_loss: 1.6003 - val_sparse_categorical_accuracy: 0.5021 - 270ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4741 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.4956 - val_sparse_categorical_accuracy: 0.5086 - 269ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3771 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.4454 - val_sparse_categorical_accuracy: 0.5086 - 264ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3267 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.4126 - val_sparse_categorical_accuracy: 0.5086 - 255ms/epoch - 8ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2822 - sparse_categorical_accuracy: 0.5310 - val_loss: 1.3724 - val_sparse_categorical_accuracy: 0.5172 - 266ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2334 - sparse_categorical_accuracy: 0.5353 - val_loss: 1.3324 - val_sparse_categorical_accuracy: 0.5172 - 278ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1789 - sparse_categorical_accuracy: 0.5364 - val_loss: 1.2939 - val_sparse_categorical_accuracy: 0.5150 - 268ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.1197 - sparse_categorical_accuracy: 0.5418 - val_loss: 1.2428 - val_sparse_categorical_accuracy: 0.5172 - 266ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0624 - sparse_categorical_accuracy: 0.5482 - val_loss: 1.1885 - val_sparse_categorical_accuracy: 0.5193 - 265ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7167 - sparse_categorical_accuracy: 0.3116 - val_loss: 1.6340 - val_sparse_categorical_accuracy: 0.5193 - 991ms/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5253 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.5074 - val_sparse_categorical_accuracy: 0.5107 - 280ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3992 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.4095 - val_sparse_categorical_accuracy: 0.5193 - 272ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2973 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.3385 - val_sparse_categorical_accuracy: 0.5172 - 281ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.2073 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2994 - val_sparse_categorical_accuracy: 0.5236 - 274ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.1399 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.3123 - val_sparse_categorical_accuracy: 0.5429 - 268ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0885 - sparse_categorical_accuracy: 0.5557 - val_loss: 1.2169 - val_sparse_categorical_accuracy: 0.5408 - 261ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.0432 - sparse_categorical_accuracy: 0.5749 - val_loss: 1.1889 - val_sparse_categorical_accuracy: 0.5386 - 273ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9942 - sparse_categorical_accuracy: 0.5931 - val_loss: 1.1686 - val_sparse_categorical_accuracy: 0.5644 - 266ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.9576 - sparse_categorical_accuracy: 0.6510 - val_loss: 1.1282 - val_sparse_categorical_accuracy: 0.5923 - 263ms/epoch - 9ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7865 - sparse_categorical_accuracy: 0.2747 - val_loss: 1.7190 - val_sparse_categorical_accuracy: 0.4316 - 748ms/epoch - 25ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5510 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.6056 - val_sparse_categorical_accuracy: 0.4466 - 273ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3962 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.5257 - val_sparse_categorical_accuracy: 0.4423 - 268ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2776 - sparse_categorical_accuracy: 0.5354 - val_loss: 1.4963 - val_sparse_categorical_accuracy: 0.4423 - 257ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.1912 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.4487 - val_sparse_categorical_accuracy: 0.4637 - 269ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.1244 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.3881 - val_sparse_categorical_accuracy: 0.4850 - 273ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0612 - sparse_categorical_accuracy: 0.5933 - val_loss: 1.3624 - val_sparse_categorical_accuracy: 0.4850 - 256ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.0030 - sparse_categorical_accuracy: 0.6373 - val_loss: 1.3460 - val_sparse_categorical_accuracy: 0.5983 - 258ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9451 - sparse_categorical_accuracy: 0.6567 - val_loss: 1.2880 - val_sparse_categorical_accuracy: 0.6004 - 254ms/epoch - 8ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.8819 - sparse_categorical_accuracy: 0.6727 - val_loss: 1.2276 - val_sparse_categorical_accuracy: 0.6068 - 266ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH20-DEPTH5
# {'NN_width': 20, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7245 - sparse_categorical_accuracy: 0.4636 - val_loss: 1.6237 - val_sparse_categorical_accuracy: 0.5150 - 843ms/epoch - 28ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5426 - sparse_categorical_accuracy: 0.5054 - val_loss: 1.4828 - val_sparse_categorical_accuracy: 0.5172 - 283ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4144 - sparse_categorical_accuracy: 0.5171 - val_loss: 1.4217 - val_sparse_categorical_accuracy: 0.5172 - 264ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3534 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.3859 - val_sparse_categorical_accuracy: 0.5172 - 271ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3039 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3361 - val_sparse_categorical_accuracy: 0.5172 - 277ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2376 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2774 - val_sparse_categorical_accuracy: 0.5172 - 373ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1599 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.3078 - val_sparse_categorical_accuracy: 0.5086 - 265ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1085 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.2529 - val_sparse_categorical_accuracy: 0.5343 - 269ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0555 - sparse_categorical_accuracy: 0.5364 - val_loss: 1.1915 - val_sparse_categorical_accuracy: 0.5601 - 368ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0264 - sparse_categorical_accuracy: 0.5728 - val_loss: 1.2215 - val_sparse_categorical_accuracy: 0.5236 - 254ms/epoch - 8ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7918 - sparse_categorical_accuracy: 0.4026 - val_loss: 1.7394 - val_sparse_categorical_accuracy: 0.5000 - 905ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6488 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.6672 - val_sparse_categorical_accuracy: 0.5193 - 324ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5666 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.5865 - val_sparse_categorical_accuracy: 0.5236 - 376ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4826 - sparse_categorical_accuracy: 0.5107 - val_loss: 1.4883 - val_sparse_categorical_accuracy: 0.5129 - 276ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3752 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3899 - val_sparse_categorical_accuracy: 0.5107 - 264ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2655 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.3055 - val_sparse_categorical_accuracy: 0.5086 - 297ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1738 - sparse_categorical_accuracy: 0.5364 - val_loss: 1.2309 - val_sparse_categorical_accuracy: 0.5472 - 290ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.0984 - sparse_categorical_accuracy: 0.5610 - val_loss: 1.1951 - val_sparse_categorical_accuracy: 0.5751 - 282ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0270 - sparse_categorical_accuracy: 0.5814 - val_loss: 1.1257 - val_sparse_categorical_accuracy: 0.5837 - 304ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.9546 - sparse_categorical_accuracy: 0.6188 - val_loss: 1.0707 - val_sparse_categorical_accuracy: 0.6438 - 275ms/epoch - 9ms/step
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 1.7266 - sparse_categorical_accuracy: 0.4560 - val_loss: 1.6768 - val_sparse_categorical_accuracy: 0.4722 - 2s/epoch - 75ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5984 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.6013 - val_sparse_categorical_accuracy: 0.4808 - 267ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5001 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5364 - val_sparse_categorical_accuracy: 0.4808 - 259ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4152 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5077 - val_sparse_categorical_accuracy: 0.4637 - 253ms/epoch - 8ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3782 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.4896 - val_sparse_categorical_accuracy: 0.4615 - 269ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.3344 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.4700 - val_sparse_categorical_accuracy: 0.4551 - 288ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2933 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4617 - val_sparse_categorical_accuracy: 0.4530 - 273ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.2545 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4259 - val_sparse_categorical_accuracy: 0.4509 - 267ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.2137 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.4300 - val_sparse_categorical_accuracy: 0.4487 - 281ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.1778 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.4017 - val_sparse_categorical_accuracy: 0.4487 - 269ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH20-DEPTH6
# {'NN_width': 20, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7702 - sparse_categorical_accuracy: 0.4347 - val_loss: 1.7276 - val_sparse_categorical_accuracy: 0.4850 - 873ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6905 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.6391 - val_sparse_categorical_accuracy: 0.4914 - 289ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.6002 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.5576 - val_sparse_categorical_accuracy: 0.4957 - 269ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.5184 - sparse_categorical_accuracy: 0.4979 - val_loss: 1.5050 - val_sparse_categorical_accuracy: 0.5000 - 258ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.4611 - sparse_categorical_accuracy: 0.5075 - val_loss: 1.4720 - val_sparse_categorical_accuracy: 0.5021 - 277ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.4187 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.4420 - val_sparse_categorical_accuracy: 0.5021 - 315ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.3753 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.4083 - val_sparse_categorical_accuracy: 0.5064 - 292ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.3272 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.3711 - val_sparse_categorical_accuracy: 0.5064 - 265ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.2730 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3308 - val_sparse_categorical_accuracy: 0.5107 - 273ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.2172 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.2765 - val_sparse_categorical_accuracy: 0.5086 - 271ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7875 - sparse_categorical_accuracy: 0.4229 - val_loss: 1.7602 - val_sparse_categorical_accuracy: 0.5043 - 974ms/epoch - 32ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.7525 - sparse_categorical_accuracy: 0.4657 - val_loss: 1.7021 - val_sparse_categorical_accuracy: 0.5043 - 260ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.6938 - sparse_categorical_accuracy: 0.4668 - val_loss: 1.6549 - val_sparse_categorical_accuracy: 0.5043 - 264ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.6495 - sparse_categorical_accuracy: 0.4679 - val_loss: 1.6148 - val_sparse_categorical_accuracy: 0.5043 - 276ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.6067 - sparse_categorical_accuracy: 0.4711 - val_loss: 1.5754 - val_sparse_categorical_accuracy: 0.5043 - 270ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.5664 - sparse_categorical_accuracy: 0.4775 - val_loss: 1.5409 - val_sparse_categorical_accuracy: 0.5043 - 268ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.5289 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.5077 - val_sparse_categorical_accuracy: 0.5043 - 319ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.4901 - sparse_categorical_accuracy: 0.4893 - val_loss: 1.4719 - val_sparse_categorical_accuracy: 0.5064 - 288ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.4511 - sparse_categorical_accuracy: 0.4936 - val_loss: 1.4410 - val_sparse_categorical_accuracy: 0.5086 - 278ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.4040 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.3996 - val_sparse_categorical_accuracy: 0.5086 - 270ms/epoch - 9ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7804 - sparse_categorical_accuracy: 0.4667 - val_loss: 1.7680 - val_sparse_categorical_accuracy: 0.4423 - 940ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.7247 - sparse_categorical_accuracy: 0.5075 - val_loss: 1.7142 - val_sparse_categorical_accuracy: 0.4466 - 320ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.6479 - sparse_categorical_accuracy: 0.5247 - val_loss: 1.6731 - val_sparse_categorical_accuracy: 0.4509 - 255ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.5897 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.6350 - val_sparse_categorical_accuracy: 0.4658 - 255ms/epoch - 8ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.5376 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.6042 - val_sparse_categorical_accuracy: 0.4658 - 269ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.4975 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.5752 - val_sparse_categorical_accuracy: 0.4658 - 304ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.4618 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.5532 - val_sparse_categorical_accuracy: 0.4658 - 281ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.4323 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5480 - val_sparse_categorical_accuracy: 0.4658 - 270ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.4084 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5119 - val_sparse_categorical_accuracy: 0.4658 - 270ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.3827 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.4944 - val_sparse_categorical_accuracy: 0.4615 - 273ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH30-DEPTH4
# {'NN_width': 30, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6182 - sparse_categorical_accuracy: 0.4679 - val_loss: 1.4764 - val_sparse_categorical_accuracy: 0.5172 - 890ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3911 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.3672 - val_sparse_categorical_accuracy: 0.5236 - 308ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.2722 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.2892 - val_sparse_categorical_accuracy: 0.5172 - 302ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1688 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.2131 - val_sparse_categorical_accuracy: 0.5215 - 317ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0874 - sparse_categorical_accuracy: 0.5814 - val_loss: 1.1681 - val_sparse_categorical_accuracy: 0.5579 - 327ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.0245 - sparse_categorical_accuracy: 0.6381 - val_loss: 1.0884 - val_sparse_categorical_accuracy: 0.6416 - 391ms/epoch - 13ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.9563 - sparse_categorical_accuracy: 0.6874 - val_loss: 1.0722 - val_sparse_categorical_accuracy: 0.6180 - 390ms/epoch - 13ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8990 - sparse_categorical_accuracy: 0.7377 - val_loss: 1.0789 - val_sparse_categorical_accuracy: 0.7039 - 304ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.8492 - sparse_categorical_accuracy: 0.7548 - val_loss: 0.9368 - val_sparse_categorical_accuracy: 0.6974 - 280ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7922 - sparse_categorical_accuracy: 0.7794 - val_loss: 0.8872 - val_sparse_categorical_accuracy: 0.7318 - 274ms/epoch - 9ms/step
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7067 - sparse_categorical_accuracy: 0.4325 - val_loss: 1.6308 - val_sparse_categorical_accuracy: 0.5064 - 891ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5571 - sparse_categorical_accuracy: 0.5075 - val_loss: 1.4836 - val_sparse_categorical_accuracy: 0.5343 - 277ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4219 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.3948 - val_sparse_categorical_accuracy: 0.5279 - 331ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3519 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.3510 - val_sparse_categorical_accuracy: 0.5236 - 277ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.2983 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3223 - val_sparse_categorical_accuracy: 0.5193 - 303ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2499 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.2696 - val_sparse_categorical_accuracy: 0.5193 - 308ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1831 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.2474 - val_sparse_categorical_accuracy: 0.5172 - 307ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1308 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.2083 - val_sparse_categorical_accuracy: 0.5150 - 309ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0826 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.1474 - val_sparse_categorical_accuracy: 0.5622 - 308ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0188 - sparse_categorical_accuracy: 0.5835 - val_loss: 1.0892 - val_sparse_categorical_accuracy: 0.6052 - 303ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6089 - sparse_categorical_accuracy: 0.4903 - val_loss: 1.5280 - val_sparse_categorical_accuracy: 0.4573 - 1s/epoch - 40ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3677 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.4448 - val_sparse_categorical_accuracy: 0.4679 - 438ms/epoch - 15ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.2441 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.3999 - val_sparse_categorical_accuracy: 0.4615 - 417ms/epoch - 14ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1690 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.3553 - val_sparse_categorical_accuracy: 0.4615 - 453ms/epoch - 15ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.1007 - sparse_categorical_accuracy: 0.5418 - val_loss: 1.2943 - val_sparse_categorical_accuracy: 0.4765 - 350ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.0407 - sparse_categorical_accuracy: 0.5526 - val_loss: 1.2645 - val_sparse_categorical_accuracy: 0.4808 - 366ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.9896 - sparse_categorical_accuracy: 0.5762 - val_loss: 1.2450 - val_sparse_categorical_accuracy: 0.5150 - 363ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.9464 - sparse_categorical_accuracy: 0.6373 - val_loss: 1.2029 - val_sparse_categorical_accuracy: 0.6645 - 321ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9070 - sparse_categorical_accuracy: 0.6985 - val_loss: 1.1615 - val_sparse_categorical_accuracy: 0.6731 - 367ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.8666 - sparse_categorical_accuracy: 0.7393 - val_loss: 1.2405 - val_sparse_categorical_accuracy: 0.5427 - 367ms/epoch - 12ms/step
# --- Starting trial: run-WIDTH30-DEPTH5
# {'NN_width': 30, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7774 - sparse_categorical_accuracy: 0.4069 - val_loss: 1.7238 - val_sparse_categorical_accuracy: 0.4850 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6619 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.6364 - val_sparse_categorical_accuracy: 0.5021 - 338ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5538 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.5460 - val_sparse_categorical_accuracy: 0.5107 - 351ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4622 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.4613 - val_sparse_categorical_accuracy: 0.5086 - 343ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3788 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3987 - val_sparse_categorical_accuracy: 0.5021 - 364ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.3100 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3469 - val_sparse_categorical_accuracy: 0.5021 - 341ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2369 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3007 - val_sparse_categorical_accuracy: 0.5043 - 332ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1580 - sparse_categorical_accuracy: 0.5782 - val_loss: 1.2114 - val_sparse_categorical_accuracy: 0.6030 - 341ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0712 - sparse_categorical_accuracy: 0.6392 - val_loss: 1.1356 - val_sparse_categorical_accuracy: 0.6094 - 375ms/epoch - 13ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.9872 - sparse_categorical_accuracy: 0.6617 - val_loss: 1.0824 - val_sparse_categorical_accuracy: 0.6588 - 349ms/epoch - 12ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 4s - loss: 1.7324 - sparse_categorical_accuracy: 0.4582 - val_loss: 1.6344 - val_sparse_categorical_accuracy: 0.5129 - 4s/epoch - 132ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.5584 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.5010 - val_sparse_categorical_accuracy: 0.5300 - 356ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4298 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.4302 - val_sparse_categorical_accuracy: 0.5279 - 350ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3569 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.3706 - val_sparse_categorical_accuracy: 0.5193 - 307ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.2941 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.3422 - val_sparse_categorical_accuracy: 0.5193 - 299ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2278 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2968 - val_sparse_categorical_accuracy: 0.5172 - 301ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1681 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2501 - val_sparse_categorical_accuracy: 0.5172 - 303ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1184 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2311 - val_sparse_categorical_accuracy: 0.5129 - 310ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0761 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.1971 - val_sparse_categorical_accuracy: 0.5386 - 323ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0423 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.1804 - val_sparse_categorical_accuracy: 0.5215 - 355ms/epoch - 12ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.8227 - sparse_categorical_accuracy: 0.4292 - val_loss: 1.7686 - val_sparse_categorical_accuracy: 0.4316 - 857ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6813 - sparse_categorical_accuracy: 0.5064 - val_loss: 1.6344 - val_sparse_categorical_accuracy: 0.4509 - 297ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5337 - sparse_categorical_accuracy: 0.5300 - val_loss: 1.5527 - val_sparse_categorical_accuracy: 0.4658 - 290ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4189 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5157 - val_sparse_categorical_accuracy: 0.4637 - 296ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3611 - sparse_categorical_accuracy: 0.5461 - val_loss: 1.4949 - val_sparse_categorical_accuracy: 0.4679 - 294ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.3111 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.4566 - val_sparse_categorical_accuracy: 0.4701 - 297ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2521 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.4652 - val_sparse_categorical_accuracy: 0.4658 - 302ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1899 - sparse_categorical_accuracy: 0.5719 - val_loss: 1.3652 - val_sparse_categorical_accuracy: 0.4808 - 317ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.1237 - sparse_categorical_accuracy: 0.5848 - val_loss: 1.2891 - val_sparse_categorical_accuracy: 0.4808 - 335ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0723 - sparse_categorical_accuracy: 0.5923 - val_loss: 1.3070 - val_sparse_categorical_accuracy: 0.4722 - 324ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH30-DEPTH6
# {'NN_width': 30, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7306 - sparse_categorical_accuracy: 0.3844 - val_loss: 1.6721 - val_sparse_categorical_accuracy: 0.4871 - 868ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6052 - sparse_categorical_accuracy: 0.4979 - val_loss: 1.5516 - val_sparse_categorical_accuracy: 0.5129 - 295ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4693 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.4653 - val_sparse_categorical_accuracy: 0.5064 - 290ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3862 - sparse_categorical_accuracy: 0.5171 - val_loss: 1.4211 - val_sparse_categorical_accuracy: 0.5043 - 288ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3079 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.3413 - val_sparse_categorical_accuracy: 0.5043 - 312ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2336 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.2839 - val_sparse_categorical_accuracy: 0.5043 - 331ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1758 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.3190 - val_sparse_categorical_accuracy: 0.5043 - 302ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1359 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2437 - val_sparse_categorical_accuracy: 0.5107 - 298ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.1025 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.1859 - val_sparse_categorical_accuracy: 0.5107 - 295ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0775 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.2385 - val_sparse_categorical_accuracy: 0.5129 - 295ms/epoch - 10ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.8033 - sparse_categorical_accuracy: 0.4122 - val_loss: 1.7489 - val_sparse_categorical_accuracy: 0.4914 - 939ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.7209 - sparse_categorical_accuracy: 0.4764 - val_loss: 1.6733 - val_sparse_categorical_accuracy: 0.5193 - 303ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.6288 - sparse_categorical_accuracy: 0.5054 - val_loss: 1.6124 - val_sparse_categorical_accuracy: 0.5193 - 296ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.5642 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.5554 - val_sparse_categorical_accuracy: 0.5258 - 290ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.5102 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.4969 - val_sparse_categorical_accuracy: 0.5300 - 313ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.4589 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.4482 - val_sparse_categorical_accuracy: 0.5322 - 310ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.4141 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.4086 - val_sparse_categorical_accuracy: 0.5322 - 304ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.3758 - sparse_categorical_accuracy: 0.5107 - val_loss: 1.3719 - val_sparse_categorical_accuracy: 0.5279 - 309ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.3328 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.3386 - val_sparse_categorical_accuracy: 0.5300 - 303ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.2841 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.3003 - val_sparse_categorical_accuracy: 0.5236 - 314ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7700 - sparse_categorical_accuracy: 0.4871 - val_loss: 1.7369 - val_sparse_categorical_accuracy: 0.4423 - 933ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6651 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.6554 - val_sparse_categorical_accuracy: 0.4444 - 294ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5600 - sparse_categorical_accuracy: 0.5129 - val_loss: 1.5967 - val_sparse_categorical_accuracy: 0.4444 - 285ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4766 - sparse_categorical_accuracy: 0.5279 - val_loss: 1.5553 - val_sparse_categorical_accuracy: 0.4487 - 290ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.4143 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.5361 - val_sparse_categorical_accuracy: 0.4466 - 332ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.3718 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.5241 - val_sparse_categorical_accuracy: 0.4487 - 296ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.3410 - sparse_categorical_accuracy: 0.5397 - val_loss: 1.5449 - val_sparse_categorical_accuracy: 0.4444 - 334ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.3129 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5045 - val_sparse_categorical_accuracy: 0.4466 - 310ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.2765 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4827 - val_sparse_categorical_accuracy: 0.4466 - 295ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.2324 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4271 - val_sparse_categorical_accuracy: 0.4509 - 402ms/epoch - 13ms/step
# --- Starting trial: run-WIDTH40-DEPTH4
# {'NN_width': 40, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6742 - sparse_categorical_accuracy: 0.4668 - val_loss: 1.5240 - val_sparse_categorical_accuracy: 0.5215 - 857ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4582 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.4092 - val_sparse_categorical_accuracy: 0.5279 - 325ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3319 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.3346 - val_sparse_categorical_accuracy: 0.5193 - 327ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2488 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.2840 - val_sparse_categorical_accuracy: 0.5172 - 320ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.1782 - sparse_categorical_accuracy: 0.5236 - val_loss: 1.2316 - val_sparse_categorical_accuracy: 0.5279 - 331ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.1086 - sparse_categorical_accuracy: 0.5899 - val_loss: 1.1890 - val_sparse_categorical_accuracy: 0.6223 - 318ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0458 - sparse_categorical_accuracy: 0.6392 - val_loss: 1.1573 - val_sparse_categorical_accuracy: 0.6223 - 326ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.9835 - sparse_categorical_accuracy: 0.6478 - val_loss: 1.1479 - val_sparse_categorical_accuracy: 0.6180 - 317ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9349 - sparse_categorical_accuracy: 0.6874 - val_loss: 1.0641 - val_sparse_categorical_accuracy: 0.6416 - 339ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.8802 - sparse_categorical_accuracy: 0.7131 - val_loss: 1.0334 - val_sparse_categorical_accuracy: 0.6373 - 324ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6463 - sparse_categorical_accuracy: 0.4818 - val_loss: 1.4815 - val_sparse_categorical_accuracy: 0.5258 - 884ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4080 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.4029 - val_sparse_categorical_accuracy: 0.5236 - 341ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3080 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3706 - val_sparse_categorical_accuracy: 0.5215 - 355ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2251 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3457 - val_sparse_categorical_accuracy: 0.5150 - 371ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.1533 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.3193 - val_sparse_categorical_accuracy: 0.5215 - 374ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.0948 - sparse_categorical_accuracy: 0.5428 - val_loss: 1.3356 - val_sparse_categorical_accuracy: 0.5215 - 409ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0411 - sparse_categorical_accuracy: 0.6156 - val_loss: 1.2498 - val_sparse_categorical_accuracy: 0.5901 - 423ms/epoch - 14ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.9880 - sparse_categorical_accuracy: 0.6916 - val_loss: 1.2072 - val_sparse_categorical_accuracy: 0.7532 - 476ms/epoch - 16ms/step
# Epoch 9/10
# 30/30 - 1s - loss: 0.9380 - sparse_categorical_accuracy: 0.7559 - val_loss: 1.4151 - val_sparse_categorical_accuracy: 0.5837 - 519ms/epoch - 17ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.8855 - sparse_categorical_accuracy: 0.7827 - val_loss: 1.3269 - val_sparse_categorical_accuracy: 0.5343 - 400ms/epoch - 13ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6407 - sparse_categorical_accuracy: 0.4764 - val_loss: 1.5269 - val_sparse_categorical_accuracy: 0.4722 - 1s/epoch - 35ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.3832 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.4474 - val_sparse_categorical_accuracy: 0.4722 - 393ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.2554 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.3701 - val_sparse_categorical_accuracy: 0.4615 - 397ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.1595 - sparse_categorical_accuracy: 0.5429 - val_loss: 1.3438 - val_sparse_categorical_accuracy: 0.4594 - 407ms/epoch - 14ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.0845 - sparse_categorical_accuracy: 0.5536 - val_loss: 1.2786 - val_sparse_categorical_accuracy: 0.4573 - 397ms/epoch - 13ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.0159 - sparse_categorical_accuracy: 0.6223 - val_loss: 1.1978 - val_sparse_categorical_accuracy: 0.5876 - 430ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.9401 - sparse_categorical_accuracy: 0.6792 - val_loss: 1.2131 - val_sparse_categorical_accuracy: 0.5192 - 438ms/epoch - 15ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.8744 - sparse_categorical_accuracy: 0.7393 - val_loss: 1.0344 - val_sparse_categorical_accuracy: 0.6752 - 423ms/epoch - 14ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.7853 - sparse_categorical_accuracy: 0.7908 - val_loss: 1.0412 - val_sparse_categorical_accuracy: 0.6731 - 412ms/epoch - 14ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.7253 - sparse_categorical_accuracy: 0.8026 - val_loss: 1.0404 - val_sparse_categorical_accuracy: 0.5983 - 469ms/epoch - 16ms/step
# --- Starting trial: run-WIDTH40-DEPTH5
# {'NN_width': 40, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6468 - sparse_categorical_accuracy: 0.4711 - val_loss: 1.5525 - val_sparse_categorical_accuracy: 0.5279 - 1s/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4409 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.4418 - val_sparse_categorical_accuracy: 0.5193 - 360ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3379 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3873 - val_sparse_categorical_accuracy: 0.5193 - 404ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2395 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2899 - val_sparse_categorical_accuracy: 0.5107 - 394ms/epoch - 13ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.1544 - sparse_categorical_accuracy: 0.5214 - val_loss: 1.2220 - val_sparse_categorical_accuracy: 0.5129 - 385ms/epoch - 13ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.0946 - sparse_categorical_accuracy: 0.5428 - val_loss: 1.1898 - val_sparse_categorical_accuracy: 0.5987 - 377ms/epoch - 13ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0442 - sparse_categorical_accuracy: 0.5867 - val_loss: 1.1273 - val_sparse_categorical_accuracy: 0.6073 - 368ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.9928 - sparse_categorical_accuracy: 0.6317 - val_loss: 1.0791 - val_sparse_categorical_accuracy: 0.6223 - 388ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9477 - sparse_categorical_accuracy: 0.6574 - val_loss: 1.0327 - val_sparse_categorical_accuracy: 0.6738 - 384ms/epoch - 13ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.8862 - sparse_categorical_accuracy: 0.7056 - val_loss: 0.9844 - val_sparse_categorical_accuracy: 0.6996 - 377ms/epoch - 13ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 1.6737 - sparse_categorical_accuracy: 0.4700 - val_loss: 1.5641 - val_sparse_categorical_accuracy: 0.5086 - 2s/epoch - 81ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4706 - sparse_categorical_accuracy: 0.4957 - val_loss: 1.4342 - val_sparse_categorical_accuracy: 0.5172 - 331ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3552 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3788 - val_sparse_categorical_accuracy: 0.5107 - 305ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2730 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3201 - val_sparse_categorical_accuracy: 0.5107 - 333ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.2016 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2726 - val_sparse_categorical_accuracy: 0.5107 - 320ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.1363 - sparse_categorical_accuracy: 0.5782 - val_loss: 1.2284 - val_sparse_categorical_accuracy: 0.6180 - 424ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.0771 - sparse_categorical_accuracy: 0.6253 - val_loss: 1.1879 - val_sparse_categorical_accuracy: 0.6459 - 339ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.0231 - sparse_categorical_accuracy: 0.6370 - val_loss: 1.1502 - val_sparse_categorical_accuracy: 0.6373 - 331ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.9593 - sparse_categorical_accuracy: 0.6531 - val_loss: 1.0986 - val_sparse_categorical_accuracy: 0.6373 - 331ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.9104 - sparse_categorical_accuracy: 0.6670 - val_loss: 1.0360 - val_sparse_categorical_accuracy: 0.6738 - 331ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7606 - sparse_categorical_accuracy: 0.4356 - val_loss: 1.6829 - val_sparse_categorical_accuracy: 0.4701 - 942ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6078 - sparse_categorical_accuracy: 0.5354 - val_loss: 1.5901 - val_sparse_categorical_accuracy: 0.4808 - 348ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.4751 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5172 - val_sparse_categorical_accuracy: 0.4701 - 331ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.3751 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4958 - val_sparse_categorical_accuracy: 0.4594 - 344ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3276 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4754 - val_sparse_categorical_accuracy: 0.4615 - 330ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2938 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4620 - val_sparse_categorical_accuracy: 0.4594 - 325ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2548 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4217 - val_sparse_categorical_accuracy: 0.4551 - 342ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.2010 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4985 - val_sparse_categorical_accuracy: 0.4509 - 333ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.1569 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.3607 - val_sparse_categorical_accuracy: 0.4594 - 376ms/epoch - 13ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.1067 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.3298 - val_sparse_categorical_accuracy: 0.4573 - 349ms/epoch - 12ms/step
# --- Starting trial: run-WIDTH40-DEPTH6
# {'NN_width': 40, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.6839 - sparse_categorical_accuracy: 0.4743 - val_loss: 1.5688 - val_sparse_categorical_accuracy: 0.5215 - 974ms/epoch - 32ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.4728 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.4338 - val_sparse_categorical_accuracy: 0.5107 - 322ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.3507 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.3628 - val_sparse_categorical_accuracy: 0.5064 - 321ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.2721 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.3277 - val_sparse_categorical_accuracy: 0.5000 - 330ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.2093 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2643 - val_sparse_categorical_accuracy: 0.5000 - 334ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.1518 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2214 - val_sparse_categorical_accuracy: 0.4979 - 344ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.1067 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.1878 - val_sparse_categorical_accuracy: 0.4979 - 357ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.0749 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.1588 - val_sparse_categorical_accuracy: 0.5086 - 386ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.0529 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.1383 - val_sparse_categorical_accuracy: 0.5451 - 343ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0361 - sparse_categorical_accuracy: 0.6156 - val_loss: 1.1253 - val_sparse_categorical_accuracy: 0.6137 - 442ms/epoch - 15ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7846 - sparse_categorical_accuracy: 0.4433 - val_loss: 1.7222 - val_sparse_categorical_accuracy: 0.5000 - 937ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6595 - sparse_categorical_accuracy: 0.4818 - val_loss: 1.6179 - val_sparse_categorical_accuracy: 0.5129 - 326ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5376 - sparse_categorical_accuracy: 0.5064 - val_loss: 1.5182 - val_sparse_categorical_accuracy: 0.5129 - 348ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.4349 - sparse_categorical_accuracy: 0.5107 - val_loss: 1.4606 - val_sparse_categorical_accuracy: 0.5086 - 342ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.3604 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.4177 - val_sparse_categorical_accuracy: 0.5086 - 333ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.2955 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.4052 - val_sparse_categorical_accuracy: 0.5086 - 333ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.2306 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3460 - val_sparse_categorical_accuracy: 0.5086 - 372ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.1614 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.3177 - val_sparse_categorical_accuracy: 0.5107 - 343ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.1103 - sparse_categorical_accuracy: 0.5139 - val_loss: 1.2797 - val_sparse_categorical_accuracy: 0.5129 - 326ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.0631 - sparse_categorical_accuracy: 0.5203 - val_loss: 1.2565 - val_sparse_categorical_accuracy: 0.5451 - 342ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 1.7992 - sparse_categorical_accuracy: 0.4528 - val_loss: 1.7563 - val_sparse_categorical_accuracy: 0.4380 - 908ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 1.6933 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.6727 - val_sparse_categorical_accuracy: 0.4573 - 343ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 1.5842 - sparse_categorical_accuracy: 0.5365 - val_loss: 1.6114 - val_sparse_categorical_accuracy: 0.4808 - 330ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 1.5059 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5648 - val_sparse_categorical_accuracy: 0.4722 - 338ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 1.4454 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5398 - val_sparse_categorical_accuracy: 0.4658 - 333ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 1.4021 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5136 - val_sparse_categorical_accuracy: 0.4615 - 337ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 1.3651 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.5035 - val_sparse_categorical_accuracy: 0.4573 - 357ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 1.3421 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4928 - val_sparse_categorical_accuracy: 0.4573 - 337ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 1.3200 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4877 - val_sparse_categorical_accuracy: 0.4573 - 341ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 1.2967 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4810 - val_sparse_categorical_accuracy: 0.4509 - 341ms/epoch - 11ms/step

# %% [markdown]
# ### Best Parameters

# %%
print("Tuned Depth for Deep NN = ",d)
print("Tuned Widhth for Deep NN = ",w)
# Out:
# Tuned Depth for Deep NN =  4
# Tuned Widhth for Deep NN =  40

# %%
model_multiclass = keras.Sequential( [keras.layers.Dense(40,activation='relu'),keras.layers.Dense(40,activation='relu'),
                           keras.layers.Dense(40,activation='relu'), keras.layers.Dense(40,activation='relu'),
                           keras.layers.Dense(6)] )

model_multiclass.compile(optimizer = 'sgd',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy()])

log_dir = "logss/multiiclassfin/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model_multiclass.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 1.7159 - sparse_categorical_accuracy: 0.4200 - val_loss: 1.5677 - val_sparse_categorical_accuracy: 0.5000 - 1s/epoch - 25ms/step
# Epoch 2/20
# 44/44 - 1s - loss: 1.4641 - sparse_categorical_accuracy: 0.5229 - val_loss: 1.3996 - val_sparse_categorical_accuracy: 0.5229 - 552ms/epoch - 13ms/step
# Epoch 3/20
# 44/44 - 1s - loss: 1.3304 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.3256 - val_sparse_categorical_accuracy: 0.5163 - 631ms/epoch - 14ms/step
# Epoch 4/20
# 44/44 - 1s - loss: 1.2420 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.2552 - val_sparse_categorical_accuracy: 0.5163 - 601ms/epoch - 14ms/step
# Epoch 5/20
# 44/44 - 1s - loss: 1.1478 - sparse_categorical_accuracy: 0.5357 - val_loss: 1.1759 - val_sparse_categorical_accuracy: 0.5556 - 569ms/epoch - 13ms/step
# Epoch 6/20
# 44/44 - 1s - loss: 1.0569 - sparse_categorical_accuracy: 0.6079 - val_loss: 1.0988 - val_sparse_categorical_accuracy: 0.6111 - 557ms/epoch - 13ms/step
# Epoch 7/20
# 44/44 - 1s - loss: 0.9614 - sparse_categorical_accuracy: 0.6529 - val_loss: 1.0113 - val_sparse_categorical_accuracy: 0.6405 - 608ms/epoch - 14ms/step
# Epoch 8/20
# 44/44 - 1s - loss: 0.8717 - sparse_categorical_accuracy: 0.6764 - val_loss: 0.9475 - val_sparse_categorical_accuracy: 0.6601 - 566ms/epoch - 13ms/step
# Epoch 9/20
# 44/44 - 1s - loss: 0.8000 - sparse_categorical_accuracy: 0.7214 - val_loss: 0.8762 - val_sparse_categorical_accuracy: 0.7386 - 562ms/epoch - 13ms/step
# Epoch 10/20
# 44/44 - 1s - loss: 0.7431 - sparse_categorical_accuracy: 0.7621 - val_loss: 0.8488 - val_sparse_categorical_accuracy: 0.7516 - 570ms/epoch - 13ms/step
# Epoch 11/20
# 44/44 - 1s - loss: 0.6970 - sparse_categorical_accuracy: 0.7779 - val_loss: 0.8279 - val_sparse_categorical_accuracy: 0.7484 - 649ms/epoch - 15ms/step
# Epoch 12/20
# 44/44 - 1s - loss: 0.6560 - sparse_categorical_accuracy: 0.7957 - val_loss: 0.7702 - val_sparse_categorical_accuracy: 0.7582 - 553ms/epoch - 13ms/step
# Epoch 13/20
# 44/44 - 1s - loss: 0.6238 - sparse_categorical_accuracy: 0.8136 - val_loss: 0.7614 - val_sparse_categorical_accuracy: 0.7876 - 676ms/epoch - 15ms/step
# Epoch 14/20
# 44/44 - 1s - loss: 0.5940 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.7214 - val_sparse_categorical_accuracy: 0.7876 - 646ms/epoch - 15ms/step
# Epoch 15/20
# 44/44 - 1s - loss: 0.5766 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.7214 - val_sparse_categorical_accuracy: 0.7908 - 563ms/epoch - 13ms/step
# Epoch 16/20
# 44/44 - 1s - loss: 0.5594 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.7058 - val_sparse_categorical_accuracy: 0.7908 - 640ms/epoch - 15ms/step
# Epoch 17/20
# 44/44 - 1s - loss: 0.5382 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.7182 - val_sparse_categorical_accuracy: 0.7908 - 628ms/epoch - 14ms/step
# Epoch 18/20
# 44/44 - 1s - loss: 0.5274 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.7326 - val_sparse_categorical_accuracy: 0.7908 - 580ms/epoch - 13ms/step
# Epoch 19/20
# 44/44 - 1s - loss: 0.5111 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.6857 - val_sparse_categorical_accuracy: 0.7810 - 633ms/epoch - 14ms/step
# Epoch 20/20
# 44/44 - 1s - loss: 0.5064 - sparse_categorical_accuracy: 0.8271 - val_loss: 0.7554 - val_sparse_categorical_accuracy: 0.7712 - 632ms/epoch - 14ms/step

# %% [markdown]
# ### Testing on Test set

# %%
print("Evaluate on test data")
results = model_multiclass.evaluate(x_test, y_test)
print("test accuracy = ", results[1]);
# Out:
# Evaluate on test data
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8520 - sparse_categorical_accuracy: 0.7959
# test accuracy =  0.795918345451355

# %% [markdown]
# ## Binary Classification

# %%
train = spark.read.csv( (r"C:\Users\SAROJ SATHISH\Downloads\MMQT\train70_augmented.csv"),header=True, inferSchema= True)
test  = spark.read.csv( (r"C:\Users\SAROJ SATHISH\Downloads\MMQT\test30_augmented.csv"),header=True, inferSchema= True)
DF = train.union(test)
DF = DF.toDF(*(c.replace('.', '_') for c in DF.columns))
train = train.toDF(*(c.replace('.', '_') for c in train.columns))
test = test.toDF(*(c.replace('.', '_') for c in test.columns))

# %%
preprocess_pipeline = get_preprocess_pipeline("binary")
preprocess_pipeline_model = preprocess_pipeline.fit(train)

train_df = preprocess_pipeline_model.transform(train)
test_df = preprocess_pipeline_model.transform(test)

# %%
train_df= train_df.limit(1400)
test_df = test_df.limit(600)

# %%
to_array = udf(lambda v: v.toArray().tolist(), ArrayType(FloatType()))

df_train = train_df
df_validate,df_test = test_df.randomSplit([0.5,0.5])

# %%
df_train_pandas = df_train.withColumn('features', to_array('features')).toPandas()
df_validate_pandas = df_validate.withColumn('features', to_array('features')).toPandas()
df_test_pandas = df_test.withColumn('features', to_array('features')).toPandas()

# %%
import tensorflow as tf
from tensorflow import keras 

# Converting the pandas DataFrame to tensors
# Note we are using 3 data sets train, validate, test

x_train = tf.constant(np.array(df_train_pandas['features'].values.tolist()))
y_train = tf.constant(np.array(df_train_pandas['outcome'].values.tolist()))

x_validate = tf.constant(np.array(df_validate_pandas['features'].values.tolist()))
y_validate = tf.constant(np.array(df_validate_pandas['outcome'].values.tolist()))


x_test = tf.constant(np.array(df_test_pandas['features'].values.tolist()))
y_test = tf.constant(np.array(df_test_pandas['outcome'].values.tolist()))

# %% [markdown]
# #### Shallow NN

# %%
import datetime
model = keras.Sequential( [keras.layers.Dense(30,activation='relu'),
                           keras.layers.Dense(1)] )
model.compile(optimizer = 'sgd',
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])

model.fit(x_train,y_train, epochs = 10,validation_data=(x_validate,y_validate),verbose = 2)
# Out:
# Epoch 1/10
# 44/44 - 1s - loss: 0.8717 - auc: 0.7351 - binary_accuracy: 0.5057 - val_loss: 0.6212 - val_auc: 0.8857 - val_binary_accuracy: 0.7785 - 1s/epoch - 33ms/step
# Epoch 2/10
# 44/44 - 0s - loss: 0.4807 - auc: 0.9146 - binary_accuracy: 0.7371 - val_loss: 0.5415 - val_auc: 0.9093 - val_binary_accuracy: 0.7427 - 361ms/epoch - 8ms/step
# Epoch 3/10
# 44/44 - 0s - loss: 0.4105 - auc: 0.9310 - binary_accuracy: 0.8193 - val_loss: 0.4855 - val_auc: 0.9169 - val_binary_accuracy: 0.8078 - 363ms/epoch - 8ms/step
# Epoch 4/10
# 44/44 - 0s - loss: 0.3647 - auc: 0.9370 - binary_accuracy: 0.8429 - val_loss: 0.4447 - val_auc: 0.9212 - val_binary_accuracy: 0.8274 - 363ms/epoch - 8ms/step
# Epoch 5/10
# 44/44 - 0s - loss: 0.3302 - auc: 0.9536 - binary_accuracy: 0.8471 - val_loss: 0.4258 - val_auc: 0.9233 - val_binary_accuracy: 0.8241 - 362ms/epoch - 8ms/step
# Epoch 6/10
# 44/44 - 0s - loss: 0.3072 - auc: 0.9532 - binary_accuracy: 0.8521 - val_loss: 0.4008 - val_auc: 0.9238 - val_binary_accuracy: 0.8339 - 393ms/epoch - 9ms/step
# Epoch 7/10
# 44/44 - 0s - loss: 0.2905 - auc: 0.9540 - binary_accuracy: 0.8593 - val_loss: 0.3834 - val_auc: 0.9240 - val_binary_accuracy: 0.8404 - 391ms/epoch - 9ms/step
# Epoch 8/10
# 44/44 - 0s - loss: 0.2786 - auc: 0.9525 - binary_accuracy: 0.8607 - val_loss: 0.3727 - val_auc: 0.9250 - val_binary_accuracy: 0.8404 - 430ms/epoch - 10ms/step
# Epoch 9/10
# 44/44 - 0s - loss: 0.2688 - auc: 0.9537 - binary_accuracy: 0.8607 - val_loss: 0.3722 - val_auc: 0.9269 - val_binary_accuracy: 0.8404 - 420ms/epoch - 10ms/step
# Epoch 10/10
# 44/44 - 0s - loss: 0.2615 - auc: 0.9555 - binary_accuracy: 0.8629 - val_loss: 0.3630 - val_auc: 0.9280 - val_binary_accuracy: 0.8404 - 392ms/epoch - 9ms/step

# %% [markdown]
# #### Shuffling

# %%
import tensorflow as tf
from tensorflow import keras 
train = tf.concat([x_train,tf.reshape(y_train,[-1,1])],1)
train_shuffle = tf.random.shuffle(train)
x_train_shuffle = train_shuffle[:,0:tf.shape(x_train)[1]]
y_train_shuffle = train_shuffle[:,tf.shape(x_train)[1]]

# %% [markdown]
# #### Hyperparameters

# %%
from tensorboard.plugins.hparams import api as hp

HP_WIDTH = hp.HParam('NN_width', hp.Discrete([20,30,40]))
HP_DEPTH = hp.HParam('NN_depth', hp.Discrete([1,2]))


with tf.summary.create_file_writer('logs1483/hparams_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_WIDTH, HP_DEPTH],
    metrics=[hp.Metric('Accuracy')],
  )

# %% [markdown]
# #### Cross Validation

# %%
def CV_Binary_model(hparams,logdir, k, current_best, d, w):
    indiceslist = []
    
    for i in range(k-1):
        indices = tf.range(i * ((tf.shape(x_train_shuffle)[0])//k), (i + 1)* ((tf.shape(x_train_shuffle)[0])//k),1).numpy().tolist()
        indiceslist.append([indices])
        
    accuracy = 0
    # combining whatever remaining after k-1 splits (to account if length of dataset is not divisible by k)
    
    indices = tf.range((k-1) * ((tf.shape(x_train_shuffle)[0])//k), (tf.shape(x_train_shuffle)[0]),1).numpy().tolist()
    
    indiceslist.append([indices]) ## indiceslist to divide train and validate
    
    for i in range(k):
        print("\nSplit no",i+1)
        model = keras.Sequential()
        for _ in range(hparams[HP_DEPTH]):
            model.add(keras.layers.Dense(hparams[HP_WIDTH],activation='relu'))
        model.add(keras.layers.Dense(1))
        model.compile(optimizer = 'sgd',
        loss=keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])
        
        b = indiceslist[i][0] 
        a = [int(item) for item in b]

        x_validate = tf.gather(x_train_shuffle,a)

        y_validate = tf.gather(y_train_shuffle,a)
        
        z = []
        
        for j in range(k):
            
            if j != i:                     ## Make sure validation and train set are different
                z =  z + indiceslist[j][0]
                
        a = [int(item) for item in z]
        
        x_train = tf.gather(x_train_shuffle, a)
        y_train = tf.gather(y_train_shuffle, a)
        
        print("\nTraining")
        
        history = model.fit(x_train, y_train, epochs= 10,validation_data = (x_validate,y_validate), verbose = 2)
        if np.max(history.history["val_binary_accuracy"]) > current_best:
                  current_best = np.max(history.history["val_binary_accuracy"])
                  d = hparams[HP_DEPTH]
                  w = hparams[HP_WIDTH]
        accuracy = accuracy + np.max(history.history["val_binary_accuracy"])
    
    return accuracy/k, d, w, current_best

# %% [markdown]
# #### Tuning

# %%
k =3 
current_best = 0
d,w = 0,0
for hp_width in HP_WIDTH.domain.values:
  for hp_depth in (HP_DEPTH.domain.values):
    hparams = {
        HP_WIDTH: hp_width,
        HP_DEPTH: hp_depth,
    }
    run_name = f"run-WIDTH{int(hparams[HP_WIDTH])}-DEPTH{hparams[HP_DEPTH]}"
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})

    run_dir = 'logs1483/hparams_tuning/' + run_name
    accuracy, d, w, current_best = CV_Binary_model(hparams,run_dir, k, current_best, d, w)

    with tf.summary.create_file_writer(run_dir).as_default():
      hp.hparams(hparams)  # record the values used in this trial
      tf.summary.scalar("Accuracy", accuracy, step=1)
# Out:
# --- Starting trial: run-WIDTH20-DEPTH1
# {'NN_width': 20, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7125 - auc_2: 0.7373 - binary_accuracy: 0.5000 - val_loss: 0.6784 - val_auc_2: 0.8002 - val_binary_accuracy: 0.7082 - 1s/epoch - 43ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5523 - auc_2: 0.8593 - binary_accuracy: 0.6167 - val_loss: 0.6024 - val_auc_2: 0.8666 - val_binary_accuracy: 0.5601 - 352ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4848 - auc_2: 0.9229 - binary_accuracy: 0.7088 - val_loss: 0.5502 - val_auc_2: 0.8861 - val_binary_accuracy: 0.7704 - 323ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4370 - auc_2: 0.9314 - binary_accuracy: 0.8116 - val_loss: 0.5111 - val_auc_2: 0.8917 - val_binary_accuracy: 0.7747 - 311ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4009 - auc_2: 0.9323 - binary_accuracy: 0.8266 - val_loss: 0.4825 - val_auc_2: 0.8944 - val_binary_accuracy: 0.7897 - 290ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3656 - auc_2: 0.9505 - binary_accuracy: 0.8469 - val_loss: 0.5116 - val_auc_2: 0.8987 - val_binary_accuracy: 0.6824 - 283ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3465 - auc_2: 0.9441 - binary_accuracy: 0.8490 - val_loss: 0.4567 - val_auc_2: 0.9033 - val_binary_accuracy: 0.7918 - 272ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3273 - auc_2: 0.9498 - binary_accuracy: 0.8480 - val_loss: 0.4216 - val_auc_2: 0.9061 - val_binary_accuracy: 0.8004 - 274ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3116 - auc_2: 0.9511 - binary_accuracy: 0.8587 - val_loss: 0.4117 - val_auc_2: 0.9063 - val_binary_accuracy: 0.7961 - 273ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2979 - auc_2: 0.9515 - binary_accuracy: 0.8597 - val_loss: 0.4055 - val_auc_2: 0.9072 - val_binary_accuracy: 0.7961 - 269ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7674 - auc_3: 0.7486 - binary_accuracy: 0.4957 - val_loss: 0.7654 - val_auc_3: 0.7647 - val_binary_accuracy: 0.6459 - 1s/epoch - 36ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5257 - auc_3: 0.8733 - binary_accuracy: 0.6242 - val_loss: 0.7042 - val_auc_3: 0.8107 - val_binary_accuracy: 0.7039 - 359ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4584 - auc_3: 0.9195 - binary_accuracy: 0.7730 - val_loss: 0.6685 - val_auc_3: 0.8470 - val_binary_accuracy: 0.6266 - 343ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4139 - auc_3: 0.9402 - binary_accuracy: 0.8148 - val_loss: 0.6418 - val_auc_3: 0.8498 - val_binary_accuracy: 0.7532 - 354ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3786 - auc_3: 0.9470 - binary_accuracy: 0.8308 - val_loss: 0.6060 - val_auc_3: 0.8504 - val_binary_accuracy: 0.7876 - 304ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3530 - auc_3: 0.9446 - binary_accuracy: 0.8415 - val_loss: 0.5883 - val_auc_3: 0.8566 - val_binary_accuracy: 0.7876 - 281ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3311 - auc_3: 0.9506 - binary_accuracy: 0.8469 - val_loss: 0.5710 - val_auc_3: 0.8597 - val_binary_accuracy: 0.7876 - 274ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3137 - auc_3: 0.9474 - binary_accuracy: 0.8437 - val_loss: 0.5597 - val_auc_3: 0.8606 - val_binary_accuracy: 0.7918 - 332ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3011 - auc_3: 0.9520 - binary_accuracy: 0.8480 - val_loss: 0.5546 - val_auc_3: 0.8682 - val_binary_accuracy: 0.7897 - 283ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2892 - auc_3: 0.9537 - binary_accuracy: 0.8522 - val_loss: 0.5399 - val_auc_3: 0.8702 - val_binary_accuracy: 0.7918 - 311ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7896 - auc_4: 0.7360 - binary_accuracy: 0.4914 - val_loss: 0.7579 - val_auc_4: 0.7872 - val_binary_accuracy: 0.6923 - 982ms/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5032 - auc_4: 0.9010 - binary_accuracy: 0.6985 - val_loss: 0.7179 - val_auc_4: 0.8292 - val_binary_accuracy: 0.5299 - 273ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4419 - auc_4: 0.9228 - binary_accuracy: 0.7543 - val_loss: 0.6456 - val_auc_4: 0.8429 - val_binary_accuracy: 0.7671 - 286ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.3969 - auc_4: 0.9433 - binary_accuracy: 0.8369 - val_loss: 0.6183 - val_auc_4: 0.8486 - val_binary_accuracy: 0.7479 - 285ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3648 - auc_4: 0.9418 - binary_accuracy: 0.8433 - val_loss: 0.5917 - val_auc_4: 0.8527 - val_binary_accuracy: 0.7756 - 272ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3402 - auc_4: 0.9442 - binary_accuracy: 0.8541 - val_loss: 0.5993 - val_auc_4: 0.8539 - val_binary_accuracy: 0.7692 - 282ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3242 - auc_4: 0.9469 - binary_accuracy: 0.8509 - val_loss: 0.5988 - val_auc_4: 0.8656 - val_binary_accuracy: 0.7628 - 335ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3058 - auc_4: 0.9506 - binary_accuracy: 0.8562 - val_loss: 0.5488 - val_auc_4: 0.8693 - val_binary_accuracy: 0.7821 - 287ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2910 - auc_4: 0.9551 - binary_accuracy: 0.8594 - val_loss: 0.5393 - val_auc_4: 0.8729 - val_binary_accuracy: 0.7863 - 278ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2836 - auc_4: 0.9495 - binary_accuracy: 0.8594 - val_loss: 0.5346 - val_auc_4: 0.8749 - val_binary_accuracy: 0.7970 - 277ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH20-DEPTH2
# {'NN_width': 20, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6906 - auc_5: 0.7346 - binary_accuracy: 0.5043 - val_loss: 0.6580 - val_auc_5: 0.8199 - val_binary_accuracy: 0.5815 - 1s/epoch - 35ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5629 - auc_5: 0.9037 - binary_accuracy: 0.6638 - val_loss: 0.6221 - val_auc_5: 0.8477 - val_binary_accuracy: 0.7747 - 372ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4863 - auc_5: 0.9230 - binary_accuracy: 0.8116 - val_loss: 0.5689 - val_auc_5: 0.8715 - val_binary_accuracy: 0.6352 - 290ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4328 - auc_5: 0.9331 - binary_accuracy: 0.8094 - val_loss: 0.5028 - val_auc_5: 0.8827 - val_binary_accuracy: 0.7833 - 293ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3830 - auc_5: 0.9452 - binary_accuracy: 0.8415 - val_loss: 0.4868 - val_auc_5: 0.8882 - val_binary_accuracy: 0.7811 - 298ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3502 - auc_5: 0.9436 - binary_accuracy: 0.8480 - val_loss: 0.4719 - val_auc_5: 0.8930 - val_binary_accuracy: 0.7876 - 350ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3231 - auc_5: 0.9497 - binary_accuracy: 0.8544 - val_loss: 0.4487 - val_auc_5: 0.8957 - val_binary_accuracy: 0.7897 - 281ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3022 - auc_5: 0.9496 - binary_accuracy: 0.8576 - val_loss: 0.4275 - val_auc_5: 0.8963 - val_binary_accuracy: 0.8004 - 278ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2856 - auc_5: 0.9508 - binary_accuracy: 0.8619 - val_loss: 0.4376 - val_auc_5: 0.8971 - val_binary_accuracy: 0.7918 - 285ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2763 - auc_5: 0.9519 - binary_accuracy: 0.8640 - val_loss: 0.4373 - val_auc_5: 0.9004 - val_binary_accuracy: 0.7961 - 346ms/epoch - 12ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6767 - auc_6: 0.7644 - binary_accuracy: 0.5054 - val_loss: 0.6454 - val_auc_6: 0.7892 - val_binary_accuracy: 0.5086 - 2s/epoch - 74ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5909 - auc_6: 0.8868 - binary_accuracy: 0.5310 - val_loss: 0.5976 - val_auc_6: 0.8192 - val_binary_accuracy: 0.5386 - 261ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5381 - auc_6: 0.9103 - binary_accuracy: 0.6285 - val_loss: 0.5603 - val_auc_6: 0.8576 - val_binary_accuracy: 0.7339 - 264ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4883 - auc_6: 0.9300 - binary_accuracy: 0.7452 - val_loss: 0.5506 - val_auc_6: 0.8538 - val_binary_accuracy: 0.7275 - 258ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4423 - auc_6: 0.9317 - binary_accuracy: 0.8116 - val_loss: 0.4871 - val_auc_6: 0.8845 - val_binary_accuracy: 0.7854 - 262ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3957 - auc_6: 0.9454 - binary_accuracy: 0.8383 - val_loss: 0.4659 - val_auc_6: 0.8875 - val_binary_accuracy: 0.7446 - 286ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3634 - auc_6: 0.9410 - binary_accuracy: 0.8276 - val_loss: 0.4269 - val_auc_6: 0.9000 - val_binary_accuracy: 0.8112 - 255ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3312 - auc_6: 0.9520 - binary_accuracy: 0.8426 - val_loss: 0.4035 - val_auc_6: 0.9102 - val_binary_accuracy: 0.8133 - 253ms/epoch - 8ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3075 - auc_6: 0.9518 - binary_accuracy: 0.8490 - val_loss: 0.3899 - val_auc_6: 0.9094 - val_binary_accuracy: 0.8262 - 251ms/epoch - 8ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2905 - auc_6: 0.9534 - binary_accuracy: 0.8587 - val_loss: 0.3730 - val_auc_6: 0.9174 - val_binary_accuracy: 0.8219 - 264ms/epoch - 9ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6555 - auc_7: 0.7613 - binary_accuracy: 0.4979 - val_loss: 0.6684 - val_auc_7: 0.7871 - val_binary_accuracy: 0.5598 - 947ms/epoch - 32ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6031 - auc_7: 0.8939 - binary_accuracy: 0.6084 - val_loss: 0.6385 - val_auc_7: 0.8486 - val_binary_accuracy: 0.5406 - 274ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5656 - auc_7: 0.9263 - binary_accuracy: 0.7307 - val_loss: 0.5967 - val_auc_7: 0.8746 - val_binary_accuracy: 0.7436 - 261ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.5245 - auc_7: 0.9401 - binary_accuracy: 0.8090 - val_loss: 0.5827 - val_auc_7: 0.8791 - val_binary_accuracy: 0.7607 - 252ms/epoch - 8ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4821 - auc_7: 0.9424 - binary_accuracy: 0.8337 - val_loss: 0.5310 - val_auc_7: 0.8864 - val_binary_accuracy: 0.7906 - 249ms/epoch - 8ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.4371 - auc_7: 0.9518 - binary_accuracy: 0.8433 - val_loss: 0.4999 - val_auc_7: 0.8938 - val_binary_accuracy: 0.7970 - 275ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3946 - auc_7: 0.9432 - binary_accuracy: 0.8476 - val_loss: 0.4979 - val_auc_7: 0.8955 - val_binary_accuracy: 0.7821 - 261ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3587 - auc_7: 0.9488 - binary_accuracy: 0.8401 - val_loss: 0.4396 - val_auc_7: 0.9063 - val_binary_accuracy: 0.8013 - 254ms/epoch - 8ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3296 - auc_7: 0.9497 - binary_accuracy: 0.8466 - val_loss: 0.4616 - val_auc_7: 0.8997 - val_binary_accuracy: 0.7863 - 264ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3047 - auc_7: 0.9537 - binary_accuracy: 0.8541 - val_loss: 0.4077 - val_auc_7: 0.9075 - val_binary_accuracy: 0.7991 - 277ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH30-DEPTH1
# {'NN_width': 30, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.8157 - auc_8: 0.7040 - binary_accuracy: 0.4979 - val_loss: 0.6639 - val_auc_8: 0.8530 - val_binary_accuracy: 0.5086 - 1s/epoch - 39ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5391 - auc_8: 0.9148 - binary_accuracy: 0.6060 - val_loss: 0.6159 - val_auc_8: 0.8694 - val_binary_accuracy: 0.7704 - 339ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4844 - auc_8: 0.9254 - binary_accuracy: 0.7409 - val_loss: 0.5682 - val_auc_8: 0.8869 - val_binary_accuracy: 0.7833 - 297ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4381 - auc_8: 0.9397 - binary_accuracy: 0.8169 - val_loss: 0.5306 - val_auc_8: 0.8905 - val_binary_accuracy: 0.7854 - 310ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4052 - auc_8: 0.9417 - binary_accuracy: 0.8362 - val_loss: 0.5038 - val_auc_8: 0.8935 - val_binary_accuracy: 0.7854 - 300ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3747 - auc_8: 0.9450 - binary_accuracy: 0.8480 - val_loss: 0.4857 - val_auc_8: 0.9000 - val_binary_accuracy: 0.7918 - 308ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3535 - auc_8: 0.9444 - binary_accuracy: 0.8512 - val_loss: 0.4606 - val_auc_8: 0.9007 - val_binary_accuracy: 0.7940 - 297ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3346 - auc_8: 0.9457 - binary_accuracy: 0.8555 - val_loss: 0.4600 - val_auc_8: 0.9046 - val_binary_accuracy: 0.7940 - 291ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3187 - auc_8: 0.9492 - binary_accuracy: 0.8587 - val_loss: 0.4701 - val_auc_8: 0.9068 - val_binary_accuracy: 0.7940 - 283ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3071 - auc_8: 0.9505 - binary_accuracy: 0.8597 - val_loss: 0.4234 - val_auc_8: 0.9064 - val_binary_accuracy: 0.8004 - 261ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6957 - auc_9: 0.7515 - binary_accuracy: 0.5054 - val_loss: 0.6572 - val_auc_9: 0.8457 - val_binary_accuracy: 0.5021 - 950ms/epoch - 32ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5344 - auc_9: 0.9000 - binary_accuracy: 0.6113 - val_loss: 0.5918 - val_auc_9: 0.8608 - val_binary_accuracy: 0.5451 - 265ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4692 - auc_9: 0.9263 - binary_accuracy: 0.7409 - val_loss: 0.5406 - val_auc_9: 0.8772 - val_binary_accuracy: 0.7554 - 336ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4171 - auc_9: 0.9382 - binary_accuracy: 0.8255 - val_loss: 0.5260 - val_auc_9: 0.8732 - val_binary_accuracy: 0.7489 - 283ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3833 - auc_9: 0.9410 - binary_accuracy: 0.8383 - val_loss: 0.4855 - val_auc_9: 0.8880 - val_binary_accuracy: 0.8069 - 273ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3559 - auc_9: 0.9422 - binary_accuracy: 0.8405 - val_loss: 0.4697 - val_auc_9: 0.8889 - val_binary_accuracy: 0.8047 - 266ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3303 - auc_9: 0.9528 - binary_accuracy: 0.8469 - val_loss: 0.4431 - val_auc_9: 0.8948 - val_binary_accuracy: 0.8047 - 266ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3137 - auc_9: 0.9537 - binary_accuracy: 0.8415 - val_loss: 0.4317 - val_auc_9: 0.9021 - val_binary_accuracy: 0.8069 - 259ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2983 - auc_9: 0.9560 - binary_accuracy: 0.8480 - val_loss: 0.4348 - val_auc_9: 0.9007 - val_binary_accuracy: 0.7661 - 265ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2887 - auc_9: 0.9537 - binary_accuracy: 0.8544 - val_loss: 0.4103 - val_auc_9: 0.9033 - val_binary_accuracy: 0.8112 - 267ms/epoch - 9ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.7771 - auc_10: 0.7392 - binary_accuracy: 0.4882 - val_loss: 0.6844 - val_auc_10: 0.8455 - val_binary_accuracy: 0.5128 - 2s/epoch - 60ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5398 - auc_10: 0.9014 - binary_accuracy: 0.5751 - val_loss: 0.6334 - val_auc_10: 0.8425 - val_binary_accuracy: 0.6175 - 271ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4812 - auc_10: 0.9184 - binary_accuracy: 0.7382 - val_loss: 0.6657 - val_auc_10: 0.8679 - val_binary_accuracy: 0.5150 - 309ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4409 - auc_10: 0.9279 - binary_accuracy: 0.7564 - val_loss: 0.5952 - val_auc_10: 0.8693 - val_binary_accuracy: 0.7607 - 270ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4043 - auc_10: 0.9382 - binary_accuracy: 0.8283 - val_loss: 0.5466 - val_auc_10: 0.8724 - val_binary_accuracy: 0.7842 - 269ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3758 - auc_10: 0.9465 - binary_accuracy: 0.8412 - val_loss: 0.5708 - val_auc_10: 0.8767 - val_binary_accuracy: 0.6346 - 275ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3552 - auc_10: 0.9457 - binary_accuracy: 0.8401 - val_loss: 0.5098 - val_auc_10: 0.8757 - val_binary_accuracy: 0.7885 - 276ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3341 - auc_10: 0.9456 - binary_accuracy: 0.8530 - val_loss: 0.4983 - val_auc_10: 0.8814 - val_binary_accuracy: 0.7842 - 272ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3162 - auc_10: 0.9533 - binary_accuracy: 0.8573 - val_loss: 0.4881 - val_auc_10: 0.8817 - val_binary_accuracy: 0.7842 - 274ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3067 - auc_10: 0.9440 - binary_accuracy: 0.8584 - val_loss: 0.4842 - val_auc_10: 0.8817 - val_binary_accuracy: 0.7842 - 267ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH30-DEPTH2
# {'NN_width': 30, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.9436 - auc_11: 0.7243 - binary_accuracy: 0.4861 - val_loss: 0.8015 - val_auc_11: 0.8278 - val_binary_accuracy: 0.4764 - 906ms/epoch - 30ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5691 - auc_11: 0.8749 - binary_accuracy: 0.5728 - val_loss: 0.6577 - val_auc_11: 0.8490 - val_binary_accuracy: 0.7103 - 284ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4643 - auc_11: 0.9248 - binary_accuracy: 0.7452 - val_loss: 0.6468 - val_auc_11: 0.8586 - val_binary_accuracy: 0.5644 - 388ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4042 - auc_11: 0.9383 - binary_accuracy: 0.8201 - val_loss: 0.5593 - val_auc_11: 0.8689 - val_binary_accuracy: 0.7747 - 304ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3599 - auc_11: 0.9429 - binary_accuracy: 0.8469 - val_loss: 0.5384 - val_auc_11: 0.8751 - val_binary_accuracy: 0.7811 - 276ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3244 - auc_11: 0.9529 - binary_accuracy: 0.8565 - val_loss: 0.5064 - val_auc_11: 0.8820 - val_binary_accuracy: 0.7918 - 289ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3065 - auc_11: 0.9489 - binary_accuracy: 0.8576 - val_loss: 0.5116 - val_auc_11: 0.8851 - val_binary_accuracy: 0.7854 - 269ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.2873 - auc_11: 0.9514 - binary_accuracy: 0.8619 - val_loss: 0.5063 - val_auc_11: 0.8884 - val_binary_accuracy: 0.7876 - 265ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2756 - auc_11: 0.9487 - binary_accuracy: 0.8640 - val_loss: 0.4887 - val_auc_11: 0.8900 - val_binary_accuracy: 0.7897 - 283ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2630 - auc_11: 0.9498 - binary_accuracy: 0.8640 - val_loss: 0.5030 - val_auc_11: 0.8902 - val_binary_accuracy: 0.7918 - 251ms/epoch - 8ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6812 - auc_12: 0.7547 - binary_accuracy: 0.4979 - val_loss: 0.6401 - val_auc_12: 0.8307 - val_binary_accuracy: 0.5172 - 942ms/epoch - 31ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5717 - auc_12: 0.8864 - binary_accuracy: 0.5385 - val_loss: 0.6213 - val_auc_12: 0.8265 - val_binary_accuracy: 0.7060 - 279ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5097 - auc_12: 0.9105 - binary_accuracy: 0.7131 - val_loss: 0.5883 - val_auc_12: 0.8629 - val_binary_accuracy: 0.7403 - 277ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4537 - auc_12: 0.9234 - binary_accuracy: 0.8019 - val_loss: 0.5176 - val_auc_12: 0.8928 - val_binary_accuracy: 0.8069 - 280ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4016 - auc_12: 0.9444 - binary_accuracy: 0.8415 - val_loss: 0.5004 - val_auc_12: 0.8933 - val_binary_accuracy: 0.7575 - 272ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3593 - auc_12: 0.9436 - binary_accuracy: 0.8458 - val_loss: 0.4584 - val_auc_12: 0.8954 - val_binary_accuracy: 0.8090 - 277ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3282 - auc_12: 0.9484 - binary_accuracy: 0.8458 - val_loss: 0.4431 - val_auc_12: 0.9038 - val_binary_accuracy: 0.8219 - 275ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3116 - auc_12: 0.9446 - binary_accuracy: 0.8405 - val_loss: 0.4393 - val_auc_12: 0.9076 - val_binary_accuracy: 0.8176 - 275ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2912 - auc_12: 0.9503 - binary_accuracy: 0.8501 - val_loss: 0.4458 - val_auc_12: 0.9078 - val_binary_accuracy: 0.8176 - 286ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2820 - auc_12: 0.9433 - binary_accuracy: 0.8522 - val_loss: 0.5301 - val_auc_12: 0.9078 - val_binary_accuracy: 0.7103 - 264ms/epoch - 9ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7079 - auc_13: 0.7233 - binary_accuracy: 0.4914 - val_loss: 0.6770 - val_auc_13: 0.7888 - val_binary_accuracy: 0.5021 - 867ms/epoch - 29ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5956 - auc_13: 0.8792 - binary_accuracy: 0.5311 - val_loss: 0.6530 - val_auc_13: 0.8255 - val_binary_accuracy: 0.5214 - 303ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5395 - auc_13: 0.9139 - binary_accuracy: 0.5815 - val_loss: 0.5984 - val_auc_13: 0.8554 - val_binary_accuracy: 0.5491 - 307ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4845 - auc_13: 0.9292 - binary_accuracy: 0.7361 - val_loss: 0.5700 - val_auc_13: 0.8725 - val_binary_accuracy: 0.6303 - 314ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4383 - auc_13: 0.9366 - binary_accuracy: 0.7833 - val_loss: 0.5274 - val_auc_13: 0.8760 - val_binary_accuracy: 0.7778 - 293ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3948 - auc_13: 0.9426 - binary_accuracy: 0.8315 - val_loss: 0.5023 - val_auc_13: 0.8812 - val_binary_accuracy: 0.7927 - 317ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3612 - auc_13: 0.9476 - binary_accuracy: 0.8412 - val_loss: 0.4775 - val_auc_13: 0.8805 - val_binary_accuracy: 0.7906 - 307ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3337 - auc_13: 0.9479 - binary_accuracy: 0.8476 - val_loss: 0.4600 - val_auc_13: 0.8846 - val_binary_accuracy: 0.7927 - 307ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3112 - auc_13: 0.9448 - binary_accuracy: 0.8562 - val_loss: 0.4423 - val_auc_13: 0.8889 - val_binary_accuracy: 0.7906 - 309ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2934 - auc_13: 0.9482 - binary_accuracy: 0.8584 - val_loss: 0.4396 - val_auc_13: 0.8893 - val_binary_accuracy: 0.7735 - 299ms/epoch - 10ms/step
# --- Starting trial: run-WIDTH40-DEPTH1
# {'NN_width': 40, 'NN_depth': 1}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6454 - auc_14: 0.7575 - binary_accuracy: 0.5161 - val_loss: 0.6333 - val_auc_14: 0.8316 - val_binary_accuracy: 0.4914 - 2s/epoch - 71ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5285 - auc_14: 0.8976 - binary_accuracy: 0.6188 - val_loss: 0.5483 - val_auc_14: 0.8571 - val_binary_accuracy: 0.5966 - 308ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4680 - auc_14: 0.9182 - binary_accuracy: 0.7334 - val_loss: 0.5108 - val_auc_14: 0.8910 - val_binary_accuracy: 0.7704 - 297ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4226 - auc_14: 0.9330 - binary_accuracy: 0.8148 - val_loss: 0.4634 - val_auc_14: 0.8983 - val_binary_accuracy: 0.7876 - 304ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3858 - auc_14: 0.9446 - binary_accuracy: 0.8340 - val_loss: 0.4411 - val_auc_14: 0.9047 - val_binary_accuracy: 0.7811 - 302ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3613 - auc_14: 0.9420 - binary_accuracy: 0.8533 - val_loss: 0.4124 - val_auc_14: 0.9104 - val_binary_accuracy: 0.7961 - 307ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3396 - auc_14: 0.9430 - binary_accuracy: 0.8522 - val_loss: 0.4088 - val_auc_14: 0.9170 - val_binary_accuracy: 0.7983 - 336ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3230 - auc_14: 0.9465 - binary_accuracy: 0.8555 - val_loss: 0.3808 - val_auc_14: 0.9192 - val_binary_accuracy: 0.8026 - 322ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3068 - auc_14: 0.9498 - binary_accuracy: 0.8533 - val_loss: 0.3680 - val_auc_14: 0.9222 - val_binary_accuracy: 0.8026 - 309ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2974 - auc_14: 0.9465 - binary_accuracy: 0.8597 - val_loss: 0.3607 - val_auc_14: 0.9228 - val_binary_accuracy: 0.8155 - 334ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7026 - auc_15: 0.7711 - binary_accuracy: 0.5161 - val_loss: 0.5925 - val_auc_15: 0.8600 - val_binary_accuracy: 0.5150 - 984ms/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.4939 - auc_15: 0.9072 - binary_accuracy: 0.7259 - val_loss: 0.5301 - val_auc_15: 0.8808 - val_binary_accuracy: 0.8004 - 310ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4260 - auc_15: 0.9394 - binary_accuracy: 0.8287 - val_loss: 0.4851 - val_auc_15: 0.8934 - val_binary_accuracy: 0.8090 - 305ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.3820 - auc_15: 0.9443 - binary_accuracy: 0.8319 - val_loss: 0.4507 - val_auc_15: 0.8942 - val_binary_accuracy: 0.8155 - 317ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3535 - auc_15: 0.9448 - binary_accuracy: 0.8351 - val_loss: 0.4349 - val_auc_15: 0.8961 - val_binary_accuracy: 0.8133 - 305ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3281 - auc_15: 0.9446 - binary_accuracy: 0.8437 - val_loss: 0.4134 - val_auc_15: 0.8965 - val_binary_accuracy: 0.8176 - 312ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3071 - auc_15: 0.9527 - binary_accuracy: 0.8490 - val_loss: 0.3950 - val_auc_15: 0.9064 - val_binary_accuracy: 0.8176 - 313ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.2933 - auc_15: 0.9565 - binary_accuracy: 0.8490 - val_loss: 0.3939 - val_auc_15: 0.9085 - val_binary_accuracy: 0.8283 - 314ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2860 - auc_15: 0.9523 - binary_accuracy: 0.8469 - val_loss: 0.3835 - val_auc_15: 0.9139 - val_binary_accuracy: 0.8197 - 408ms/epoch - 14ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2753 - auc_15: 0.9549 - binary_accuracy: 0.8576 - val_loss: 0.3694 - val_auc_15: 0.9144 - val_binary_accuracy: 0.8197 - 358ms/epoch - 12ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7693 - auc_16: 0.7359 - binary_accuracy: 0.4925 - val_loss: 0.7148 - val_auc_16: 0.8019 - val_binary_accuracy: 0.7009 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5138 - auc_16: 0.9227 - binary_accuracy: 0.6921 - val_loss: 0.6747 - val_auc_16: 0.8408 - val_binary_accuracy: 0.5342 - 309ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.4553 - auc_16: 0.9304 - binary_accuracy: 0.7833 - val_loss: 0.6144 - val_auc_16: 0.8584 - val_binary_accuracy: 0.7073 - 320ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4089 - auc_16: 0.9387 - binary_accuracy: 0.8294 - val_loss: 0.6183 - val_auc_16: 0.8589 - val_binary_accuracy: 0.6004 - 372ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.3758 - auc_16: 0.9453 - binary_accuracy: 0.8326 - val_loss: 0.5565 - val_auc_16: 0.8704 - val_binary_accuracy: 0.7863 - 313ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3493 - auc_16: 0.9494 - binary_accuracy: 0.8444 - val_loss: 0.5395 - val_auc_16: 0.8707 - val_binary_accuracy: 0.7564 - 363ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3277 - auc_16: 0.9518 - binary_accuracy: 0.8509 - val_loss: 0.5298 - val_auc_16: 0.8708 - val_binary_accuracy: 0.7842 - 336ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3107 - auc_16: 0.9527 - binary_accuracy: 0.8552 - val_loss: 0.5084 - val_auc_16: 0.8774 - val_binary_accuracy: 0.7885 - 330ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2977 - auc_16: 0.9504 - binary_accuracy: 0.8573 - val_loss: 0.5042 - val_auc_16: 0.8789 - val_binary_accuracy: 0.7885 - 319ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2896 - auc_16: 0.9481 - binary_accuracy: 0.8584 - val_loss: 0.4899 - val_auc_16: 0.8799 - val_binary_accuracy: 0.7885 - 318ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH40-DEPTH2
# {'NN_width': 40, 'NN_depth': 2}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6969 - auc_17: 0.7642 - binary_accuracy: 0.5043 - val_loss: 0.6390 - val_auc_17: 0.8046 - val_binary_accuracy: 0.4893 - 1s/epoch - 41ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5663 - auc_17: 0.8891 - binary_accuracy: 0.5385 - val_loss: 0.5868 - val_auc_17: 0.8684 - val_binary_accuracy: 0.5150 - 298ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5077 - auc_17: 0.9188 - binary_accuracy: 0.6467 - val_loss: 0.5476 - val_auc_17: 0.8726 - val_binary_accuracy: 0.7554 - 307ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4562 - auc_17: 0.9300 - binary_accuracy: 0.7762 - val_loss: 0.5019 - val_auc_17: 0.8967 - val_binary_accuracy: 0.7833 - 322ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4114 - auc_17: 0.9398 - binary_accuracy: 0.8169 - val_loss: 0.4685 - val_auc_17: 0.8973 - val_binary_accuracy: 0.7940 - 325ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3757 - auc_17: 0.9382 - binary_accuracy: 0.8448 - val_loss: 0.4449 - val_auc_17: 0.8993 - val_binary_accuracy: 0.7918 - 374ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3440 - auc_17: 0.9470 - binary_accuracy: 0.8480 - val_loss: 0.4178 - val_auc_17: 0.9024 - val_binary_accuracy: 0.8004 - 350ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3189 - auc_17: 0.9504 - binary_accuracy: 0.8565 - val_loss: 0.4737 - val_auc_17: 0.9043 - val_binary_accuracy: 0.7747 - 331ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3054 - auc_17: 0.9478 - binary_accuracy: 0.8597 - val_loss: 0.3897 - val_auc_17: 0.9081 - val_binary_accuracy: 0.8047 - 324ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2875 - auc_17: 0.9477 - binary_accuracy: 0.8565 - val_loss: 0.3975 - val_auc_17: 0.9070 - val_binary_accuracy: 0.7961 - 320ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.7460 - auc_18: 0.7689 - binary_accuracy: 0.4904 - val_loss: 0.7288 - val_auc_18: 0.8119 - val_binary_accuracy: 0.4871 - 2s/epoch - 71ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5919 - auc_18: 0.8938 - binary_accuracy: 0.5278 - val_loss: 0.6907 - val_auc_18: 0.8220 - val_binary_accuracy: 0.5172 - 353ms/epoch - 12ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5292 - auc_18: 0.9086 - binary_accuracy: 0.6317 - val_loss: 0.6613 - val_auc_18: 0.8117 - val_binary_accuracy: 0.7425 - 341ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4763 - auc_18: 0.9273 - binary_accuracy: 0.7719 - val_loss: 0.6283 - val_auc_18: 0.8412 - val_binary_accuracy: 0.7511 - 297ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4265 - auc_18: 0.9404 - binary_accuracy: 0.8244 - val_loss: 0.6014 - val_auc_18: 0.8491 - val_binary_accuracy: 0.7790 - 301ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3827 - auc_18: 0.9467 - binary_accuracy: 0.8426 - val_loss: 0.5780 - val_auc_18: 0.8515 - val_binary_accuracy: 0.7897 - 308ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3469 - auc_18: 0.9471 - binary_accuracy: 0.8458 - val_loss: 0.5682 - val_auc_18: 0.8540 - val_binary_accuracy: 0.7361 - 336ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3198 - auc_18: 0.9468 - binary_accuracy: 0.8458 - val_loss: 0.5830 - val_auc_18: 0.8597 - val_binary_accuracy: 0.7833 - 317ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3014 - auc_18: 0.9524 - binary_accuracy: 0.8480 - val_loss: 0.5476 - val_auc_18: 0.8721 - val_binary_accuracy: 0.7918 - 310ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2853 - auc_18: 0.9515 - binary_accuracy: 0.8501 - val_loss: 0.5358 - val_auc_18: 0.8748 - val_binary_accuracy: 0.7918 - 302ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6950 - auc_19: 0.7597 - binary_accuracy: 0.4968 - val_loss: 0.6671 - val_auc_19: 0.8277 - val_binary_accuracy: 0.5107 - 1s/epoch - 35ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.5689 - auc_19: 0.8991 - binary_accuracy: 0.5343 - val_loss: 0.6042 - val_auc_19: 0.8599 - val_binary_accuracy: 0.5299 - 301ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5035 - auc_19: 0.9191 - binary_accuracy: 0.6813 - val_loss: 0.5776 - val_auc_19: 0.8660 - val_binary_accuracy: 0.7564 - 329ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4481 - auc_19: 0.9345 - binary_accuracy: 0.7940 - val_loss: 0.5257 - val_auc_19: 0.8860 - val_binary_accuracy: 0.7628 - 327ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4063 - auc_19: 0.9366 - binary_accuracy: 0.8133 - val_loss: 0.4877 - val_auc_19: 0.8912 - val_binary_accuracy: 0.7671 - 302ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3667 - auc_19: 0.9459 - binary_accuracy: 0.8412 - val_loss: 0.4694 - val_auc_19: 0.8933 - val_binary_accuracy: 0.7714 - 311ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3330 - auc_19: 0.9518 - binary_accuracy: 0.8530 - val_loss: 0.4474 - val_auc_19: 0.8938 - val_binary_accuracy: 0.7949 - 357ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3117 - auc_19: 0.9505 - binary_accuracy: 0.8509 - val_loss: 0.4391 - val_auc_19: 0.8994 - val_binary_accuracy: 0.7949 - 321ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2900 - auc_19: 0.9526 - binary_accuracy: 0.8584 - val_loss: 0.4004 - val_auc_19: 0.9020 - val_binary_accuracy: 0.7970 - 317ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2732 - auc_19: 0.9564 - binary_accuracy: 0.8552 - val_loss: 0.4186 - val_auc_19: 0.9039 - val_binary_accuracy: 0.7799 - 349ms/epoch - 12ms/step

# %% [markdown]
# #### Best parameters

# %%
print("Tuned Depth for Shallow NN = ",d)
print("Tuned Widhth for Shallow NN = ",w)
# Out:
# Tuned Depth for Shallow NN =  1
# Tuned Widhth for Shallow NN =  40

# %%
model = keras.Sequential( [keras.layers.Dense(40,activation='relu'),
                           keras.layers.Dense(1)] )

model.compile(optimizer = 'sgd',
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])

model.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2)
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 0.6737 - auc_20: 0.7742 - binary_accuracy: 0.5179 - val_loss: 0.6027 - val_auc_20: 0.8494 - val_binary_accuracy: 0.6059 - 1s/epoch - 23ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 0.4977 - auc_20: 0.9239 - binary_accuracy: 0.7157 - val_loss: 0.5292 - val_auc_20: 0.8884 - val_binary_accuracy: 0.7818 - 388ms/epoch - 9ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 0.4302 - auc_20: 0.9417 - binary_accuracy: 0.8343 - val_loss: 0.4846 - val_auc_20: 0.9033 - val_binary_accuracy: 0.7948 - 362ms/epoch - 8ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 0.3821 - auc_20: 0.9437 - binary_accuracy: 0.8364 - val_loss: 0.4313 - val_auc_20: 0.9113 - val_binary_accuracy: 0.8274 - 365ms/epoch - 8ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 0.3448 - auc_20: 0.9489 - binary_accuracy: 0.8479 - val_loss: 0.3993 - val_auc_20: 0.9149 - val_binary_accuracy: 0.8339 - 369ms/epoch - 8ms/step
# Epoch 6/20
# 44/44 - 0s - loss: 0.3194 - auc_20: 0.9499 - binary_accuracy: 0.8500 - val_loss: 0.3764 - val_auc_20: 0.9223 - val_binary_accuracy: 0.8339 - 374ms/epoch - 8ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.2986 - auc_20: 0.9531 - binary_accuracy: 0.8557 - val_loss: 0.3714 - val_auc_20: 0.9297 - val_binary_accuracy: 0.8208 - 366ms/epoch - 8ms/step
# Epoch 8/20
# 44/44 - 0s - loss: 0.2879 - auc_20: 0.9483 - binary_accuracy: 0.8600 - val_loss: 0.3444 - val_auc_20: 0.9301 - val_binary_accuracy: 0.8371 - 362ms/epoch - 8ms/step
# Epoch 9/20
# 44/44 - 0s - loss: 0.2743 - auc_20: 0.9540 - binary_accuracy: 0.8593 - val_loss: 0.3353 - val_auc_20: 0.9305 - val_binary_accuracy: 0.8404 - 367ms/epoch - 8ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.2667 - auc_20: 0.9479 - binary_accuracy: 0.8629 - val_loss: 0.3248 - val_auc_20: 0.9341 - val_binary_accuracy: 0.8339 - 369ms/epoch - 8ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.2589 - auc_20: 0.9527 - binary_accuracy: 0.8629 - val_loss: 0.3220 - val_auc_20: 0.9376 - val_binary_accuracy: 0.8339 - 365ms/epoch - 8ms/step
# Epoch 12/20
# 44/44 - 0s - loss: 0.2536 - auc_20: 0.9507 - binary_accuracy: 0.8629 - val_loss: 0.3187 - val_auc_20: 0.9379 - val_binary_accuracy: 0.8339 - 364ms/epoch - 8ms/step
# Epoch 13/20
# 44/44 - 0s - loss: 0.2497 - auc_20: 0.9477 - binary_accuracy: 0.8636 - val_loss: 0.3090 - val_auc_20: 0.9379 - val_binary_accuracy: 0.8339 - 362ms/epoch - 8ms/step
# Epoch 14/20
# 44/44 - 0s - loss: 0.2455 - auc_20: 0.9515 - binary_accuracy: 0.8636 - val_loss: 0.3047 - val_auc_20: 0.9380 - val_binary_accuracy: 0.8371 - 365ms/epoch - 8ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.2420 - auc_20: 0.9533 - binary_accuracy: 0.8636 - val_loss: 0.3039 - val_auc_20: 0.9380 - val_binary_accuracy: 0.8469 - 378ms/epoch - 9ms/step
# Epoch 16/20
# 44/44 - 0s - loss: 0.2403 - auc_20: 0.9504 - binary_accuracy: 0.8636 - val_loss: 0.3039 - val_auc_20: 0.9399 - val_binary_accuracy: 0.8339 - 360ms/epoch - 8ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.2364 - auc_20: 0.9549 - binary_accuracy: 0.8636 - val_loss: 0.2976 - val_auc_20: 0.9399 - val_binary_accuracy: 0.8371 - 368ms/epoch - 8ms/step
# Epoch 18/20
# 44/44 - 0s - loss: 0.2353 - auc_20: 0.9512 - binary_accuracy: 0.8629 - val_loss: 0.2912 - val_auc_20: 0.9400 - val_binary_accuracy: 0.8371 - 364ms/epoch - 8ms/step
# Epoch 19/20
# 44/44 - 0s - loss: 0.2355 - auc_20: 0.9491 - binary_accuracy: 0.8636 - val_loss: 0.2899 - val_auc_20: 0.9403 - val_binary_accuracy: 0.8371 - 375ms/epoch - 9ms/step
# Epoch 20/20
# 44/44 - 0s - loss: 0.2346 - auc_20: 0.9508 - binary_accuracy: 0.8629 - val_loss: 0.2902 - val_auc_20: 0.9418 - val_binary_accuracy: 0.8371 - 363ms/epoch - 8ms/step

# %% [markdown]
# #### Testing on Test set

# %%
print("Evaluate on test data")
results = model.evaluate(x_test, y_test)
print("test accuracy = ", results[2]);
# Out:
# Evaluate on test data
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2728 - auc_20: 0.9419 - binary_accuracy: 0.8532
# test accuracy =  0.8532423377037048

# %% [markdown]
# #### Deep NN

# %%
import datetime
model = keras.Sequential( [keras.layers.Dense(30,activation='relu'),keras.layers.Dense(30,activation='relu'),
                           keras.layers.Dense(30,activation='relu'),keras.layers.Dense(30,activation='relu'),
                           keras.layers.Dense(1)] )
model.compile(optimizer = 'sgd',
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])

model.fit(x_train,y_train, epochs = 10,validation_data=(x_validate,y_validate),verbose = 2)
# Out:
# Epoch 1/10
# 44/44 - 1s - loss: 0.6683 - auc_21: 0.7582 - binary_accuracy: 0.5179 - val_loss: 0.6549 - val_auc_21: 0.8201 - val_binary_accuracy: 0.5244 - 1s/epoch - 23ms/step
# Epoch 2/10
# 44/44 - 0s - loss: 0.6326 - auc_21: 0.8711 - binary_accuracy: 0.5257 - val_loss: 0.6276 - val_auc_21: 0.8599 - val_binary_accuracy: 0.5244 - 343ms/epoch - 8ms/step
# Epoch 3/10
# 44/44 - 0s - loss: 0.5916 - auc_21: 0.9007 - binary_accuracy: 0.5264 - val_loss: 0.5822 - val_auc_21: 0.8919 - val_binary_accuracy: 0.5179 - 346ms/epoch - 8ms/step
# Epoch 4/10
# 44/44 - 0s - loss: 0.5303 - auc_21: 0.9232 - binary_accuracy: 0.6071 - val_loss: 0.5085 - val_auc_21: 0.9118 - val_binary_accuracy: 0.7427 - 346ms/epoch - 8ms/step
# Epoch 5/10
# 44/44 - 0s - loss: 0.4444 - auc_21: 0.9402 - binary_accuracy: 0.7929 - val_loss: 0.4285 - val_auc_21: 0.9265 - val_binary_accuracy: 0.7948 - 338ms/epoch - 8ms/step
# Epoch 6/10
# 44/44 - 0s - loss: 0.3628 - auc_21: 0.9483 - binary_accuracy: 0.8443 - val_loss: 0.3505 - val_auc_21: 0.9366 - val_binary_accuracy: 0.8241 - 344ms/epoch - 8ms/step
# Epoch 7/10
# 44/44 - 0s - loss: 0.3151 - auc_21: 0.9466 - binary_accuracy: 0.8407 - val_loss: 0.3139 - val_auc_21: 0.9411 - val_binary_accuracy: 0.8306 - 345ms/epoch - 8ms/step
# Epoch 8/10
# 44/44 - 0s - loss: 0.2736 - auc_21: 0.9538 - binary_accuracy: 0.8629 - val_loss: 0.3166 - val_auc_21: 0.9465 - val_binary_accuracy: 0.8339 - 343ms/epoch - 8ms/step
# Epoch 9/10
# 44/44 - 0s - loss: 0.2691 - auc_21: 0.9492 - binary_accuracy: 0.8507 - val_loss: 0.3277 - val_auc_21: 0.9453 - val_binary_accuracy: 0.8306 - 342ms/epoch - 8ms/step
# Epoch 10/10
# 44/44 - 0s - loss: 0.2715 - auc_21: 0.9499 - binary_accuracy: 0.8443 - val_loss: 0.2899 - val_auc_21: 0.9468 - val_binary_accuracy: 0.8371 - 342ms/epoch - 8ms/step

# %% [markdown]
# #### Shuffling

# %%
import tensorflow as tf
from tensorflow import keras 
train = tf.concat([x_train,tf.reshape(y_train,[-1,1])],1)
train_shuffle = tf.random.shuffle(train)
x_train_shuffle = train_shuffle[:,0:tf.shape(x_train)[1]]
y_train_shuffle = train_shuffle[:,tf.shape(x_train)[1]]

# %% [markdown]
# #### Hyper parameters

# %%
from tensorboard.plugins.hparams import api as hp

HP_WIDTH = hp.HParam('NN_width', hp.Discrete([20,30,40]))
HP_DEPTH = hp.HParam('NN_depth', hp.Discrete([4,5,6]))


with tf.summary.create_file_writer('logs1483/hparams_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_WIDTH, HP_DEPTH],
    metrics=[hp.Metric('Accuracy')],
  )

# %% [markdown]
# #### CrossValidation

# %%
def CV_Deep_Binary_model(hparams,logdir, k, current_best, d, w):
    indiceslist = []
    
    for i in range(k-1):
        indices = tf.range(i * ((tf.shape(x_train_shuffle)[0])//k), (i + 1)* ((tf.shape(x_train_shuffle)[0])//k),1).numpy().tolist()
        indiceslist.append([indices])
        
    accuracy = 0
    # combining whatever remaining after k-1 splits (to account if length of dataset is not divisible by k)
    
    indices = tf.range((k-1) * ((tf.shape(x_train_shuffle)[0])//k), (tf.shape(x_train_shuffle)[0]),1).numpy().tolist()
    
    indiceslist.append([indices]) ## indiceslist to divide train and validate
    
    for i in range(k):
        print("\nSplit no",i+1)
        model = keras.Sequential()
        for _ in range(hparams[HP_DEPTH]):
            model.add(keras.layers.Dense(hparams[HP_WIDTH],activation='relu'))
        model.add(keras.layers.Dense(1))
        model.compile(optimizer = 'sgd',
        loss=keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])
        
        b = indiceslist[i][0] 
        a = [int(item) for item in b]

        x_validate = tf.gather(x_train_shuffle,a)

        y_validate = tf.gather(y_train_shuffle,a)
        
        z = []
        
        for j in range(k):
            
            if j != i:                     ## Make sure validation and train set are different
                z =  z + indiceslist[j][0]
                
        a = [int(item) for item in z]
        
        x_train = tf.gather(x_train_shuffle, a)
        y_train = tf.gather(y_train_shuffle, a)
        
        print("\nTraining")
        
        history = model.fit(x_train, y_train, epochs= 10,validation_data = (x_validate,y_validate), verbose = 2)
        if np.max(history.history["val_binary_accuracy"]) > current_best:
                  current_best = np.max(history.history["val_binary_accuracy"])
                  d = hparams[HP_DEPTH]
                  w = hparams[HP_WIDTH]
        accuracy = accuracy + np.max(history.history["val_binary_accuracy"])
    
    return accuracy/k, d, w, current_best

# %% [markdown]
# #### Tuning

# %%
k =3 
current_best = 0
d,w = 0,0
for hp_width in HP_WIDTH.domain.values:
  for hp_depth in (HP_DEPTH.domain.values):
    hparams = {
        HP_WIDTH: hp_width,
        HP_DEPTH: hp_depth,
    }
    run_name = f"run-WIDTH{int(hparams[HP_WIDTH])}-DEPTH{hparams[HP_DEPTH]}"
    print('--- Starting trial: %s' % run_name)
    print({h.name: hparams[h] for h in hparams})

    run_dir = 'logs1483/hparams_tuning/' + run_name
    accuracy, d, w, current_best = CV_Deep_Binary_model(hparams,run_dir, k, current_best, d, w)

    with tf.summary.create_file_writer(run_dir).as_default():
      hp.hparams(hparams)  # record the values used in this trial
      tf.summary.scalar("Accuracy", accuracy, step=1)
# Out:
# --- Starting trial: run-WIDTH20-DEPTH4
# {'NN_width': 20, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6996 - auc_22: 0.5756 - binary_accuracy: 0.5000 - val_loss: 0.6939 - val_auc_22: 0.7352 - val_binary_accuracy: 0.4657 - 1s/epoch - 35ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6783 - auc_22: 0.7761 - binary_accuracy: 0.5214 - val_loss: 0.6814 - val_auc_22: 0.7619 - val_binary_accuracy: 0.4764 - 259ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6604 - auc_22: 0.8210 - binary_accuracy: 0.5343 - val_loss: 0.6745 - val_auc_22: 0.8063 - val_binary_accuracy: 0.4785 - 252ms/epoch - 8ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6508 - auc_22: 0.8708 - binary_accuracy: 0.5353 - val_loss: 0.6659 - val_auc_22: 0.8702 - val_binary_accuracy: 0.4807 - 252ms/epoch - 8ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6392 - auc_22: 0.8994 - binary_accuracy: 0.5353 - val_loss: 0.6625 - val_auc_22: 0.8592 - val_binary_accuracy: 0.4850 - 256ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6261 - auc_22: 0.9091 - binary_accuracy: 0.5364 - val_loss: 0.6421 - val_auc_22: 0.8857 - val_binary_accuracy: 0.4850 - 256ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6092 - auc_22: 0.9138 - binary_accuracy: 0.5375 - val_loss: 0.6262 - val_auc_22: 0.8880 - val_binary_accuracy: 0.4871 - 253ms/epoch - 8ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5860 - auc_22: 0.9258 - binary_accuracy: 0.5375 - val_loss: 0.6135 - val_auc_22: 0.8434 - val_binary_accuracy: 0.4871 - 257ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5606 - auc_22: 0.9214 - binary_accuracy: 0.5375 - val_loss: 0.5833 - val_auc_22: 0.8983 - val_binary_accuracy: 0.4850 - 254ms/epoch - 8ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5239 - auc_22: 0.9304 - binary_accuracy: 0.5375 - val_loss: 0.5409 - val_auc_22: 0.9038 - val_binary_accuracy: 0.4850 - 252ms/epoch - 8ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6708 - auc_23: 0.6976 - binary_accuracy: 0.5150 - val_loss: 0.6658 - val_auc_23: 0.8566 - val_binary_accuracy: 0.5408 - 2s/epoch - 63ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6527 - auc_23: 0.7901 - binary_accuracy: 0.5182 - val_loss: 0.6577 - val_auc_23: 0.8367 - val_binary_accuracy: 0.5408 - 264ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6414 - auc_23: 0.8592 - binary_accuracy: 0.5182 - val_loss: 0.6499 - val_auc_23: 0.8494 - val_binary_accuracy: 0.5365 - 263ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6288 - auc_23: 0.8837 - binary_accuracy: 0.5182 - val_loss: 0.6442 - val_auc_23: 0.8416 - val_binary_accuracy: 0.5343 - 270ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6171 - auc_23: 0.8865 - binary_accuracy: 0.5203 - val_loss: 0.6278 - val_auc_23: 0.8737 - val_binary_accuracy: 0.5687 - 272ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6021 - auc_23: 0.9105 - binary_accuracy: 0.5931 - val_loss: 0.6231 - val_auc_23: 0.8778 - val_binary_accuracy: 0.7768 - 261ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5885 - auc_23: 0.9152 - binary_accuracy: 0.7377 - val_loss: 0.6005 - val_auc_23: 0.8893 - val_binary_accuracy: 0.7790 - 257ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5698 - auc_23: 0.9195 - binary_accuracy: 0.8041 - val_loss: 0.5915 - val_auc_23: 0.8962 - val_binary_accuracy: 0.7489 - 259ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5471 - auc_23: 0.9299 - binary_accuracy: 0.8148 - val_loss: 0.5628 - val_auc_23: 0.8992 - val_binary_accuracy: 0.7961 - 284ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5260 - auc_23: 0.9402 - binary_accuracy: 0.8276 - val_loss: 0.5427 - val_auc_23: 0.9161 - val_binary_accuracy: 0.8219 - 254ms/epoch - 8ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6840 - auc_24: 0.6875 - binary_accuracy: 0.4968 - val_loss: 0.6866 - val_auc_24: 0.7104 - val_binary_accuracy: 0.4979 - 1s/epoch - 34ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6658 - auc_24: 0.8253 - binary_accuracy: 0.5139 - val_loss: 0.6802 - val_auc_24: 0.6848 - val_binary_accuracy: 0.5107 - 266ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6523 - auc_24: 0.8509 - binary_accuracy: 0.5204 - val_loss: 0.6763 - val_auc_24: 0.7363 - val_binary_accuracy: 0.5171 - 272ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6426 - auc_24: 0.8594 - binary_accuracy: 0.5215 - val_loss: 0.6659 - val_auc_24: 0.7889 - val_binary_accuracy: 0.5150 - 259ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6318 - auc_24: 0.8750 - binary_accuracy: 0.5215 - val_loss: 0.6560 - val_auc_24: 0.7760 - val_binary_accuracy: 0.5192 - 264ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6193 - auc_24: 0.8924 - binary_accuracy: 0.5215 - val_loss: 0.6458 - val_auc_24: 0.8255 - val_binary_accuracy: 0.5192 - 263ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6032 - auc_24: 0.9105 - binary_accuracy: 0.5236 - val_loss: 0.6345 - val_auc_24: 0.8533 - val_binary_accuracy: 0.5192 - 275ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5845 - auc_24: 0.9124 - binary_accuracy: 0.5279 - val_loss: 0.6194 - val_auc_24: 0.8429 - val_binary_accuracy: 0.5321 - 286ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5586 - auc_24: 0.9211 - binary_accuracy: 0.5976 - val_loss: 0.5899 - val_auc_24: 0.8783 - val_binary_accuracy: 0.6218 - 260ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5259 - auc_24: 0.9315 - binary_accuracy: 0.7468 - val_loss: 0.5687 - val_auc_24: 0.8765 - val_binary_accuracy: 0.5705 - 255ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH20-DEPTH5
# {'NN_width': 20, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6954 - auc_25: 0.5392 - binary_accuracy: 0.4968 - val_loss: 0.6866 - val_auc_25: 0.7804 - val_binary_accuracy: 0.4678 - 1s/epoch - 36ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6752 - auc_25: 0.7554 - binary_accuracy: 0.5278 - val_loss: 0.6793 - val_auc_25: 0.8142 - val_binary_accuracy: 0.4871 - 271ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6631 - auc_25: 0.8035 - binary_accuracy: 0.5353 - val_loss: 0.6730 - val_auc_25: 0.8399 - val_binary_accuracy: 0.4871 - 262ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6539 - auc_25: 0.8500 - binary_accuracy: 0.5385 - val_loss: 0.6621 - val_auc_25: 0.8438 - val_binary_accuracy: 0.4936 - 260ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6442 - auc_25: 0.8712 - binary_accuracy: 0.5385 - val_loss: 0.6587 - val_auc_25: 0.8769 - val_binary_accuracy: 0.4957 - 265ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6322 - auc_25: 0.8979 - binary_accuracy: 0.5385 - val_loss: 0.6381 - val_auc_25: 0.8920 - val_binary_accuracy: 0.4957 - 276ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6165 - auc_25: 0.9049 - binary_accuracy: 0.5418 - val_loss: 0.6381 - val_auc_25: 0.8946 - val_binary_accuracy: 0.4957 - 274ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5972 - auc_25: 0.9276 - binary_accuracy: 0.5589 - val_loss: 0.6069 - val_auc_25: 0.9049 - val_binary_accuracy: 0.5150 - 284ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5702 - auc_25: 0.9365 - binary_accuracy: 0.6981 - val_loss: 0.5770 - val_auc_25: 0.9146 - val_binary_accuracy: 0.6674 - 281ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5364 - auc_25: 0.9479 - binary_accuracy: 0.8330 - val_loss: 0.5400 - val_auc_25: 0.9197 - val_binary_accuracy: 0.7940 - 277ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6765 - auc_26: 0.6127 - binary_accuracy: 0.5107 - val_loss: 0.6745 - val_auc_26: 0.6848 - val_binary_accuracy: 0.5365 - 1s/epoch - 36ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6612 - auc_26: 0.7241 - binary_accuracy: 0.5171 - val_loss: 0.6682 - val_auc_26: 0.8122 - val_binary_accuracy: 0.5386 - 323ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6524 - auc_26: 0.7914 - binary_accuracy: 0.5182 - val_loss: 0.6625 - val_auc_26: 0.8192 - val_binary_accuracy: 0.5386 - 289ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6434 - auc_26: 0.8274 - binary_accuracy: 0.5182 - val_loss: 0.6529 - val_auc_26: 0.8747 - val_binary_accuracy: 0.5365 - 258ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6309 - auc_26: 0.8577 - binary_accuracy: 0.5193 - val_loss: 0.6420 - val_auc_26: 0.8592 - val_binary_accuracy: 0.5365 - 258ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6133 - auc_26: 0.8745 - binary_accuracy: 0.5193 - val_loss: 0.6189 - val_auc_26: 0.8787 - val_binary_accuracy: 0.5343 - 282ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5875 - auc_26: 0.8904 - binary_accuracy: 0.5193 - val_loss: 0.5992 - val_auc_26: 0.8945 - val_binary_accuracy: 0.5322 - 257ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5450 - auc_26: 0.9168 - binary_accuracy: 0.6017 - val_loss: 0.6081 - val_auc_26: 0.8389 - val_binary_accuracy: 0.7554 - 277ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.4909 - auc_26: 0.9253 - binary_accuracy: 0.7784 - val_loss: 0.4911 - val_auc_26: 0.9007 - val_binary_accuracy: 0.7961 - 258ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.4266 - auc_26: 0.9318 - binary_accuracy: 0.8158 - val_loss: 0.4343 - val_auc_26: 0.9133 - val_binary_accuracy: 0.7747 - 242ms/epoch - 8ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.7083 - auc_27: 0.4955 - binary_accuracy: 0.4775 - val_loss: 0.6976 - val_auc_27: 0.6954 - val_binary_accuracy: 0.4893 - 2s/epoch - 62ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6900 - auc_27: 0.7704 - binary_accuracy: 0.4936 - val_loss: 0.6903 - val_auc_27: 0.6954 - val_binary_accuracy: 0.4915 - 290ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6730 - auc_27: 0.8324 - binary_accuracy: 0.5064 - val_loss: 0.6842 - val_auc_27: 0.7260 - val_binary_accuracy: 0.4936 - 268ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6604 - auc_27: 0.8483 - binary_accuracy: 0.5150 - val_loss: 0.6768 - val_auc_27: 0.8405 - val_binary_accuracy: 0.4936 - 273ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6498 - auc_27: 0.8907 - binary_accuracy: 0.5172 - val_loss: 0.6692 - val_auc_27: 0.8359 - val_binary_accuracy: 0.5000 - 256ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6378 - auc_27: 0.8779 - binary_accuracy: 0.5182 - val_loss: 0.6599 - val_auc_27: 0.8542 - val_binary_accuracy: 0.5000 - 265ms/epoch - 9ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6227 - auc_27: 0.8920 - binary_accuracy: 0.5193 - val_loss: 0.6507 - val_auc_27: 0.8653 - val_binary_accuracy: 0.5000 - 280ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6026 - auc_27: 0.8842 - binary_accuracy: 0.5215 - val_loss: 0.6531 - val_auc_27: 0.8627 - val_binary_accuracy: 0.5000 - 270ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5744 - auc_27: 0.9004 - binary_accuracy: 0.5215 - val_loss: 0.5988 - val_auc_27: 0.8725 - val_binary_accuracy: 0.5085 - 271ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5274 - auc_27: 0.9260 - binary_accuracy: 0.6180 - val_loss: 0.5710 - val_auc_27: 0.8473 - val_binary_accuracy: 0.7051 - 279ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH20-DEPTH6
# {'NN_width': 20, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7427 - auc_28: 0.6081 - binary_accuracy: 0.4936 - val_loss: 0.7328 - val_auc_28: 0.7628 - val_binary_accuracy: 0.4528 - 989ms/epoch - 33ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.7408 - auc_28: 0.7359 - binary_accuracy: 0.4936 - val_loss: 0.7043 - val_auc_28: 0.7461 - val_binary_accuracy: 0.4528 - 283ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6959 - auc_28: 0.8011 - binary_accuracy: 0.4946 - val_loss: 0.6962 - val_auc_28: 0.7508 - val_binary_accuracy: 0.4528 - 276ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6801 - auc_28: 0.8510 - binary_accuracy: 0.5000 - val_loss: 0.6887 - val_auc_28: 0.8137 - val_binary_accuracy: 0.4528 - 285ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6672 - auc_28: 0.8788 - binary_accuracy: 0.5128 - val_loss: 0.6790 - val_auc_28: 0.8281 - val_binary_accuracy: 0.4592 - 283ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6539 - auc_28: 0.9033 - binary_accuracy: 0.5246 - val_loss: 0.6676 - val_auc_28: 0.8508 - val_binary_accuracy: 0.4614 - 286ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6382 - auc_28: 0.9298 - binary_accuracy: 0.5289 - val_loss: 0.6548 - val_auc_28: 0.8613 - val_binary_accuracy: 0.4614 - 274ms/epoch - 9ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6192 - auc_28: 0.9321 - binary_accuracy: 0.5310 - val_loss: 0.6467 - val_auc_28: 0.8630 - val_binary_accuracy: 0.4657 - 279ms/epoch - 9ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5949 - auc_28: 0.9448 - binary_accuracy: 0.5332 - val_loss: 0.6168 - val_auc_28: 0.8756 - val_binary_accuracy: 0.4700 - 276ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5649 - auc_28: 0.9440 - binary_accuracy: 0.5418 - val_loss: 0.5905 - val_auc_28: 0.8791 - val_binary_accuracy: 0.5021 - 278ms/epoch - 9ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6901 - auc_29: 0.5678 - binary_accuracy: 0.4743 - val_loss: 0.6876 - val_auc_29: 0.8022 - val_binary_accuracy: 0.5043 - 1s/epoch - 39ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6787 - auc_29: 0.7763 - binary_accuracy: 0.4946 - val_loss: 0.6842 - val_auc_29: 0.8465 - val_binary_accuracy: 0.5086 - 279ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6659 - auc_29: 0.8604 - binary_accuracy: 0.5075 - val_loss: 0.6769 - val_auc_29: 0.8934 - val_binary_accuracy: 0.5086 - 289ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6566 - auc_29: 0.8839 - binary_accuracy: 0.5128 - val_loss: 0.6713 - val_auc_29: 0.8984 - val_binary_accuracy: 0.5172 - 268ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6472 - auc_29: 0.8920 - binary_accuracy: 0.5150 - val_loss: 0.6644 - val_auc_29: 0.8865 - val_binary_accuracy: 0.5172 - 278ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6378 - auc_29: 0.9068 - binary_accuracy: 0.5171 - val_loss: 0.6550 - val_auc_29: 0.8969 - val_binary_accuracy: 0.5172 - 317ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6281 - auc_29: 0.9083 - binary_accuracy: 0.5171 - val_loss: 0.6475 - val_auc_29: 0.8901 - val_binary_accuracy: 0.5215 - 289ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6165 - auc_29: 0.9220 - binary_accuracy: 0.5182 - val_loss: 0.6332 - val_auc_29: 0.9048 - val_binary_accuracy: 0.5215 - 286ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6014 - auc_29: 0.9227 - binary_accuracy: 0.5193 - val_loss: 0.6179 - val_auc_29: 0.9051 - val_binary_accuracy: 0.5215 - 282ms/epoch - 9ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5814 - auc_29: 0.9297 - binary_accuracy: 0.5203 - val_loss: 0.6100 - val_auc_29: 0.8874 - val_binary_accuracy: 0.5408 - 291ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7524 - auc_30: 0.6640 - binary_accuracy: 0.4764 - val_loss: 0.7213 - val_auc_30: 0.6365 - val_binary_accuracy: 0.4872 - 1s/epoch - 40ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6819 - auc_30: 0.7902 - binary_accuracy: 0.4946 - val_loss: 0.6964 - val_auc_30: 0.6887 - val_binary_accuracy: 0.4893 - 261ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6338 - auc_30: 0.8263 - binary_accuracy: 0.5107 - val_loss: 0.6842 - val_auc_30: 0.6710 - val_binary_accuracy: 0.4957 - 270ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6030 - auc_30: 0.8627 - binary_accuracy: 0.5172 - val_loss: 0.6547 - val_auc_30: 0.7788 - val_binary_accuracy: 0.4957 - 276ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.5619 - auc_30: 0.8989 - binary_accuracy: 0.5193 - val_loss: 0.6126 - val_auc_30: 0.8286 - val_binary_accuracy: 0.6261 - 270ms/epoch - 9ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5067 - auc_30: 0.9260 - binary_accuracy: 0.6931 - val_loss: 0.6100 - val_auc_30: 0.7881 - val_binary_accuracy: 0.6966 - 314ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.4419 - auc_30: 0.9299 - binary_accuracy: 0.7929 - val_loss: 0.5149 - val_auc_30: 0.8703 - val_binary_accuracy: 0.7821 - 292ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3800 - auc_30: 0.9433 - binary_accuracy: 0.8326 - val_loss: 0.4762 - val_auc_30: 0.8812 - val_binary_accuracy: 0.7970 - 301ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3345 - auc_30: 0.9467 - binary_accuracy: 0.8380 - val_loss: 0.5592 - val_auc_30: 0.8825 - val_binary_accuracy: 0.6389 - 288ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2991 - auc_30: 0.9504 - binary_accuracy: 0.8401 - val_loss: 0.4774 - val_auc_30: 0.8888 - val_binary_accuracy: 0.8056 - 269ms/epoch - 9ms/step
# --- Starting trial: run-WIDTH30-DEPTH4
# {'NN_width': 30, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6715 - auc_31: 0.6917 - binary_accuracy: 0.5343 - val_loss: 0.6677 - val_auc_31: 0.7540 - val_binary_accuracy: 0.5000 - 2s/epoch - 73ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6557 - auc_31: 0.8187 - binary_accuracy: 0.5385 - val_loss: 0.6589 - val_auc_31: 0.8239 - val_binary_accuracy: 0.5000 - 282ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6440 - auc_31: 0.8863 - binary_accuracy: 0.5385 - val_loss: 0.6527 - val_auc_31: 0.8681 - val_binary_accuracy: 0.5000 - 275ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6313 - auc_31: 0.9224 - binary_accuracy: 0.5385 - val_loss: 0.6381 - val_auc_31: 0.8728 - val_binary_accuracy: 0.4957 - 280ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6168 - auc_31: 0.9345 - binary_accuracy: 0.5418 - val_loss: 0.6275 - val_auc_31: 0.8823 - val_binary_accuracy: 0.5000 - 292ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5990 - auc_31: 0.9431 - binary_accuracy: 0.5749 - val_loss: 0.6019 - val_auc_31: 0.8954 - val_binary_accuracy: 0.5343 - 305ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5768 - auc_31: 0.9463 - binary_accuracy: 0.6788 - val_loss: 0.5875 - val_auc_31: 0.9071 - val_binary_accuracy: 0.7618 - 340ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5529 - auc_31: 0.9448 - binary_accuracy: 0.8255 - val_loss: 0.5593 - val_auc_31: 0.9101 - val_binary_accuracy: 0.7747 - 304ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5204 - auc_31: 0.9590 - binary_accuracy: 0.8351 - val_loss: 0.5366 - val_auc_31: 0.9149 - val_binary_accuracy: 0.7983 - 300ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.4891 - auc_31: 0.9493 - binary_accuracy: 0.8662 - val_loss: 0.5033 - val_auc_31: 0.9142 - val_binary_accuracy: 0.7940 - 308ms/epoch - 10ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6640 - auc_32: 0.7557 - binary_accuracy: 0.5150 - val_loss: 0.6591 - val_auc_32: 0.8368 - val_binary_accuracy: 0.5408 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6445 - auc_32: 0.8473 - binary_accuracy: 0.5182 - val_loss: 0.6476 - val_auc_32: 0.8773 - val_binary_accuracy: 0.5365 - 283ms/epoch - 9ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6267 - auc_32: 0.8919 - binary_accuracy: 0.5182 - val_loss: 0.6264 - val_auc_32: 0.8688 - val_binary_accuracy: 0.5343 - 287ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.5846 - auc_32: 0.9145 - binary_accuracy: 0.5610 - val_loss: 0.6129 - val_auc_32: 0.8665 - val_binary_accuracy: 0.7597 - 302ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.5498 - auc_32: 0.9252 - binary_accuracy: 0.7227 - val_loss: 0.5716 - val_auc_32: 0.8840 - val_binary_accuracy: 0.7833 - 302ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5057 - auc_32: 0.9378 - binary_accuracy: 0.8084 - val_loss: 0.5388 - val_auc_32: 0.8942 - val_binary_accuracy: 0.7489 - 354ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.4560 - auc_32: 0.9378 - binary_accuracy: 0.8308 - val_loss: 0.4873 - val_auc_32: 0.8997 - val_binary_accuracy: 0.7961 - 320ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3999 - auc_32: 0.9449 - binary_accuracy: 0.8383 - val_loss: 0.4354 - val_auc_32: 0.9040 - val_binary_accuracy: 0.7983 - 331ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3486 - auc_32: 0.9511 - binary_accuracy: 0.8373 - val_loss: 0.4404 - val_auc_32: 0.9100 - val_binary_accuracy: 0.7940 - 345ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3190 - auc_32: 0.9473 - binary_accuracy: 0.8340 - val_loss: 0.3871 - val_auc_32: 0.9196 - val_binary_accuracy: 0.8112 - 310ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7076 - auc_33: 0.7297 - binary_accuracy: 0.4807 - val_loss: 0.6820 - val_auc_33: 0.7511 - val_binary_accuracy: 0.4957 - 1s/epoch - 34ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6120 - auc_33: 0.8367 - binary_accuracy: 0.5172 - val_loss: 0.6453 - val_auc_33: 0.7889 - val_binary_accuracy: 0.5107 - 322ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5504 - auc_33: 0.8907 - binary_accuracy: 0.5247 - val_loss: 0.6031 - val_auc_33: 0.8529 - val_binary_accuracy: 0.5085 - 306ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.4940 - auc_33: 0.9192 - binary_accuracy: 0.6695 - val_loss: 0.5591 - val_auc_33: 0.8675 - val_binary_accuracy: 0.7714 - 292ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4370 - auc_33: 0.9313 - binary_accuracy: 0.7886 - val_loss: 0.5929 - val_auc_33: 0.8139 - val_binary_accuracy: 0.7521 - 298ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3908 - auc_33: 0.9318 - binary_accuracy: 0.8187 - val_loss: 0.4889 - val_auc_33: 0.8820 - val_binary_accuracy: 0.7457 - 294ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3402 - auc_33: 0.9437 - binary_accuracy: 0.8326 - val_loss: 0.4490 - val_auc_33: 0.8922 - val_binary_accuracy: 0.8205 - 319ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3061 - auc_33: 0.9465 - binary_accuracy: 0.8369 - val_loss: 0.4389 - val_auc_33: 0.8935 - val_binary_accuracy: 0.8098 - 308ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2841 - auc_33: 0.9543 - binary_accuracy: 0.8519 - val_loss: 0.4740 - val_auc_33: 0.8908 - val_binary_accuracy: 0.8120 - 307ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2744 - auc_33: 0.9514 - binary_accuracy: 0.8476 - val_loss: 0.4155 - val_auc_33: 0.8965 - val_binary_accuracy: 0.8248 - 316ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH30-DEPTH5
# {'NN_width': 30, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6887 - auc_34: 0.6336 - binary_accuracy: 0.5118 - val_loss: 0.6843 - val_auc_34: 0.7607 - val_binary_accuracy: 0.4742 - 1s/epoch - 38ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6665 - auc_34: 0.8241 - binary_accuracy: 0.5332 - val_loss: 0.6791 - val_auc_34: 0.8584 - val_binary_accuracy: 0.4785 - 306ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6569 - auc_34: 0.8937 - binary_accuracy: 0.5364 - val_loss: 0.6734 - val_auc_34: 0.8605 - val_binary_accuracy: 0.4807 - 326ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6490 - auc_34: 0.9160 - binary_accuracy: 0.5375 - val_loss: 0.6672 - val_auc_34: 0.8670 - val_binary_accuracy: 0.4828 - 329ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6403 - auc_34: 0.9315 - binary_accuracy: 0.5375 - val_loss: 0.6568 - val_auc_34: 0.8772 - val_binary_accuracy: 0.4850 - 320ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6285 - auc_34: 0.9397 - binary_accuracy: 0.5385 - val_loss: 0.6458 - val_auc_34: 0.8824 - val_binary_accuracy: 0.4850 - 338ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6151 - auc_34: 0.9399 - binary_accuracy: 0.5385 - val_loss: 0.6349 - val_auc_34: 0.8846 - val_binary_accuracy: 0.4850 - 311ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5961 - auc_34: 0.9418 - binary_accuracy: 0.5385 - val_loss: 0.6140 - val_auc_34: 0.8895 - val_binary_accuracy: 0.4850 - 298ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5715 - auc_34: 0.9404 - binary_accuracy: 0.5621 - val_loss: 0.5998 - val_auc_34: 0.8916 - val_binary_accuracy: 0.7232 - 302ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5380 - auc_34: 0.9454 - binary_accuracy: 0.7173 - val_loss: 0.6037 - val_auc_34: 0.8902 - val_binary_accuracy: 0.5172 - 306ms/epoch - 10ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6995 - auc_35: 0.5712 - binary_accuracy: 0.4818 - val_loss: 0.6897 - val_auc_35: 0.7370 - val_binary_accuracy: 0.5107 - 1s/epoch - 40ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6747 - auc_35: 0.7871 - binary_accuracy: 0.5021 - val_loss: 0.6831 - val_auc_35: 0.8076 - val_binary_accuracy: 0.5215 - 387ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6582 - auc_35: 0.8486 - binary_accuracy: 0.5139 - val_loss: 0.6764 - val_auc_35: 0.7866 - val_binary_accuracy: 0.5236 - 401ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6478 - auc_35: 0.8536 - binary_accuracy: 0.5161 - val_loss: 0.6690 - val_auc_35: 0.8892 - val_binary_accuracy: 0.5258 - 435ms/epoch - 15ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6389 - auc_35: 0.8631 - binary_accuracy: 0.5193 - val_loss: 0.6618 - val_auc_35: 0.8923 - val_binary_accuracy: 0.5279 - 439ms/epoch - 15ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6284 - auc_35: 0.8853 - binary_accuracy: 0.5193 - val_loss: 0.6550 - val_auc_35: 0.8908 - val_binary_accuracy: 0.5279 - 406ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6135 - auc_35: 0.9003 - binary_accuracy: 0.5193 - val_loss: 0.6360 - val_auc_35: 0.9005 - val_binary_accuracy: 0.5300 - 365ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5907 - auc_35: 0.9219 - binary_accuracy: 0.5193 - val_loss: 0.6169 - val_auc_35: 0.9014 - val_binary_accuracy: 0.5300 - 363ms/epoch - 12ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5610 - auc_35: 0.9286 - binary_accuracy: 0.5535 - val_loss: 0.5997 - val_auc_35: 0.9019 - val_binary_accuracy: 0.5300 - 374ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5178 - auc_35: 0.9362 - binary_accuracy: 0.7441 - val_loss: 0.5583 - val_auc_35: 0.8902 - val_binary_accuracy: 0.7597 - 340ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6885 - auc_36: 0.7058 - binary_accuracy: 0.4914 - val_loss: 0.6820 - val_auc_36: 0.7739 - val_binary_accuracy: 0.5064 - 2s/epoch - 83ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6500 - auc_36: 0.8712 - binary_accuracy: 0.5215 - val_loss: 0.6756 - val_auc_36: 0.7864 - val_binary_accuracy: 0.5064 - 291ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6339 - auc_36: 0.8717 - binary_accuracy: 0.5215 - val_loss: 0.6631 - val_auc_36: 0.8544 - val_binary_accuracy: 0.5064 - 310ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6162 - auc_36: 0.8907 - binary_accuracy: 0.5215 - val_loss: 0.6424 - val_auc_36: 0.8484 - val_binary_accuracy: 0.5043 - 327ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.5925 - auc_36: 0.9140 - binary_accuracy: 0.5290 - val_loss: 0.6221 - val_auc_36: 0.8689 - val_binary_accuracy: 0.5385 - 334ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5635 - auc_36: 0.9252 - binary_accuracy: 0.6534 - val_loss: 0.6138 - val_auc_36: 0.8432 - val_binary_accuracy: 0.7073 - 321ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5230 - auc_36: 0.9330 - binary_accuracy: 0.7918 - val_loss: 0.6178 - val_auc_36: 0.8665 - val_binary_accuracy: 0.5043 - 353ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.4768 - auc_36: 0.9380 - binary_accuracy: 0.8069 - val_loss: 0.5097 - val_auc_36: 0.8893 - val_binary_accuracy: 0.7863 - 326ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.4100 - auc_36: 0.9508 - binary_accuracy: 0.8498 - val_loss: 0.4603 - val_auc_36: 0.8864 - val_binary_accuracy: 0.8120 - 324ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3470 - auc_36: 0.9516 - binary_accuracy: 0.8541 - val_loss: 0.4322 - val_auc_36: 0.8873 - val_binary_accuracy: 0.7521 - 311ms/epoch - 10ms/step
# --- Starting trial: run-WIDTH30-DEPTH6
# {'NN_width': 30, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6940 - auc_37: 0.5833 - binary_accuracy: 0.4957 - val_loss: 0.6879 - val_auc_37: 0.5737 - val_binary_accuracy: 0.4614 - 1s/epoch - 42ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6780 - auc_37: 0.6056 - binary_accuracy: 0.5225 - val_loss: 0.6824 - val_auc_37: 0.5561 - val_binary_accuracy: 0.4742 - 290ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6679 - auc_37: 0.7091 - binary_accuracy: 0.5353 - val_loss: 0.6799 - val_auc_37: 0.7569 - val_binary_accuracy: 0.4807 - 276ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6639 - auc_37: 0.8011 - binary_accuracy: 0.5364 - val_loss: 0.6779 - val_auc_37: 0.7726 - val_binary_accuracy: 0.4871 - 287ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6612 - auc_37: 0.8324 - binary_accuracy: 0.5375 - val_loss: 0.6765 - val_auc_37: 0.8382 - val_binary_accuracy: 0.4936 - 295ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6589 - auc_37: 0.8324 - binary_accuracy: 0.5385 - val_loss: 0.6757 - val_auc_37: 0.7720 - val_binary_accuracy: 0.4936 - 330ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6564 - auc_37: 0.8775 - binary_accuracy: 0.5385 - val_loss: 0.6733 - val_auc_37: 0.8632 - val_binary_accuracy: 0.4957 - 317ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6540 - auc_37: 0.8953 - binary_accuracy: 0.5385 - val_loss: 0.6716 - val_auc_37: 0.7883 - val_binary_accuracy: 0.4957 - 321ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6511 - auc_37: 0.9197 - binary_accuracy: 0.5385 - val_loss: 0.6683 - val_auc_37: 0.8825 - val_binary_accuracy: 0.4957 - 304ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6475 - auc_37: 0.9298 - binary_accuracy: 0.5385 - val_loss: 0.6648 - val_auc_37: 0.8868 - val_binary_accuracy: 0.4957 - 295ms/epoch - 10ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7017 - auc_38: 0.6527 - binary_accuracy: 0.4743 - val_loss: 0.6945 - val_auc_38: 0.7008 - val_binary_accuracy: 0.5086 - 1s/epoch - 40ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6764 - auc_38: 0.7654 - binary_accuracy: 0.4989 - val_loss: 0.6785 - val_auc_38: 0.8258 - val_binary_accuracy: 0.5215 - 398ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6513 - auc_38: 0.8132 - binary_accuracy: 0.5161 - val_loss: 0.6749 - val_auc_38: 0.7608 - val_binary_accuracy: 0.5236 - 278ms/epoch - 9ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6400 - auc_38: 0.8351 - binary_accuracy: 0.5182 - val_loss: 0.6591 - val_auc_38: 0.8515 - val_binary_accuracy: 0.5236 - 280ms/epoch - 9ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6278 - auc_38: 0.8672 - binary_accuracy: 0.5193 - val_loss: 0.6452 - val_auc_38: 0.8718 - val_binary_accuracy: 0.5258 - 292ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6120 - auc_38: 0.8932 - binary_accuracy: 0.5193 - val_loss: 0.6295 - val_auc_38: 0.8840 - val_binary_accuracy: 0.5300 - 330ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5944 - auc_38: 0.9004 - binary_accuracy: 0.5193 - val_loss: 0.6030 - val_auc_38: 0.9004 - val_binary_accuracy: 0.5322 - 309ms/epoch - 10ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5708 - auc_38: 0.9091 - binary_accuracy: 0.5460 - val_loss: 0.6090 - val_auc_38: 0.8705 - val_binary_accuracy: 0.7597 - 298ms/epoch - 10ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5328 - auc_38: 0.9272 - binary_accuracy: 0.7259 - val_loss: 0.5315 - val_auc_38: 0.9165 - val_binary_accuracy: 0.7725 - 292ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.4819 - auc_38: 0.9350 - binary_accuracy: 0.7934 - val_loss: 0.5213 - val_auc_38: 0.8996 - val_binary_accuracy: 0.7725 - 304ms/epoch - 10ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6785 - auc_39: 0.6037 - binary_accuracy: 0.5075 - val_loss: 0.6776 - val_auc_39: 0.5343 - val_binary_accuracy: 0.5278 - 2s/epoch - 68ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6631 - auc_39: 0.7597 - binary_accuracy: 0.5204 - val_loss: 0.6748 - val_auc_39: 0.6503 - val_binary_accuracy: 0.5278 - 314ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6578 - auc_39: 0.8213 - binary_accuracy: 0.5204 - val_loss: 0.6731 - val_auc_39: 0.7450 - val_binary_accuracy: 0.5278 - 295ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6528 - auc_39: 0.8676 - binary_accuracy: 0.5215 - val_loss: 0.6671 - val_auc_39: 0.8203 - val_binary_accuracy: 0.5278 - 304ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6465 - auc_39: 0.8851 - binary_accuracy: 0.5215 - val_loss: 0.6624 - val_auc_39: 0.8004 - val_binary_accuracy: 0.5214 - 298ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6375 - auc_39: 0.9157 - binary_accuracy: 0.5258 - val_loss: 0.6546 - val_auc_39: 0.7914 - val_binary_accuracy: 0.5214 - 313ms/epoch - 10ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6258 - auc_39: 0.9043 - binary_accuracy: 0.5311 - val_loss: 0.6448 - val_auc_39: 0.8201 - val_binary_accuracy: 0.5256 - 326ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6093 - auc_39: 0.9119 - binary_accuracy: 0.5440 - val_loss: 0.6357 - val_auc_39: 0.8231 - val_binary_accuracy: 0.6004 - 317ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5883 - auc_39: 0.9183 - binary_accuracy: 0.6803 - val_loss: 0.6131 - val_auc_39: 0.8574 - val_binary_accuracy: 0.7415 - 316ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5645 - auc_39: 0.9376 - binary_accuracy: 0.8122 - val_loss: 0.5926 - val_auc_39: 0.8881 - val_binary_accuracy: 0.8056 - 299ms/epoch - 10ms/step
# --- Starting trial: run-WIDTH40-DEPTH4
# {'NN_width': 40, 'NN_depth': 4}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6751 - auc_40: 0.7130 - binary_accuracy: 0.5268 - val_loss: 0.6671 - val_auc_40: 0.8467 - val_binary_accuracy: 0.4914 - 1s/epoch - 37ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6379 - auc_40: 0.8730 - binary_accuracy: 0.5385 - val_loss: 0.6564 - val_auc_40: 0.8625 - val_binary_accuracy: 0.4850 - 303ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6115 - auc_40: 0.9056 - binary_accuracy: 0.5396 - val_loss: 0.6196 - val_auc_40: 0.8763 - val_binary_accuracy: 0.4807 - 370ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.5783 - auc_40: 0.9164 - binary_accuracy: 0.5675 - val_loss: 0.6402 - val_auc_40: 0.8728 - val_binary_accuracy: 0.4764 - 338ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.5384 - auc_40: 0.9230 - binary_accuracy: 0.6756 - val_loss: 0.5717 - val_auc_40: 0.8779 - val_binary_accuracy: 0.5536 - 304ms/epoch - 10ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.4811 - auc_40: 0.9473 - binary_accuracy: 0.7752 - val_loss: 0.5179 - val_auc_40: 0.8907 - val_binary_accuracy: 0.7618 - 358ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.4168 - auc_40: 0.9541 - binary_accuracy: 0.8469 - val_loss: 0.5603 - val_auc_40: 0.8849 - val_binary_accuracy: 0.5773 - 336ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3660 - auc_40: 0.9488 - binary_accuracy: 0.8544 - val_loss: 0.6293 - val_auc_40: 0.8834 - val_binary_accuracy: 0.7961 - 328ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3204 - auc_40: 0.9527 - binary_accuracy: 0.8662 - val_loss: 0.5161 - val_auc_40: 0.8939 - val_binary_accuracy: 0.8047 - 330ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2950 - auc_40: 0.9497 - binary_accuracy: 0.8630 - val_loss: 0.4489 - val_auc_40: 0.8934 - val_binary_accuracy: 0.7790 - 321ms/epoch - 11ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6650 - auc_41: 0.7330 - binary_accuracy: 0.4989 - val_loss: 0.6485 - val_auc_41: 0.8380 - val_binary_accuracy: 0.5322 - 1s/epoch - 38ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6390 - auc_41: 0.8632 - binary_accuracy: 0.5310 - val_loss: 0.6370 - val_auc_41: 0.8828 - val_binary_accuracy: 0.7103 - 298ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5908 - auc_41: 0.9017 - binary_accuracy: 0.6842 - val_loss: 0.5831 - val_auc_41: 0.9149 - val_binary_accuracy: 0.8133 - 316ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.5457 - auc_41: 0.9301 - binary_accuracy: 0.8126 - val_loss: 0.5450 - val_auc_41: 0.9239 - val_binary_accuracy: 0.7854 - 320ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4983 - auc_41: 0.9377 - binary_accuracy: 0.8298 - val_loss: 0.5055 - val_auc_41: 0.9345 - val_binary_accuracy: 0.7983 - 324ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.4437 - auc_41: 0.9415 - binary_accuracy: 0.8437 - val_loss: 0.4288 - val_auc_41: 0.9341 - val_binary_accuracy: 0.8433 - 340ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3852 - auc_41: 0.9444 - binary_accuracy: 0.8469 - val_loss: 0.4299 - val_auc_41: 0.9404 - val_binary_accuracy: 0.7961 - 350ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3357 - auc_41: 0.9519 - binary_accuracy: 0.8522 - val_loss: 0.3415 - val_auc_41: 0.9341 - val_binary_accuracy: 0.8433 - 338ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.3029 - auc_41: 0.9490 - binary_accuracy: 0.8533 - val_loss: 0.3748 - val_auc_41: 0.9356 - val_binary_accuracy: 0.8305 - 320ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2880 - auc_41: 0.9470 - binary_accuracy: 0.8480 - val_loss: 0.3003 - val_auc_41: 0.9426 - val_binary_accuracy: 0.8562 - 321ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6802 - auc_42: 0.7640 - binary_accuracy: 0.4989 - val_loss: 0.6524 - val_auc_42: 0.8140 - val_binary_accuracy: 0.5278 - 1s/epoch - 39ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6087 - auc_42: 0.8661 - binary_accuracy: 0.5215 - val_loss: 0.6245 - val_auc_42: 0.8370 - val_binary_accuracy: 0.5235 - 397ms/epoch - 13ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.5625 - auc_42: 0.8906 - binary_accuracy: 0.5290 - val_loss: 0.6158 - val_auc_42: 0.8254 - val_binary_accuracy: 0.6667 - 301ms/epoch - 10ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.5093 - auc_42: 0.9089 - binary_accuracy: 0.6599 - val_loss: 0.5470 - val_auc_42: 0.8773 - val_binary_accuracy: 0.7308 - 310ms/epoch - 10ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.4496 - auc_42: 0.9195 - binary_accuracy: 0.7790 - val_loss: 0.5005 - val_auc_42: 0.8908 - val_binary_accuracy: 0.7714 - 317ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.3868 - auc_42: 0.9445 - binary_accuracy: 0.8315 - val_loss: 0.5026 - val_auc_42: 0.8898 - val_binary_accuracy: 0.7628 - 351ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.3387 - auc_42: 0.9498 - binary_accuracy: 0.8423 - val_loss: 0.7625 - val_auc_42: 0.8957 - val_binary_accuracy: 0.5449 - 325ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.3176 - auc_42: 0.9478 - binary_accuracy: 0.8401 - val_loss: 0.4645 - val_auc_42: 0.8996 - val_binary_accuracy: 0.7714 - 322ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.2816 - auc_42: 0.9577 - binary_accuracy: 0.8627 - val_loss: 0.4085 - val_auc_42: 0.9039 - val_binary_accuracy: 0.8205 - 318ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.2757 - auc_42: 0.9509 - binary_accuracy: 0.8519 - val_loss: 0.3729 - val_auc_42: 0.9089 - val_binary_accuracy: 0.8291 - 319ms/epoch - 11ms/step
# --- Starting trial: run-WIDTH40-DEPTH5
# {'NN_width': 40, 'NN_depth': 5}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6739 - auc_43: 0.6722 - binary_accuracy: 0.5353 - val_loss: 0.6695 - val_auc_43: 0.7549 - val_binary_accuracy: 0.4957 - 1s/epoch - 48ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6629 - auc_43: 0.7983 - binary_accuracy: 0.5385 - val_loss: 0.6671 - val_auc_43: 0.7899 - val_binary_accuracy: 0.4957 - 331ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6577 - auc_43: 0.8562 - binary_accuracy: 0.5385 - val_loss: 0.6627 - val_auc_43: 0.8573 - val_binary_accuracy: 0.4957 - 350ms/epoch - 12ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6514 - auc_43: 0.8950 - binary_accuracy: 0.5385 - val_loss: 0.6592 - val_auc_43: 0.8541 - val_binary_accuracy: 0.4957 - 360ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6445 - auc_43: 0.9133 - binary_accuracy: 0.5385 - val_loss: 0.6476 - val_auc_43: 0.8827 - val_binary_accuracy: 0.4957 - 371ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6353 - auc_43: 0.9333 - binary_accuracy: 0.5385 - val_loss: 0.6373 - val_auc_43: 0.8933 - val_binary_accuracy: 0.4957 - 413ms/epoch - 14ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6249 - auc_43: 0.9379 - binary_accuracy: 0.5385 - val_loss: 0.6360 - val_auc_43: 0.8943 - val_binary_accuracy: 0.4957 - 368ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6115 - auc_43: 0.9463 - binary_accuracy: 0.5385 - val_loss: 0.6140 - val_auc_43: 0.9090 - val_binary_accuracy: 0.5000 - 362ms/epoch - 12ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5937 - auc_43: 0.9451 - binary_accuracy: 0.5728 - val_loss: 0.5910 - val_auc_43: 0.9187 - val_binary_accuracy: 0.5708 - 366ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5730 - auc_43: 0.9478 - binary_accuracy: 0.7195 - val_loss: 0.5743 - val_auc_43: 0.9238 - val_binary_accuracy: 0.7747 - 368ms/epoch - 12ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 2s - loss: 0.6883 - auc_44: 0.7522 - binary_accuracy: 0.4839 - val_loss: 0.6849 - val_auc_44: 0.8225 - val_binary_accuracy: 0.5172 - 2s/epoch - 79ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6534 - auc_44: 0.8513 - binary_accuracy: 0.5161 - val_loss: 0.6758 - val_auc_44: 0.8791 - val_binary_accuracy: 0.5193 - 308ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6383 - auc_44: 0.8888 - binary_accuracy: 0.5193 - val_loss: 0.6658 - val_auc_44: 0.8569 - val_binary_accuracy: 0.5236 - 325ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6222 - auc_44: 0.9011 - binary_accuracy: 0.5193 - val_loss: 0.6487 - val_auc_44: 0.8823 - val_binary_accuracy: 0.5236 - 335ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6010 - auc_44: 0.9171 - binary_accuracy: 0.5193 - val_loss: 0.6471 - val_auc_44: 0.8634 - val_binary_accuracy: 0.5236 - 333ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5711 - auc_44: 0.9279 - binary_accuracy: 0.5471 - val_loss: 0.5933 - val_auc_44: 0.8961 - val_binary_accuracy: 0.7446 - 398ms/epoch - 13ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5288 - auc_44: 0.9413 - binary_accuracy: 0.7527 - val_loss: 0.5592 - val_auc_44: 0.8986 - val_binary_accuracy: 0.6609 - 371ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.4762 - auc_44: 0.9470 - binary_accuracy: 0.8255 - val_loss: 0.5228 - val_auc_44: 0.8989 - val_binary_accuracy: 0.7725 - 341ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.4174 - auc_44: 0.9449 - binary_accuracy: 0.8330 - val_loss: 0.4906 - val_auc_44: 0.9036 - val_binary_accuracy: 0.8026 - 327ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3586 - auc_44: 0.9492 - binary_accuracy: 0.8544 - val_loss: 0.5644 - val_auc_44: 0.9030 - val_binary_accuracy: 0.6524 - 344ms/epoch - 11ms/step
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7207 - auc_45: 0.6442 - binary_accuracy: 0.4764 - val_loss: 0.6937 - val_auc_45: 0.6937 - val_binary_accuracy: 0.4936 - 1s/epoch - 41ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6742 - auc_45: 0.8241 - binary_accuracy: 0.5064 - val_loss: 0.6803 - val_auc_45: 0.7067 - val_binary_accuracy: 0.5021 - 317ms/epoch - 11ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6478 - auc_45: 0.8357 - binary_accuracy: 0.5204 - val_loss: 0.6677 - val_auc_45: 0.8259 - val_binary_accuracy: 0.5064 - 379ms/epoch - 13ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6319 - auc_45: 0.8699 - binary_accuracy: 0.5204 - val_loss: 0.6560 - val_auc_45: 0.8578 - val_binary_accuracy: 0.5064 - 346ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6131 - auc_45: 0.8871 - binary_accuracy: 0.5215 - val_loss: 0.6482 - val_auc_45: 0.8671 - val_binary_accuracy: 0.5085 - 350ms/epoch - 12ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5881 - auc_45: 0.8966 - binary_accuracy: 0.5215 - val_loss: 0.6388 - val_auc_45: 0.8692 - val_binary_accuracy: 0.5064 - 351ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5557 - auc_45: 0.9194 - binary_accuracy: 0.5215 - val_loss: 0.6064 - val_auc_45: 0.8795 - val_binary_accuracy: 0.5064 - 344ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.5074 - auc_45: 0.9240 - binary_accuracy: 0.5676 - val_loss: 0.6560 - val_auc_45: 0.8715 - val_binary_accuracy: 0.5021 - 398ms/epoch - 13ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.4601 - auc_45: 0.9294 - binary_accuracy: 0.7436 - val_loss: 0.6476 - val_auc_45: 0.8807 - val_binary_accuracy: 0.5021 - 371ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.4020 - auc_45: 0.9346 - binary_accuracy: 0.8101 - val_loss: 0.5371 - val_auc_45: 0.8945 - val_binary_accuracy: 0.6154 - 362ms/epoch - 12ms/step
# --- Starting trial: run-WIDTH40-DEPTH6
# {'NN_width': 40, 'NN_depth': 6}
#
# Split no 1
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6892 - auc_46: 0.5282 - binary_accuracy: 0.5011 - val_loss: 0.6888 - val_auc_46: 0.5643 - val_binary_accuracy: 0.4528 - 1s/epoch - 44ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6772 - auc_46: 0.7407 - binary_accuracy: 0.5236 - val_loss: 0.6877 - val_auc_46: 0.7096 - val_binary_accuracy: 0.4549 - 307ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6687 - auc_46: 0.8286 - binary_accuracy: 0.5343 - val_loss: 0.6840 - val_auc_46: 0.6857 - val_binary_accuracy: 0.4571 - 319ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6615 - auc_46: 0.8757 - binary_accuracy: 0.5353 - val_loss: 0.6772 - val_auc_46: 0.8582 - val_binary_accuracy: 0.4635 - 366ms/epoch - 12ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6555 - auc_46: 0.8974 - binary_accuracy: 0.5375 - val_loss: 0.6752 - val_auc_46: 0.8131 - val_binary_accuracy: 0.4657 - 342ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6490 - auc_46: 0.9091 - binary_accuracy: 0.5375 - val_loss: 0.6680 - val_auc_46: 0.8927 - val_binary_accuracy: 0.4742 - 329ms/epoch - 11ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6424 - auc_46: 0.9159 - binary_accuracy: 0.5375 - val_loss: 0.6609 - val_auc_46: 0.9053 - val_binary_accuracy: 0.4742 - 337ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.6337 - auc_46: 0.9343 - binary_accuracy: 0.5375 - val_loss: 0.6529 - val_auc_46: 0.9058 - val_binary_accuracy: 0.4700 - 373ms/epoch - 12ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.6238 - auc_46: 0.9394 - binary_accuracy: 0.5375 - val_loss: 0.6471 - val_auc_46: 0.9061 - val_binary_accuracy: 0.4742 - 350ms/epoch - 12ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.6107 - auc_46: 0.9431 - binary_accuracy: 0.5375 - val_loss: 0.6284 - val_auc_46: 0.9060 - val_binary_accuracy: 0.4742 - 347ms/epoch - 12ms/step
#
# Split no 2
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.7086 - auc_47: 0.5765 - binary_accuracy: 0.4700 - val_loss: 0.6946 - val_auc_47: 0.6863 - val_binary_accuracy: 0.5021 - 1s/epoch - 38ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6771 - auc_47: 0.7902 - binary_accuracy: 0.4925 - val_loss: 0.6826 - val_auc_47: 0.7523 - val_binary_accuracy: 0.5150 - 309ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6611 - auc_47: 0.8238 - binary_accuracy: 0.5150 - val_loss: 0.6776 - val_auc_47: 0.8797 - val_binary_accuracy: 0.5193 - 322ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6513 - auc_47: 0.8514 - binary_accuracy: 0.5161 - val_loss: 0.6703 - val_auc_47: 0.8637 - val_binary_accuracy: 0.5236 - 328ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6436 - auc_47: 0.8929 - binary_accuracy: 0.5193 - val_loss: 0.6614 - val_auc_47: 0.8718 - val_binary_accuracy: 0.5236 - 325ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.6347 - auc_47: 0.8995 - binary_accuracy: 0.5193 - val_loss: 0.6525 - val_auc_47: 0.8728 - val_binary_accuracy: 0.5258 - 367ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.6239 - auc_47: 0.8977 - binary_accuracy: 0.5193 - val_loss: 0.6405 - val_auc_47: 0.8743 - val_binary_accuracy: 0.5258 - 340ms/epoch - 11ms/step
# Epoch 8/10
# 30/30 - 1s - loss: 0.6106 - auc_47: 0.9053 - binary_accuracy: 0.5193 - val_loss: 0.6268 - val_auc_47: 0.8922 - val_binary_accuracy: 0.5279 - 1s/epoch - 41ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.5938 - auc_47: 0.9120 - binary_accuracy: 0.5193 - val_loss: 0.6127 - val_auc_47: 0.9002 - val_binary_accuracy: 0.5300 - 310ms/epoch - 10ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.5713 - auc_47: 0.9158 - binary_accuracy: 0.5460 - val_loss: 0.5826 - val_auc_47: 0.8916 - val_binary_accuracy: 0.6910 - 338ms/epoch - 11ms/step
#
# Split no 3
#
# Training
# Epoch 1/10
# 30/30 - 1s - loss: 0.6929 - auc_48: 0.7250 - binary_accuracy: 0.4764 - val_loss: 0.6861 - val_auc_48: 0.7695 - val_binary_accuracy: 0.4936 - 1s/epoch - 40ms/step
# Epoch 2/10
# 30/30 - 0s - loss: 0.6632 - auc_48: 0.8377 - binary_accuracy: 0.5097 - val_loss: 0.6797 - val_auc_48: 0.7795 - val_binary_accuracy: 0.5000 - 311ms/epoch - 10ms/step
# Epoch 3/10
# 30/30 - 0s - loss: 0.6444 - auc_48: 0.8768 - binary_accuracy: 0.5215 - val_loss: 0.6617 - val_auc_48: 0.7173 - val_binary_accuracy: 0.5107 - 333ms/epoch - 11ms/step
# Epoch 4/10
# 30/30 - 0s - loss: 0.6254 - auc_48: 0.8807 - binary_accuracy: 0.5215 - val_loss: 0.6503 - val_auc_48: 0.8523 - val_binary_accuracy: 0.5150 - 344ms/epoch - 11ms/step
# Epoch 5/10
# 30/30 - 0s - loss: 0.6029 - auc_48: 0.9058 - binary_accuracy: 0.5215 - val_loss: 0.6236 - val_auc_48: 0.8615 - val_binary_accuracy: 0.5171 - 343ms/epoch - 11ms/step
# Epoch 6/10
# 30/30 - 0s - loss: 0.5709 - auc_48: 0.9128 - binary_accuracy: 0.5215 - val_loss: 0.5945 - val_auc_48: 0.8668 - val_binary_accuracy: 0.5192 - 353ms/epoch - 12ms/step
# Epoch 7/10
# 30/30 - 0s - loss: 0.5246 - auc_48: 0.9291 - binary_accuracy: 0.5279 - val_loss: 0.5704 - val_auc_48: 0.8512 - val_binary_accuracy: 0.7329 - 371ms/epoch - 12ms/step
# Epoch 8/10
# 30/30 - 0s - loss: 0.4658 - auc_48: 0.9383 - binary_accuracy: 0.7328 - val_loss: 0.5330 - val_auc_48: 0.8666 - val_binary_accuracy: 0.7372 - 342ms/epoch - 11ms/step
# Epoch 9/10
# 30/30 - 0s - loss: 0.4097 - auc_48: 0.9355 - binary_accuracy: 0.8015 - val_loss: 0.4875 - val_auc_48: 0.8905 - val_binary_accuracy: 0.7500 - 325ms/epoch - 11ms/step
# Epoch 10/10
# 30/30 - 0s - loss: 0.3602 - auc_48: 0.9412 - binary_accuracy: 0.8283 - val_loss: 0.4775 - val_auc_48: 0.8824 - val_binary_accuracy: 0.7500 - 343ms/epoch - 11ms/step

# %% [markdown]
# #### Tuned Parameters

# %%
print("Tuned Depth for Deep NN = ",d)
print("Tuned Widhth for Deep NN = ",w)
# Out:
# Tuned Depth for Deep NN =  4
# Tuned Widhth for Deep NN =  40

# %%
model = keras.Sequential( [keras.layers.Dense(40,activation='relu'),keras.layers.Dense(40,activation='relu'),
                           keras.layers.Dense(40,activation='relu'),keras.layers.Dense(40,activation='relu'),
                           keras.layers.Dense(1)] )

model.compile(optimizer = 'sgd',
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.AUC(from_logits=True),keras.metrics.BinaryAccuracy()])

model.fit(x_train,y_train, epochs = 20,validation_data=(x_validate,y_validate),verbose = 2)
# Out:
# Epoch 1/20
# 44/44 - 1s - loss: 0.6793 - auc_49: 0.7408 - binary_accuracy: 0.5071 - val_loss: 0.6584 - val_auc_49: 0.8465 - val_binary_accuracy: 0.5179 - 1s/epoch - 23ms/step
# Epoch 2/20
# 44/44 - 0s - loss: 0.6300 - auc_49: 0.8748 - binary_accuracy: 0.5257 - val_loss: 0.6265 - val_auc_49: 0.8750 - val_binary_accuracy: 0.5212 - 435ms/epoch - 10ms/step
# Epoch 3/20
# 44/44 - 0s - loss: 0.5882 - auc_49: 0.9162 - binary_accuracy: 0.5357 - val_loss: 0.5797 - val_auc_49: 0.9094 - val_binary_accuracy: 0.6906 - 378ms/epoch - 9ms/step
# Epoch 4/20
# 44/44 - 0s - loss: 0.5289 - auc_49: 0.9348 - binary_accuracy: 0.7257 - val_loss: 0.5215 - val_auc_49: 0.9213 - val_binary_accuracy: 0.6938 - 366ms/epoch - 8ms/step
# Epoch 5/20
# 44/44 - 0s - loss: 0.4508 - auc_49: 0.9416 - binary_accuracy: 0.8314 - val_loss: 0.4345 - val_auc_49: 0.9360 - val_binary_accuracy: 0.8306 - 373ms/epoch - 8ms/step
# Epoch 6/20
# 44/44 - 0s - loss: 0.3717 - auc_49: 0.9467 - binary_accuracy: 0.8400 - val_loss: 0.3628 - val_auc_49: 0.9390 - val_binary_accuracy: 0.8371 - 366ms/epoch - 8ms/step
# Epoch 7/20
# 44/44 - 0s - loss: 0.3133 - auc_49: 0.9496 - binary_accuracy: 0.8529 - val_loss: 0.3440 - val_auc_49: 0.9435 - val_binary_accuracy: 0.8241 - 374ms/epoch - 9ms/step
# Epoch 8/20
# 44/44 - 0s - loss: 0.2806 - auc_49: 0.9520 - binary_accuracy: 0.8521 - val_loss: 0.2870 - val_auc_49: 0.9424 - val_binary_accuracy: 0.8436 - 373ms/epoch - 8ms/step
# Epoch 9/20
# 44/44 - 0s - loss: 0.2591 - auc_49: 0.9515 - binary_accuracy: 0.8621 - val_loss: 0.2865 - val_auc_49: 0.9409 - val_binary_accuracy: 0.8436 - 374ms/epoch - 9ms/step
# Epoch 10/20
# 44/44 - 0s - loss: 0.2609 - auc_49: 0.9503 - binary_accuracy: 0.8529 - val_loss: 0.4055 - val_auc_49: 0.9421 - val_binary_accuracy: 0.8176 - 365ms/epoch - 8ms/step
# Epoch 11/20
# 44/44 - 0s - loss: 0.2696 - auc_49: 0.9485 - binary_accuracy: 0.8557 - val_loss: 0.2701 - val_auc_49: 0.9474 - val_binary_accuracy: 0.8469 - 374ms/epoch - 9ms/step
# Epoch 12/20
# 44/44 - 0s - loss: 0.2635 - auc_49: 0.9483 - binary_accuracy: 0.8450 - val_loss: 0.3179 - val_auc_49: 0.9471 - val_binary_accuracy: 0.8404 - 379ms/epoch - 9ms/step
# Epoch 13/20
# 44/44 - 0s - loss: 0.2592 - auc_49: 0.9517 - binary_accuracy: 0.8471 - val_loss: 0.4278 - val_auc_49: 0.9472 - val_binary_accuracy: 0.8306 - 370ms/epoch - 8ms/step
# Epoch 14/20
# 44/44 - 0s - loss: 0.2864 - auc_49: 0.9421 - binary_accuracy: 0.8386 - val_loss: 0.2532 - val_auc_49: 0.9485 - val_binary_accuracy: 0.8404 - 372ms/epoch - 8ms/step
# Epoch 15/20
# 44/44 - 0s - loss: 0.2529 - auc_49: 0.9515 - binary_accuracy: 0.8536 - val_loss: 0.2557 - val_auc_49: 0.9486 - val_binary_accuracy: 0.8469 - 374ms/epoch - 9ms/step
# Epoch 16/20
# 44/44 - 0s - loss: 0.2514 - auc_49: 0.9481 - binary_accuracy: 0.8571 - val_loss: 0.2490 - val_auc_49: 0.9487 - val_binary_accuracy: 0.8436 - 366ms/epoch - 8ms/step
# Epoch 17/20
# 44/44 - 0s - loss: 0.2493 - auc_49: 0.9513 - binary_accuracy: 0.8564 - val_loss: 0.3395 - val_auc_49: 0.9467 - val_binary_accuracy: 0.8274 - 376ms/epoch - 9ms/step
# Epoch 18/20
# 44/44 - 0s - loss: 0.2479 - auc_49: 0.9505 - binary_accuracy: 0.8543 - val_loss: 0.2506 - val_auc_49: 0.9489 - val_binary_accuracy: 0.8469 - 373ms/epoch - 8ms/step
# Epoch 19/20
# 44/44 - 0s - loss: 0.2309 - auc_49: 0.9565 - binary_accuracy: 0.8686 - val_loss: 0.2650 - val_auc_49: 0.9489 - val_binary_accuracy: 0.8469 - 375ms/epoch - 9ms/step
# Epoch 20/20
# 44/44 - 0s - loss: 0.2521 - auc_49: 0.9497 - binary_accuracy: 0.8557 - val_loss: 0.2532 - val_auc_49: 0.9489 - val_binary_accuracy: 0.8469 - 375ms/epoch - 9ms/step

# %% [markdown]
# ### Testing on test set

# %%
print("Evaluate on test data")
results = model.evaluate(x_test, y_test)
print("test accuracy = ", results[2]);
# Out:
# Evaluate on test data
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2969 - auc_49: 0.9411 - binary_accuracy: 0.8464
# test accuracy =  0.8464163541793823
